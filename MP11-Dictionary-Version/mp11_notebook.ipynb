# %% [markdown]
# # CS440/ECE448 Spring 2023
# # MP11: Reinforcement Learning

# %% [markdown]
# The first thing you need to do is to download this file: <a href="mp11.zip">mp11.zip</a>.  If you want, you can also download <a href="mp11_extra.zip">mp11_extra.zip</a>, the extra credit assignment.  `mp11.zip` has the following content:
#
# * `submitted.py`: Your homework. Edit, and then submit to <a href="https://www.gradescope.com/courses/486387">Gradescope</a>.
# * `mp11_notebook.ipynb`: This is a <a href="https://anaconda.org/anaconda/jupyter">Jupyter</a> notebook to help you debug.  You can completely ignore it if you want, although you might find that it gives you useful instructions.
# * `pong.py`: This is a program that plays Pong.  If called interactively, it will call the module `pong_display.py` to create a display, so that you can play.  If told to use a Q-learner, it will call your `submitted.py` to do Q-learning.
# * `grade.py`: Once your homework seems to be working, you can test it by typing `python grade.py`, which will run the tests in `tests/tests_visible.py`.
# * `tests/test_visible.py`: This file contains about half of the <a href="https://docs.python.org/3/library/unittest.html">unit tests</a> that Gradescope will run in order to grade your homework.  If you can get a perfect score on these tests, then you should also get a perfect score on the additional hidden tests that Gradescope uses.
# * `requirements.txt`: This tells you which python packages you need to have installed, in order to run `grade.py`.  You can install all of those packages by typing `pip install -r requirements.txt` or `pip3 install -r requirements.txt`.

# %% [markdown]
# This file (`mp11_notebook.ipynb`) will walk you through the whole MP, giving you instructions and debugging tips as you go.
#
# ### Table of Contents
#
# 1. <a href="#section1">Playing Pong</a>
# 1. <a href="#section2">Creating a Q-Learner Object</a>
# 1. <a href="#section3">Epsilon-First Exploration</a>
# 1. <a href="#section4">Q-Learning</a>
# 1. <a href="#section5">Saving and Loading Your Q and N Tables</a>
# 1. <a href="#section6">Exploitation</a>
# 1. <a href="#section7">Acting</a>
# 1. <a href="#section8">Training</a>
# 1. <a href="#section9">Extra Credit</a>
# 1. <a href="#grade">Grade Your Homework</a>

# %% [markdown]
# <a id='section1'></a>

# %% [markdown]
# ## Playing Pong

# %% [markdown]
# Pong was the <a href="https://en.wikipedia.org/wiki/Pong">first video game produced by Atari.</a>  It is a simple game, based on table tennis.  Here is a two-person version of the game: https://commons.wikimedia.org/wiki/File:Pong_Game_Test2.gif
#
# We will be playing a one-person version of the game:
#
# * When the ball hits the top, bottom, or left wall of the playing field, it bounces.
# * The right end of the playing field is open, except for the paddle.  If the ball hits the paddle, it bounces, and the player's score increments by one.  If the ball hits the open space, the game is over; the score resets to zero, and a new game begins.
#
# The game is pretty simple, but in order to get a better feeling for it, you may want to try playing it yourself.  Use the up arrow to move the paddle upward, and the down arrow to move the paddle downward.  See how high you can make your score:

# %%
# !python pong.py
# Out:
# pygame 2.3.0 (SDL 2.24.2, Python 3.10.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Completed 0 games, 3 rewards, 1012 frames, score 2, max score 2
# Completed 1 games, 4 rewards, 1220 frames, score 0, max score 2

# %% [markdown]
# Once you figure out how to use the arrow keys to control your paddle, we hope you will find that the game is not too hard for a human to play.  However, for a computer, it's difficult to know: where should the paddle be moved at each time step?  In order to see how difficult it is for a computer to play, let's ask the "random" player to play the game.
#
# **WARNING:** The following line will open a pygame window.  The pygame window will be hidden by this window -- in order to see it, you will need to minimize this window.  The pygame window will consume a lot of CPU time just waiting for the processor, so in order to kill it, you will need to come back to this window, click on the block below, then click the Jupyter "stop" button (the square button at the top of this window) in order to stop processing.

# %%
# !python pong.py --player random
# Out:
# pygame 2.3.0 (SDL 2.24.2, Python 3.10.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Completed 0 games, 1 rewards, 182 frames, score 0, max score 0
# Completed 1 games, 2 rewards, 390 frames, score 0, max score 0
# Completed 2 games, 3 rewards, 571 frames, score 0, max score 0
# Completed 3 games, 4 rewards, 752 frames, score 0, max score 0
# ^C
# Traceback (most recent call last):
#   File "/Users/jhasegaw/Dropbox/mark/teaching/ece448/ece448labs/spring23/mp11/src/pong.py", line 270, in <module>
#     application.run()
#   File "/Users/jhasegaw/Dropbox/mark/teaching/ece448/ece448labs/spring23/mp11/src/pong.py", line 170, in run
#     self.display.update_display()
#   File "/Users/jhasegaw/Dropbox/mark/teaching/ece448/ece448labs/spring23/mp11/src/pong_display.py", line 65, in update_display
#     self.fps.tick(60)
# KeyboardInterrupt

# %% [markdown]
# <a id='section2'></a>

# %% [markdown]
# ## Creating a Q-Learner Object

# %% [markdown]
# The first thing you will do is to create a `q_learner` object that can store your learned Q table and your N table (table of exploration counts).
#
# Like any other object-oriented language, python permits you to create new object classes in order to store data that will be needed from time to time.  If you are not already very, very familiar with python classes, you might want to study the python class tutorial: https://docs.python.org/3/tutorial/classes.html
#
# Like any other object in python, a `q_learner` object is created by calling its name as a function, e.g., `my_q_learner=submitted.q_learner()`.  Doing so calls the function `submitted.q_learner.__init__()`.  Let's look at the docstring to see what it should do.

# %%
import submitted, importlib
importlib.reload(submitted)
help(submitted.q_learner.__init__)
# Out:
# Help on function __init__ in module submitted:
#
# __init__(self, alpha, epsilon, gamma, nfirst, state_cardinality)
#     Create a new q_learner object.
#     Your q_learner object should store the provided values of alpha,
#     epsilon, gamma, and nfirst.
#     It should also create a Q table and an N table.
#     Q[...state..., ...action...] = expected utility of state/action pair.
#     N[...state..., ...action...] = # times state/action has been explored.
#     Both are initialized to all zeros.
#     Up to you: how will you encode the state and action in order to
#     define these two lookup tables?  The state will be a list of 5 integers,
#     such that 0 <= state[i] < state_cardinality[i] for 0 <= i < 5.
#
#     The action will be either -1, 0, or 1.
#     It is up to you to decide how to convert an input state and action
#     into indices that you can use to access your stored Q and N tables.
#
#     @params:
#     alpha (scalar) - learning rate of the Q-learner
#     epsilon (scalar) - probability of taking a random action
#     gamma (scalar) - discount factor
#     nfirst (scalar) - exploring each state/action pair nfirst times before exploiting
#     state_cardinality (list) - cardinality of each of the quantized state variables
#
#     @return:
#     None

# %% [markdown]
# Write your `__init__` function to meet the requirements specified in the docstring.  Once you have completed it, the following code should run without errors:

# %%
importlib.reload(submitted)

q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])

print(q_learner)
# Out:
# <submitted.q_learner object at 0x000001A7999F49D0>

# %% [markdown]
# <a id='section3'></a>

# %% [markdown]
# ## Epsilon-First Exploration

# %% [markdown]
# In order to manage the exploration/exploitation tradeoff, we will be using both "epsilon-first" and "epsilon-greedy" (https://en.wikipedia.org/wiki/Multi-armed_bandit#Semi-uniform_strategies).
#
# The epsilon-first strategy explores every state/action pair at least `nfirst` times before it ever starts to exploit any strategy.  Your `q_learner` should have a table to keep track of how many times it has explored a state/action pair prior to the start of any exploitation.  The method for storing that table is up to you; in order to have some standardized API, therefore, you need to write a method called `report_exploration_counts` that returns a list of the three exploration counts for a given state.

# %%
importlib.reload(submitted)
help(submitted.q_learner.report_exploration_counts)
# Out:
# Help on function report_exploration_counts in module submitted:
#
# report_exploration_counts(self, state)
#     Check to see how many times each action has been explored in this state.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     explored_count (array of 3 ints):
#       number of times that each action has been explored from this state.
#       The mapping from actions to integers is up to you, but there must be three of them.

# %% [markdown]
# Write `report_exploration_counts` so that it returns a list or array for any given state.  Test your code with the following:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('This is how many times state [0,0,0,0,0] has been explored so far:')
print(q_learner.report_exploration_counts([0,0,0,0,0]))
print('This is how many times state [9,9,1,1,9] has been explored so far:')
print(q_learner.report_exploration_counts([9,9,1,1,9]))
# Out:
# This is how many times state [0,0,0,0,0] has been explored so far:
# [0, 0, 0]
# This is how many times state [9,9,1,1,9] has been explored so far:
# [0, 0, 0]

# %% [markdown]
# When your learner first starts learning, it will call the function `choose_unexplored_action` to choose an unexplored action.  This function should choose a function uniformly at random from the set of unexplored actions in a given state, if there are any:

# %%
importlib.reload(submitted)
help(submitted.q_learner.choose_unexplored_action)
# Out:
# Help on function choose_unexplored_action in module submitted:
#
# choose_unexplored_action(self, state)
#     Choose an action that has been explored less than nfirst times.
#     If many actions are underexplored, you should choose uniformly
#     from among those actions; don't just choose the first one all
#     the time.
#
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#        These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     action (scalar): either -1, or 0, or 1, or None
#       If all actions have been explored at least n_explore times, return None.
#       Otherwise, choose one uniformly at random from those w/count less than n_explore.
#       When you choose an action, you should increment its count in your counter table.

# %% [markdown]
# If this has been written correctly, the following block should generate a random sequence of actions.  If the next block produces the same action 5 times in a row, that is the wrong result, and the result would be that your code does not pass the autograder.

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
# Out:
# Next action: 0
# Next action: 0
# Next action: -1
# Next action: 1
# Next action: -1

# %% [markdown]
# After all three actions have been explored `nfirst` times, the function `choose_unexplored_action` should return `None`, as shown here:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,1,[10,10,2,2,10])
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
# Out:
# Next action: 0
# Next action: 1
# Next action: -1
# Next action: None

# %% [markdown]
# <a id='section4'></a>

# %% [markdown]
# ## Q-Learning

# %% [markdown]
# The reinforcement learning we are implementing is called Q-learning (https://en.wikipedia.org/wiki/Q-learning).
#
# Q-learning keeps a table $Q[s,a]$ that specifies the expected utility of action $a$ in state $s$.  The organization of this table is up to you.  In order to have a standard API, the first thing you should implement is a function `report_q` with the following docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.report_q)
# Out:
# Help on function report_q in module submitted:
#
# report_q(self, state)
#     Report the current Q values for the given state.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     Q (array of 3 floats):
#       reward plus expected future utility of each of the three actions.
#       The mapping from actions to integers is up to you, but there must be three of them.

# %% [markdown]
# When your `q_learner` is first initialized, the value of $Q[state,action]$ should be zero for all state/action pairs, thus the `report_q` function should return lists of zeros:

# %%
importlib.reload(submitted)
q_learner=submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Q[0,0,0,0,0] is now:',q_learner.report_q([0,0,0,0,0]))
print('Q[9,9,1,1,9] is now:',q_learner.report_q([9,9,1,1,9]))
# Out:
# Q[0,0,0,0,0] is now: [0, 0, 0]
# Q[9,9,1,1,9] is now: [0, 0, 0]

# %% [markdown]
# There are actually many different Q-learning algorithms available, but when people refer to Q-learning with no modifier, they usually mean the time-difference (TD) algorithm.  For example, this is the algorithm that's described on the wikipedia page (https://en.wikipedia.org/wiki/Q-learning).  This is the algorithm you will implement for this MP.
#
# In supervised machine learning, the learner tries to imitate a reference label.  In reinforcement learning, there is no reference label.  Q-learning replaces the reference label with a "local Q" value, which is the utility that was obtained by performing action $a$ in state $s$ one time.  It is usually calculated like this:
#
# $$Q_{local}(s_t,a_t) = r_t + \gamma\max_{a_{t+1}}Q(s_{t+1},a_{t+1})$$
#
# where $r_t$ is the reward that was achieved by performing action $a_t$ in state $s_t$, $s_{t+1}$ is the state into which the game transitioned, and $a_{t+1}$ is one of the actions that could be performed in that state.  $Q_{local}$ is computed by your `q_local` function, which has this docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.q_local)
# Out:
# Help on function q_local in module submitted:
#
# q_local(self, reward, newstate)
#     The update to Q estimated from a single step of game play:
#     reward plus gamma times the max of Q[newstate, ...].
#
#     @param:
#     reward (scalar float): the reward achieved from the current step of game play.
#     newstate (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     Q_local (scalar float): the local value of Q
#
#     {
#       key: {
#         1: 2,
#         2: 4,
#         5: 1
#       }
#     }

# %% [markdown]
# Initially, `q_local` should just return the given reward, because initially, all Q values are 0:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,10,10])
print('Q_local(6.25,[9,9,1,1,9]) is currently:',q_learner.q_local(6.25,[9,9,1,1,9]))
# Out:
# Q_local(6.25,[9,9,1,1,9]) is currently: 6.25

# %% [markdown]
# Now you can use `q_learner.q_local` as the target for `q_learner.learn`.  The basic algorithm is
#
# $$Q(s,a) = Q(s,a) + \alpha (Q_{local}(s,a)-Q(s,a))$$
#
# Here is the docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.learn)
# Out:
# Help on function learn in module submitted:
#
# learn(self, state, action, reward, newstate)
#     Update the internal Q-table on the basis of an observed
#     state, action, reward, newstate sequence.
#
#     @params:
#     state: a list of 5 numbers: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle.
#     action: an integer, one of -1, 0, or +1
#     reward: a reward; positive for hitting the ball, negative for losing a game
#     newstate: a list of 5 numbers, in the same format as state
#
#     @return:
#     None

# %% [markdown]
# The following block checks a sequence of Q updates:
#
# 1. First, $Q([9,9,1,1,9],-1)$ is updated.  Since all Q values start at zero, it will be updated to just have a value equal to $\alpha$ (0.05) times the given reward (6.25) for a total value of 0.3125.
# 1. When we print out $Q([9,9,1,1,9],:)$, we see that one of the elements has been updated.
# 1. Next, update $Q([9,9,1,1,8],1)$ with a given reward, and with $[9,9,1,1,9]$ as the given next state.  Since $Q([9,9,1,1,9],-1)$ is larger than zero, the next-state Q-value should be multiplied by $\gamma$ (0.99) and added to the reward (3.1), then multiplied by $\alpha$, giving a total value of 0.17046875.
# 1. The resulting Q-value is reported.

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
q_learner.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('Q[9,9,1,1,9] is now',q_learner.report_q([9,9,1,1,9]))
q_learner.learn([9,9,1,1,8],1,3.1,[9,9,1,1,9])
print('Q[9,9,1,1,8] is now',q_learner.report_q([9,9,1,1,8]))
# Out:
# Q[9,9,1,1,9] is now [0.3125, 0, 0]
# Q[9,9,1,1,8] is now [0, 0, 0.17046875000000003]

# %% [markdown]
# <a id='section5'></a>

# %% [markdown]
# ## Saving and Loading your Q and N Tables

# %% [markdown]
# After you've spent a long time training your `q_learner`, you will want to save your Q and N tables so that you can reload them later.  The format of Q and N is up to you, therefore it's also up to you to write the `save` and `load` functions.  Here are the docstrings:

# %%
importlib.reload(submitted)
help(submitted.q_learner.save)
# Out:
# Help on function save in module submitted:
#
# save(self, filename)
#     Save your Q and N tables to a file.
#     This can save in any format you like, as long as your "load"
#     function uses the same file format.  We recommend numpy.savez,
#     but you can use something else if you prefer.
#
#     @params:
#     filename (str) - filename to which it should be saved
#     @return:
#     None

# %%
importlib.reload(submitted)
help(submitted.q_learner.load)
# Out:
# Help on function load in module submitted:
#
# load(self, filename)
#     Load the Q and N tables from a file.
#     This should load from whatever file format your save function
#     used.  We recommend numpy.load, but you can use something
#     else if you prefer.
#
#     @params:
#     filename (str) - filename from which it should be loaded
#     @return:
#     None

# %% [markdown]
# These functions can be tested by doing one step of training one `q_learner`, then saving its results, then loading them into another `q_learner`:

# %%
importlib.reload(submitted)
q_learner1 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Next action:',q_learner1.choose_unexplored_action([9,9,1,1,9]))
q_learner1.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('N1[9,9,1,1,8] is now',q_learner1.report_exploration_counts([9,9,1,1,9]))
print('Q1[9,9,1,1,8] is now',q_learner1.report_q([9,9,1,1,9]))
q_learner1.save('test.npz')

q_learner2 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('N2[9,9,1,1,8] starts out as',q_learner2.report_exploration_counts([9,9,1,1,9]))
print('Q2[9,9,1,1,8] starts out as',q_learner2.report_q([9,9,1,1,9]))
q_learner2.load('test.npz')
print('N2[9,9,1,1,8] is now',q_learner2.report_exploration_counts([9,9,1,1,9]))
print('Q2[9,9,1,1,8] is now',q_learner2.report_q([9,9,1,1,9]))
# Out:
# Next action: -1
# N1[9,9,1,1,8] is now [1, 0, 0]
# Q1[9,9,1,1,8] is now [0.3125, 0, 0]
# N2[9,9,1,1,8] starts out as [0, 0, 0]
# Q2[9,9,1,1,8] starts out as [0, 0, 0]
# N2[9,9,1,1,8] is now [0, 0, 0]
# Q2[9,9,1,1,8] is now [0, 0, 0]

# %% [markdown]
# <a id='section6'></a>

# %% [markdown]
# ## Exploitation

# %% [markdown]
# A reinforcement learner always has to trade off between exploration (choosing an action at random) versus exploitation (choosing the action with the maximum expected utility).  Before we worry about that tradeoff, though, let's first make sure that exploitation works.

# %%
importlib.reload(submitted)
help(submitted.q_learner.exploit)
# Out:
# Help on function exploit in module submitted:
#
# exploit(self, state)
#     Return the action that has the highest Q-value for the current state, and its Q-value.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     action (scalar int): either -1, or 0, or 1.
#       The action that has the highest Q-value.  Ties can be broken any way you want.
#     Q (scalar float):
#       The Q-value of the selected action

# %%
importlib.reload(submitted)
q_learner1 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
q_learner1.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('Q1[9,9,1,1,9] is now',q_learner1.report_q([9,9,1,1,9]))
print('The best action and Q from state [9,9,1,1,9] are',q_learner1.exploit([9,9,1,1,9]))
# Out:
# Q1[9,9,1,1,9] is now [0.3125, 0, 0]
# The best action and Q from state [9,9,1,1,9] are (-1, 0.3125)

# %% [markdown]
# <a id='section7'></a>

# %% [markdown]
# ## Acting

# %% [markdown]
# When your learner decides which action to perform, it should trade off exploration vs. exploitation using both the epsilon-first and the epsilon-greedy strategies:
# 1. If there is any action that has been explored fewer than `nfirst` times, then choose one of those actions at random.  Otherwise...
# 1. With probability `epsilon`, choose an action at random.  Otherwise...
# 1. Exploit.

# %%
importlib.reload(submitted)
help(submitted.q_learner.act)
# Out:
# Help on function act in module submitted:
#
# act(self, state)
#     Decide what action to take in the current state.
#     If any action has been taken less than nfirst times, then choose one of those
#     actions, uniformly at random.
#     Otherwise, with probability epsilon, choose an action uniformly at random.
#     Otherwise, choose the action with the best Q(state,action).
#
#     @params:
#     state: a list of 5 integers: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     -1 if the paddle should move upward
#     0 if the paddle should be stationary
#     1 if the paddle should move downward

# %% [markdown]
# In order to test all three types of action (epsilon-first exploration, epsilon-greedy exploration, and exploitation), let's create a learner with `nfirst=1` and `epsilon=0.25`, and set it so that the best action from state `[9,9,1,1,9]` is `-1`.  With these settings, a sequence of calls to `q_learner.act` should produce the following sequence of actions:
#
# 1. The first three actions should include each possible action once.
# 1. After the first three actions, 3/4 of the remaining actions should be `-1`.  The remaining 1/4 should be randomly chosen.

# %%
importlib.reload(submitted)
q_learner=submitted.q_learner(0.05,0.25,0.99,1,[10,10,2,2,10])
q_learner.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
# Out:
# An epsilon-first action: -1
# An epsilon-first action: 0
# An epsilon-first action: 1
# An epsilon-greedy explore/exploit action: None
# An epsilon-greedy explore/exploit action: None
# An epsilon-greedy explore/exploit action: None
# An epsilon-greedy explore/exploit action: None
# An epsilon-greedy explore/exploit action: None
# An epsilon-greedy explore/exploit action: None
# An epsilon-greedy explore/exploit action: None
# An epsilon-greedy explore/exploit action: None
# An epsilon-greedy explore/exploit action: None
# An epsilon-greedy explore/exploit action: None
# An epsilon-greedy explore/exploit action: 0
# An epsilon-greedy explore/exploit action: 1

# %% [markdown]
# <a id='section8'></a>

# %% [markdown]
# ## Training

# %% [markdown]
# Now that all of your components work, you can try training your algorithm.  Do this by giving your `q_learner` as a player to a new `pong.PongGame` object.  Set `visibility=False` so that the `PongGame` doesn't create a new window.

# %%
import pong, importlib, submitted
importlib.reload(pong)
help(pong.PongGame.__init__)
# Out:
# Help on function __init__ in module pong:
#
# __init__(self, ball_speed=4, paddle_speed=8, learner=None, visible=True, state_quantization=[10, 10, 2, 2, 10])
#     Create a new pong game, with a specified player.
#
#     @params:
#     ball_speed (scalar int) - average ball speed in pixels/frame
#     paddle_speed (scalar int) - paddle moves 0, +paddle_speed, or -paddle_speed
#     learner - can be None if the player is human.  If not None, should be an
#       object of type random_learner, submitted.q_learner, or submitted.deep_q.
#     visible (bool) - should this game have an attached pygame window?
#     state_quantization (list) - if not None, state variables are quantized
#       into integers of these cardinalities before being passed to the learner.

# %% [markdown]
# As you can see, we should set `visibility=False` so that the `PongGame` doesn't create a new window.  We should also make sure that the PongGame uses the same state quantization as the learner.

# %%
importlib.reload(pong)
importlib.reload(submitted)
state_quantization = [10,10,2,2,10]
q_learner=submitted.q_learner(0.05,0.05,0.99,5,state_quantization)

pong_game = pong.PongGame(learner=q_learner, visible=False, state_quantization=state_quantization)
print(pong_game)
# Out:
# <pong.PongGame object at 0x000001A7984D7A50>

# %% [markdown]
# In order to train our learner, we want it to play the game many times.  To do that we use the PongGame.run function:

# %%
help(pong_game.run)
# Out:
# Help on method run in module pong:
#
# run(m_rewards=inf, m_games=inf, m_frames=inf, states=[]) method of pong.PongGame instance
#     Run the game.
#     @param
#     m_frames (scalar int): maximum number of frames to be played
#     m_rewards (scalar int): maximum number of rewards earned (+ or -)
#     m_games (scalar int): maximum number of games
#     states (list): list of states whose Q-values should be returned
#        each state is a list of 5 ints: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#        These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#        and the y-position of the paddle, all quantized.
#        0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#
#     @return
#     scores (list): list of scores of all completed games
#
#     The following will be returned only if the player is q_learning or deep_q.
#     New elements will be added to these lists once/frame if m_frames is specified,
#     else once/reward if m_rewards is specified, else once/game:
#       q_achieved (list): list of the q-values of the moves that were taken
#       q_states (list): list of the q-values of requested states

# %% [markdown]
# In order to make sure our learner is learning, let's tell `pong_game.run` to output all 3 Q-values of all of the 4000 states in every time step.
#
# To make sure that's not an outrageous amount of data, let's tell it to only output the Q values once/reward, and ask it to only collect 5000 rewards:

# %%
states = [[x,y,vx,vy,py] for x in range(10) for y in range(10) for vx in range(2) for vy in range(2) for py in range(10) ]

scores, q_achieved, q_states = pong_game.run(m_rewards=500, states=states)

print('The number of games played was',len(scores))
print('The number of rewards was',len(q_states))
print('The size of each returned Q-matrix was',q_states[0].shape)
# Out:
# Completed 0 games, 2 rewards, 406 frames, score 1, max score 1
# Completed 1 games, 3 rewards, 587 frames, score 0, max score 1
# Completed 2 games, 6 rewards, 1373 frames, score 2, max score 2
# Completed 3 games, 9 rewards, 1958 frames, score 2, max score 2
# Completed 4 games, 10 rewards, 2212 frames, score 0, max score 2
# Completed 5 games, 12 rewards, 2763 frames, score 1, max score 2
# Completed 6 games, 14 rewards, 3314 frames, score 1, max score 2
# Completed 7 games, 16 rewards, 3720 frames, score 1, max score 2
# Completed 8 games, 17 rewards, 3901 frames, score 0, max score 2
# Completed 9 games, 19 rewards, 4253 frames, score 1, max score 2
# Completed 10 games, 20 rewards, 4507 frames, score 0, max score 2
# Completed 11 games, 24 rewards, 6154 frames, score 3, max score 3
# Completed 12 games, 25 rewards, 6362 frames, score 0, max score 3
# Completed 13 games, 26 rewards, 6570 frames, score 0, max score 3
# Completed 14 games, 27 rewards, 6778 frames, score 0, max score 3
# Completed 15 games, 28 rewards, 7032 frames, score 0, max score 3
# Completed 16 games, 29 rewards, 7240 frames, score 0, max score 3
# Completed 17 games, 30 rewards, 7448 frames, score 0, max score 3
# Completed 18 games, 32 rewards, 7816 frames, score 1, max score 3
# Completed 19 games, 35 rewards, 8341 frames, score 2, max score 3
# Completed 20 games, 36 rewards, 8595 frames, score 0, max score 3
# Completed 21 games, 37 rewards, 8803 frames, score 0, max score 3
# Completed 22 games, 39 rewards, 9337 frames, score 1, max score 3
# Completed 23 games, 40 rewards, 9545 frames, score 0, max score 3
# Completed 24 games, 41 rewards, 9753 frames, score 0, max score 3
# Completed 25 games, 42 rewards, 9961 frames, score 0, max score 3
# Completed 26 games, 43 rewards, 10215 frames, score 0, max score 3
# Completed 27 games, 44 rewards, 10423 frames, score 0, max score 3
# Completed 28 games, 46 rewards, 10974 frames, score 1, max score 3
# Completed 29 games, 47 rewards, 11155 frames, score 0, max score 3
# Completed 30 games, 48 rewards, 11336 frames, score 0, max score 3
# Completed 31 games, 49 rewards, 11517 frames, score 0, max score 3
# Completed 32 games, 51 rewards, 11900 frames, score 1, max score 3
# Completed 33 games, 52 rewards, 12154 frames, score 0, max score 3
# Completed 34 games, 53 rewards, 12335 frames, score 0, max score 3
# Completed 35 games, 54 rewards, 12516 frames, score 0, max score 3
# Completed 36 games, 56 rewards, 12929 frames, score 1, max score 3
# Completed 37 games, 58 rewards, 13357 frames, score 1, max score 3
# Completed 38 games, 59 rewards, 13611 frames, score 0, max score 3
# Completed 39 games, 61 rewards, 14048 frames, score 1, max score 3
# Completed 40 games, 62 rewards, 14229 frames, score 0, max score 3
# Completed 41 games, 63 rewards, 14410 frames, score 0, max score 3
# Completed 42 games, 65 rewards, 15012 frames, score 1, max score 3
# Completed 43 games, 66 rewards, 15220 frames, score 0, max score 3
# Completed 44 games, 67 rewards, 15428 frames, score 0, max score 3
# Completed 45 games, 68 rewards, 15682 frames, score 0, max score 3
# Completed 46 games, 69 rewards, 15890 frames, score 0, max score 3
# Completed 47 games, 70 rewards, 16098 frames, score 0, max score 3
# Completed 48 games, 71 rewards, 16352 frames, score 0, max score 3
# Completed 49 games, 72 rewards, 16606 frames, score 0, max score 3
# Completed 50 games, 73 rewards, 16787 frames, score 0, max score 3
# Completed 51 games, 74 rewards, 16995 frames, score 0, max score 3
# Completed 52 games, 75 rewards, 17249 frames, score 0, max score 3
# Completed 53 games, 76 rewards, 17503 frames, score 0, max score 3
# Completed 54 games, 77 rewards, 17711 frames, score 0, max score 3
# Completed 55 games, 78 rewards, 17892 frames, score 0, max score 3
# Completed 56 games, 80 rewards, 18811 frames, score 1, max score 3
# Completed 57 games, 81 rewards, 19019 frames, score 0, max score 3
# Completed 58 games, 82 rewards, 19200 frames, score 0, max score 3
# Completed 59 games, 83 rewards, 19454 frames, score 0, max score 3
# Completed 60 games, 84 rewards, 19708 frames, score 0, max score 3
# Completed 61 games, 85 rewards, 19962 frames, score 0, max score 3
# Completed 62 games, 88 rewards, 20762 frames, score 2, max score 3
# Completed 63 games, 90 rewards, 21199 frames, score 1, max score 3
# Completed 64 games, 91 rewards, 21380 frames, score 0, max score 3
# Completed 65 games, 92 rewards, 21634 frames, score 0, max score 3
# Completed 66 games, 93 rewards, 21842 frames, score 0, max score 3
# Completed 67 games, 94 rewards, 22096 frames, score 0, max score 3
# Completed 68 games, 95 rewards, 22350 frames, score 0, max score 3
# Completed 69 games, 96 rewards, 22531 frames, score 0, max score 3
# Completed 70 games, 97 rewards, 22785 frames, score 0, max score 3
# Completed 71 games, 98 rewards, 22966 frames, score 0, max score 3
# Completed 72 games, 99 rewards, 23220 frames, score 0, max score 3
# Completed 73 games, 100 rewards, 23401 frames, score 0, max score 3
# Completed 74 games, 103 rewards, 24074 frames, score 2, max score 3
# Completed 75 games, 104 rewards, 24282 frames, score 0, max score 3
# Completed 76 games, 106 rewards, 24673 frames, score 1, max score 3
# Completed 77 games, 107 rewards, 24854 frames, score 0, max score 3
# Completed 78 games, 108 rewards, 25062 frames, score 0, max score 3
# Completed 79 games, 109 rewards, 25270 frames, score 0, max score 3
# Completed 80 games, 113 rewards, 26058 frames, score 3, max score 3
# Completed 81 games, 114 rewards, 26312 frames, score 0, max score 3
# Completed 82 games, 116 rewards, 26800 frames, score 1, max score 3
# Completed 83 games, 117 rewards, 27054 frames, score 0, max score 3
# Completed 84 games, 118 rewards, 27235 frames, score 0, max score 3
# Completed 85 games, 120 rewards, 27835 frames, score 1, max score 3
# Completed 86 games, 121 rewards, 28043 frames, score 0, max score 3
# Completed 87 games, 122 rewards, 28251 frames, score 0, max score 3
# Completed 88 games, 123 rewards, 28459 frames, score 0, max score 3
# Completed 89 games, 124 rewards, 28713 frames, score 0, max score 3
# Completed 90 games, 125 rewards, 28921 frames, score 0, max score 3
# Completed 91 games, 126 rewards, 29129 frames, score 0, max score 3
# Completed 92 games, 128 rewards, 29516 frames, score 1, max score 3
# Completed 93 games, 129 rewards, 29770 frames, score 0, max score 3
# Completed 94 games, 130 rewards, 30024 frames, score 0, max score 3
# Completed 95 games, 131 rewards, 30205 frames, score 0, max score 3
# Completed 96 games, 132 rewards, 30459 frames, score 0, max score 3
# Completed 97 games, 133 rewards, 30713 frames, score 0, max score 3
# Completed 98 games, 134 rewards, 30967 frames, score 0, max score 3
# Completed 99 games, 135 rewards, 31221 frames, score 0, max score 3
# Completed 100 games, 136 rewards, 31475 frames, score 0, max score 3
# Completed 101 games, 137 rewards, 31683 frames, score 0, max score 3
# Completed 102 games, 138 rewards, 31937 frames, score 0, max score 3
# Completed 103 games, 139 rewards, 32191 frames, score 0, max score 3
# Completed 104 games, 140 rewards, 32445 frames, score 0, max score 3
# Completed 105 games, 141 rewards, 32626 frames, score 0, max score 3
# Completed 106 games, 143 rewards, 33202 frames, score 1, max score 3
# Completed 107 games, 145 rewards, 33630 frames, score 1, max score 3
# Completed 108 games, 146 rewards, 33838 frames, score 0, max score 3
# Completed 109 games, 147 rewards, 34092 frames, score 0, max score 3
# Completed 110 games, 148 rewards, 34300 frames, score 0, max score 3
# Completed 111 games, 149 rewards, 34481 frames, score 0, max score 3
# Completed 112 games, 150 rewards, 34662 frames, score 0, max score 3
# Completed 113 games, 153 rewards, 35419 frames, score 2, max score 3
# Completed 114 games, 155 rewards, 35824 frames, score 1, max score 3
# Completed 115 games, 156 rewards, 36032 frames, score 0, max score 3
# Completed 116 games, 158 rewards, 36583 frames, score 1, max score 3
# Completed 117 games, 159 rewards, 36837 frames, score 0, max score 3
# Completed 118 games, 160 rewards, 37045 frames, score 0, max score 3
# Completed 119 games, 161 rewards, 37253 frames, score 0, max score 3
# Completed 120 games, 163 rewards, 37620 frames, score 1, max score 3
# Completed 121 games, 165 rewards, 38282 frames, score 1, max score 3
# Completed 122 games, 167 rewards, 38688 frames, score 1, max score 3
# Completed 123 games, 168 rewards, 38869 frames, score 0, max score 3
# Completed 124 games, 169 rewards, 39077 frames, score 0, max score 3
# Completed 125 games, 170 rewards, 39331 frames, score 0, max score 3
# Completed 126 games, 171 rewards, 39585 frames, score 0, max score 3
# Completed 127 games, 172 rewards, 39839 frames, score 0, max score 3
# Completed 128 games, 173 rewards, 40047 frames, score 0, max score 3
# Completed 129 games, 176 rewards, 42071 frames, score 2, max score 3
# Completed 130 games, 177 rewards, 42252 frames, score 0, max score 3
# Completed 131 games, 178 rewards, 42506 frames, score 0, max score 3
# Completed 132 games, 179 rewards, 42760 frames, score 0, max score 3
# Completed 133 games, 180 rewards, 43014 frames, score 0, max score 3
# Completed 134 games, 181 rewards, 43195 frames, score 0, max score 3
# Completed 135 games, 182 rewards, 43449 frames, score 0, max score 3
# Completed 136 games, 184 rewards, 43871 frames, score 1, max score 3
# Completed 137 games, 185 rewards, 44052 frames, score 0, max score 3
# Completed 138 games, 186 rewards, 44233 frames, score 0, max score 3
# Completed 139 games, 188 rewards, 44643 frames, score 1, max score 3
# Completed 140 games, 189 rewards, 44851 frames, score 0, max score 3
# Completed 141 games, 190 rewards, 45032 frames, score 0, max score 3
# Completed 142 games, 191 rewards, 45286 frames, score 0, max score 3
# Completed 143 games, 192 rewards, 45494 frames, score 0, max score 3
# Completed 144 games, 193 rewards, 45675 frames, score 0, max score 3
# Completed 145 games, 194 rewards, 45883 frames, score 0, max score 3
# Completed 146 games, 195 rewards, 46091 frames, score 0, max score 3
# Completed 147 games, 196 rewards, 46345 frames, score 0, max score 3
# Completed 148 games, 197 rewards, 46526 frames, score 0, max score 3
# Completed 149 games, 198 rewards, 46707 frames, score 0, max score 3
# Completed 150 games, 199 rewards, 46915 frames, score 0, max score 3
# Completed 151 games, 200 rewards, 47096 frames, score 0, max score 3
# Completed 152 games, 201 rewards, 47350 frames, score 0, max score 3
# Completed 153 games, 202 rewards, 47558 frames, score 0, max score 3
# Completed 154 games, 203 rewards, 47812 frames, score 0, max score 3
# Completed 155 games, 204 rewards, 47993 frames, score 0, max score 3
# Completed 156 games, 205 rewards, 48174 frames, score 0, max score 3
# Completed 157 games, 206 rewards, 48382 frames, score 0, max score 3
# Completed 158 games, 207 rewards, 48636 frames, score 0, max score 3
# Completed 159 games, 208 rewards, 48890 frames, score 0, max score 3
# Completed 160 games, 209 rewards, 49098 frames, score 0, max score 3
# Completed 161 games, 211 rewards, 49606 frames, score 1, max score 3
# Completed 162 games, 212 rewards, 49860 frames, score 0, max score 3
# Completed 163 games, 213 rewards, 50041 frames, score 0, max score 3
# Completed 164 games, 214 rewards, 50222 frames, score 0, max score 3
# Completed 165 games, 215 rewards, 50476 frames, score 0, max score 3
# Completed 166 games, 216 rewards, 50730 frames, score 0, max score 3
# Completed 167 games, 217 rewards, 50938 frames, score 0, max score 3
# Completed 168 games, 218 rewards, 51119 frames, score 0, max score 3
# Completed 169 games, 221 rewards, 51818 frames, score 2, max score 3
# Completed 170 games, 222 rewards, 52072 frames, score 0, max score 3
# Completed 171 games, 223 rewards, 52253 frames, score 0, max score 3
# Completed 172 games, 225 rewards, 52690 frames, score 1, max score 3
# Completed 173 games, 226 rewards, 52944 frames, score 0, max score 3
# Completed 174 games, 228 rewards, 53327 frames, score 1, max score 3
# Completed 175 games, 229 rewards, 53581 frames, score 0, max score 3
# Completed 176 games, 230 rewards, 53789 frames, score 0, max score 3
# Completed 177 games, 231 rewards, 53970 frames, score 0, max score 3
# Completed 178 games, 232 rewards, 54178 frames, score 0, max score 3
# Completed 179 games, 235 rewards, 54736 frames, score 2, max score 3
# Completed 180 games, 236 rewards, 54917 frames, score 0, max score 3
# Completed 181 games, 237 rewards, 55098 frames, score 0, max score 3
# Completed 182 games, 238 rewards, 55352 frames, score 0, max score 3
# Completed 183 games, 239 rewards, 55606 frames, score 0, max score 3
# Completed 184 games, 240 rewards, 55814 frames, score 0, max score 3
# Completed 185 games, 241 rewards, 55995 frames, score 0, max score 3
# Completed 186 games, 242 rewards, 56203 frames, score 0, max score 3
# Completed 187 games, 243 rewards, 56384 frames, score 0, max score 3
# Completed 188 games, 244 rewards, 56565 frames, score 0, max score 3
# Completed 189 games, 245 rewards, 56746 frames, score 0, max score 3
# Completed 190 games, 246 rewards, 56954 frames, score 0, max score 3
# Completed 191 games, 247 rewards, 57135 frames, score 0, max score 3
# Completed 192 games, 248 rewards, 57389 frames, score 0, max score 3
# Completed 193 games, 249 rewards, 57643 frames, score 0, max score 3
# Completed 194 games, 252 rewards, 58123 frames, score 2, max score 3
# Completed 195 games, 253 rewards, 58304 frames, score 0, max score 3
# Completed 196 games, 254 rewards, 58485 frames, score 0, max score 3
# Completed 197 games, 255 rewards, 58739 frames, score 0, max score 3
# Completed 198 games, 256 rewards, 58947 frames, score 0, max score 3
# Completed 199 games, 257 rewards, 59128 frames, score 0, max score 3
# Completed 200 games, 259 rewards, 59616 frames, score 1, max score 3
# Completed 201 games, 260 rewards, 59870 frames, score 0, max score 3
# Completed 202 games, 261 rewards, 60124 frames, score 0, max score 3
# Completed 203 games, 262 rewards, 60332 frames, score 0, max score 3
# Completed 204 games, 263 rewards, 60513 frames, score 0, max score 3
# Completed 205 games, 264 rewards, 60767 frames, score 0, max score 3
# Completed 206 games, 265 rewards, 60975 frames, score 0, max score 3
# Completed 207 games, 267 rewards, 61637 frames, score 1, max score 3
# Completed 208 games, 269 rewards, 62108 frames, score 1, max score 3
# Completed 209 games, 270 rewards, 62362 frames, score 0, max score 3
# Completed 210 games, 272 rewards, 62913 frames, score 1, max score 3
# Completed 211 games, 273 rewards, 63121 frames, score 0, max score 3
# Completed 212 games, 274 rewards, 63375 frames, score 0, max score 3
# Completed 213 games, 275 rewards, 63629 frames, score 0, max score 3
# Completed 214 games, 276 rewards, 63837 frames, score 0, max score 3
# Completed 215 games, 278 rewards, 64189 frames, score 1, max score 3
# Completed 216 games, 279 rewards, 64397 frames, score 0, max score 3
# Completed 217 games, 280 rewards, 64605 frames, score 0, max score 3
# Completed 218 games, 281 rewards, 64859 frames, score 0, max score 3
# Completed 219 games, 283 rewards, 65299 frames, score 1, max score 3
# Completed 220 games, 284 rewards, 65480 frames, score 0, max score 3
# Completed 221 games, 285 rewards, 65734 frames, score 0, max score 3
# Completed 222 games, 286 rewards, 65942 frames, score 0, max score 3
# Completed 223 games, 287 rewards, 66150 frames, score 0, max score 3
# Completed 224 games, 289 rewards, 66578 frames, score 1, max score 3
# Completed 225 games, 292 rewards, 67437 frames, score 2, max score 3
# Completed 226 games, 293 rewards, 67618 frames, score 0, max score 3
# Completed 227 games, 294 rewards, 67826 frames, score 0, max score 3
# Completed 228 games, 295 rewards, 68007 frames, score 0, max score 3
# Completed 229 games, 296 rewards, 68215 frames, score 0, max score 3
# Completed 230 games, 297 rewards, 68469 frames, score 0, max score 3
# Completed 231 games, 298 rewards, 68677 frames, score 0, max score 3
# Completed 232 games, 299 rewards, 68858 frames, score 0, max score 3
# Completed 233 games, 300 rewards, 69112 frames, score 0, max score 3
# Completed 234 games, 301 rewards, 69366 frames, score 0, max score 3
# Completed 235 games, 302 rewards, 69620 frames, score 0, max score 3
# Completed 236 games, 304 rewards, 70034 frames, score 1, max score 3
# Completed 237 games, 305 rewards, 70288 frames, score 0, max score 3
# Completed 238 games, 306 rewards, 70496 frames, score 0, max score 3
# Completed 239 games, 307 rewards, 70750 frames, score 0, max score 3
# Completed 240 games, 308 rewards, 70931 frames, score 0, max score 3
# Completed 241 games, 310 rewards, 71336 frames, score 1, max score 3
# Completed 242 games, 312 rewards, 71998 frames, score 1, max score 3
# Completed 243 games, 313 rewards, 72252 frames, score 0, max score 3
# Completed 244 games, 314 rewards, 72506 frames, score 0, max score 3
# Completed 245 games, 317 rewards, 73043 frames, score 2, max score 3
# Completed 246 games, 318 rewards, 73224 frames, score 0, max score 3
# Completed 247 games, 319 rewards, 73432 frames, score 0, max score 3
# Completed 248 games, 320 rewards, 73640 frames, score 0, max score 3
# Completed 249 games, 322 rewards, 74174 frames, score 1, max score 3
# Completed 250 games, 323 rewards, 74355 frames, score 0, max score 3
# Completed 251 games, 324 rewards, 74609 frames, score 0, max score 3
# Completed 252 games, 326 rewards, 74980 frames, score 1, max score 3
# Completed 253 games, 327 rewards, 75188 frames, score 0, max score 3
# Completed 254 games, 329 rewards, 75850 frames, score 1, max score 3
# Completed 255 games, 330 rewards, 76104 frames, score 0, max score 3
# Completed 256 games, 331 rewards, 76312 frames, score 0, max score 3
# Completed 257 games, 333 rewards, 76749 frames, score 1, max score 3
# Completed 258 games, 334 rewards, 76957 frames, score 0, max score 3
# Completed 259 games, 335 rewards, 77165 frames, score 0, max score 3
# Completed 260 games, 336 rewards, 77419 frames, score 0, max score 3
# Completed 261 games, 338 rewards, 77970 frames, score 1, max score 3
# Completed 262 games, 339 rewards, 78224 frames, score 0, max score 3
# Completed 263 games, 340 rewards, 78432 frames, score 0, max score 3
# Completed 264 games, 341 rewards, 78686 frames, score 0, max score 3
# Completed 265 games, 342 rewards, 78867 frames, score 0, max score 3
# Completed 266 games, 343 rewards, 79048 frames, score 0, max score 3
# Completed 267 games, 346 rewards, 79633 frames, score 2, max score 3
# Completed 268 games, 348 rewards, 80055 frames, score 1, max score 3
# Completed 269 games, 349 rewards, 80263 frames, score 0, max score 3
# Completed 270 games, 350 rewards, 80471 frames, score 0, max score 3
# Completed 271 games, 351 rewards, 80725 frames, score 0, max score 3
# Completed 272 games, 352 rewards, 80906 frames, score 0, max score 3
# Completed 273 games, 353 rewards, 81114 frames, score 0, max score 3
# Completed 274 games, 354 rewards, 81322 frames, score 0, max score 3
# Completed 275 games, 355 rewards, 81530 frames, score 0, max score 3
# Completed 276 games, 358 rewards, 82039 frames, score 2, max score 3
# Completed 277 games, 359 rewards, 82247 frames, score 0, max score 3
# Completed 278 games, 360 rewards, 82501 frames, score 0, max score 3
# Completed 279 games, 361 rewards, 82709 frames, score 0, max score 3
# Completed 280 games, 362 rewards, 82890 frames, score 0, max score 3
# Completed 281 games, 363 rewards, 83098 frames, score 0, max score 3
# Completed 282 games, 364 rewards, 83306 frames, score 0, max score 3
# Completed 283 games, 365 rewards, 83560 frames, score 0, max score 3
# Completed 284 games, 366 rewards, 83768 frames, score 0, max score 3
# Completed 285 games, 367 rewards, 83949 frames, score 0, max score 3
# Completed 286 games, 368 rewards, 84130 frames, score 0, max score 3
# Completed 287 games, 369 rewards, 84338 frames, score 0, max score 3
# Completed 288 games, 370 rewards, 84592 frames, score 0, max score 3
# Completed 289 games, 372 rewards, 85172 frames, score 1, max score 3
# Completed 290 games, 374 rewards, 85513 frames, score 1, max score 3
# Completed 291 games, 376 rewards, 85950 frames, score 1, max score 3
# Completed 292 games, 377 rewards, 86158 frames, score 0, max score 3
# Completed 293 games, 378 rewards, 86412 frames, score 0, max score 3
# Completed 294 games, 379 rewards, 86620 frames, score 0, max score 3
# Completed 295 games, 381 rewards, 87117 frames, score 1, max score 3
# Completed 296 games, 382 rewards, 87371 frames, score 0, max score 3
# Completed 297 games, 384 rewards, 87799 frames, score 1, max score 3
# Completed 298 games, 385 rewards, 88007 frames, score 0, max score 3
# Completed 299 games, 388 rewards, 88617 frames, score 2, max score 3
# Completed 300 games, 389 rewards, 88871 frames, score 0, max score 3
# Completed 301 games, 390 rewards, 89079 frames, score 0, max score 3
# Completed 302 games, 391 rewards, 89260 frames, score 0, max score 3
# Completed 303 games, 393 rewards, 89643 frames, score 1, max score 3
# Completed 304 games, 394 rewards, 89897 frames, score 0, max score 3
# Completed 305 games, 395 rewards, 90105 frames, score 0, max score 3
# Completed 306 games, 397 rewards, 90602 frames, score 1, max score 3
# Completed 307 games, 398 rewards, 90856 frames, score 0, max score 3
# Completed 308 games, 400 rewards, 91339 frames, score 1, max score 3
# Completed 309 games, 401 rewards, 91547 frames, score 0, max score 3
# Completed 310 games, 402 rewards, 91801 frames, score 0, max score 3
# Completed 311 games, 403 rewards, 92009 frames, score 0, max score 3
# Completed 312 games, 404 rewards, 92190 frames, score 0, max score 3
# Completed 313 games, 406 rewards, 92588 frames, score 1, max score 3
# Completed 314 games, 407 rewards, 92769 frames, score 0, max score 3
# Completed 315 games, 408 rewards, 93023 frames, score 0, max score 3
# Completed 316 games, 409 rewards, 93204 frames, score 0, max score 3
# Completed 317 games, 412 rewards, 93837 frames, score 2, max score 3
# Completed 318 games, 413 rewards, 94045 frames, score 0, max score 3
# Completed 319 games, 415 rewards, 94412 frames, score 1, max score 3
# Completed 320 games, 417 rewards, 94924 frames, score 1, max score 3
# Completed 321 games, 419 rewards, 95307 frames, score 1, max score 3
# Completed 322 games, 420 rewards, 95488 frames, score 0, max score 3
# Completed 323 games, 421 rewards, 95696 frames, score 0, max score 3
# Completed 324 games, 422 rewards, 95904 frames, score 0, max score 3
# Completed 325 games, 423 rewards, 96112 frames, score 0, max score 3
# Completed 326 games, 424 rewards, 96293 frames, score 0, max score 3
# Completed 327 games, 427 rewards, 97000 frames, score 2, max score 3
# Completed 328 games, 428 rewards, 97254 frames, score 0, max score 3
# Completed 329 games, 430 rewards, 97600 frames, score 1, max score 3
# Completed 330 games, 431 rewards, 97781 frames, score 0, max score 3
# Completed 331 games, 432 rewards, 98035 frames, score 0, max score 3
# Completed 332 games, 433 rewards, 98243 frames, score 0, max score 3
# Completed 333 games, 434 rewards, 98497 frames, score 0, max score 3
# Completed 334 games, 435 rewards, 98678 frames, score 0, max score 3
# Completed 335 games, 437 rewards, 99061 frames, score 1, max score 3
# Completed 336 games, 438 rewards, 99269 frames, score 0, max score 3
# Completed 337 games, 439 rewards, 99523 frames, score 0, max score 3
# Completed 338 games, 442 rewards, 100477 frames, score 2, max score 3
# Completed 339 games, 443 rewards, 100658 frames, score 0, max score 3
# Completed 340 games, 444 rewards, 100912 frames, score 0, max score 3
# Completed 341 games, 445 rewards, 101166 frames, score 0, max score 3
# Completed 342 games, 447 rewards, 101828 frames, score 1, max score 3
# Completed 343 games, 448 rewards, 102082 frames, score 0, max score 3
# Completed 344 games, 449 rewards, 102336 frames, score 0, max score 3
# Completed 345 games, 450 rewards, 102544 frames, score 0, max score 3
# Completed 346 games, 451 rewards, 102725 frames, score 0, max score 3
# Completed 347 games, 453 rewards, 103162 frames, score 1, max score 3
# Completed 348 games, 455 rewards, 103533 frames, score 1, max score 3
# Completed 349 games, 456 rewards, 103714 frames, score 0, max score 3
# Completed 350 games, 457 rewards, 103968 frames, score 0, max score 3
# Completed 351 games, 458 rewards, 104222 frames, score 0, max score 3
# Completed 352 games, 459 rewards, 104476 frames, score 0, max score 3
# Completed 353 games, 460 rewards, 104657 frames, score 0, max score 3
# Completed 354 games, 461 rewards, 104865 frames, score 0, max score 3
# Completed 355 games, 462 rewards, 105046 frames, score 0, max score 3
# Completed 356 games, 463 rewards, 105254 frames, score 0, max score 3
# Completed 357 games, 464 rewards, 105462 frames, score 0, max score 3
# Completed 358 games, 465 rewards, 105716 frames, score 0, max score 3
# Completed 359 games, 467 rewards, 106084 frames, score 1, max score 3
# Completed 360 games, 468 rewards, 106292 frames, score 0, max score 3
# Completed 361 games, 471 rewards, 106984 frames, score 2, max score 3
# Completed 362 games, 472 rewards, 107165 frames, score 0, max score 3
# Completed 363 games, 473 rewards, 107419 frames, score 0, max score 3
# Completed 364 games, 475 rewards, 107856 frames, score 1, max score 3
# Completed 365 games, 478 rewards, 108737 frames, score 2, max score 3
# Completed 366 games, 479 rewards, 108945 frames, score 0, max score 3
# Completed 367 games, 480 rewards, 109126 frames, score 0, max score 3
# Completed 368 games, 481 rewards, 109380 frames, score 0, max score 3
# Completed 369 games, 482 rewards, 109634 frames, score 0, max score 3
# Completed 370 games, 483 rewards, 109842 frames, score 0, max score 3
# Completed 371 games, 484 rewards, 110096 frames, score 0, max score 3
# Completed 372 games, 485 rewards, 110304 frames, score 0, max score 3
# Completed 373 games, 486 rewards, 110485 frames, score 0, max score 3
# Completed 374 games, 487 rewards, 110666 frames, score 0, max score 3
# Completed 375 games, 488 rewards, 110920 frames, score 0, max score 3
# Completed 376 games, 490 rewards, 111496 frames, score 1, max score 3
# Completed 377 games, 491 rewards, 111677 frames, score 0, max score 3
# Completed 378 games, 492 rewards, 111858 frames, score 0, max score 3
# Completed 379 games, 493 rewards, 112039 frames, score 0, max score 3
# Completed 380 games, 494 rewards, 112293 frames, score 0, max score 3
# Completed 381 games, 495 rewards, 112501 frames, score 0, max score 3
# Completed 382 games, 497 rewards, 113035 frames, score 1, max score 3
# Completed 383 games, 498 rewards, 113216 frames, score 0, max score 3
# Completed 384 games, 499 rewards, 113397 frames, score 0, max score 3
# Completed 385 games, 500 rewards, 113605 frames, score 0, max score 3
# The number of games played was 387
# The number of rewards was 500
# The size of each returned Q-matrix was (4000, 3)

# %% [markdown]
# The returned value of `q_states` is a list of 4000x3 numpy arrays (20 states, 3 actions).  The list contains `m_rewards` of these. We want to convert it into something that matplotlib can plot.

# %%
import numpy as np

Q = np.array([np.reshape(q,-1) for q in q_states])
print('Q is now of shape',Q.shape)
print('the max absolute value of Q is ',np.amax(abs(Q)))
# Out:
# Q is now of shape (500, 12000)
# the max absolute value of Q is  0.5

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(14,6),layout='tight')
ax = [ fig.add_subplot(2,1,x) for x in range(1,3) ]
ax[0].plot(np.arange(0,len(q_states)),Q)
ax[0].set_title('Q values of all states')
ax[1].plot(np.arange(0,len(q_states)),q_achieved)
ax[1].set_title('Q values of state achieved at each time')
ax[1].set_ylabel('Reward number')
# Out:
# Text(0, 0.5, 'Reward number')

# %% [markdown]
# OK, now let's try running it for a much longer period -- say, 5000 complete games.  We won't ask it to print out any states this time.

# %%
scores, q_achieved, q_states = pong_game.run(m_games=5000, states=[])

print('The number of games played was',len(scores))
print('The number of video frames was',len(q_states))
print('The size of each returned Q-matrix was',q_states[0].shape)
# Out:
# Completed 0 games, 1 rewards, 182 frames, score 0, max score 3
# Completed 1 games, 3 rewards, 580 frames, score 1, max score 3
# Completed 2 games, 4 rewards, 834 frames, score 0, max score 3
# Completed 3 games, 5 rewards, 1088 frames, score 0, max score 3
# Completed 4 games, 6 rewards, 1269 frames, score 0, max score 3
# Completed 5 games, 7 rewards, 1477 frames, score 0, max score 3
# Completed 6 games, 8 rewards, 1731 frames, score 0, max score 3
# Completed 7 games, 9 rewards, 1912 frames, score 0, max score 3
# Completed 8 games, 10 rewards, 2166 frames, score 0, max score 3
# Completed 9 games, 11 rewards, 2374 frames, score 0, max score 3
# Completed 10 games, 12 rewards, 2582 frames, score 0, max score 3
# Completed 11 games, 13 rewards, 2763 frames, score 0, max score 3
# Completed 12 games, 15 rewards, 3425 frames, score 1, max score 3
# Completed 13 games, 16 rewards, 3679 frames, score 0, max score 3
# Completed 14 games, 17 rewards, 3860 frames, score 0, max score 3
# Completed 15 games, 18 rewards, 4068 frames, score 0, max score 3
# Completed 16 games, 19 rewards, 4249 frames, score 0, max score 3
# Completed 17 games, 21 rewards, 4599 frames, score 1, max score 3
# Completed 18 games, 22 rewards, 4807 frames, score 0, max score 3
# Completed 19 games, 24 rewards, 5159 frames, score 1, max score 3
# Completed 20 games, 26 rewards, 5593 frames, score 1, max score 3
# Completed 21 games, 27 rewards, 5801 frames, score 0, max score 3
# Completed 22 games, 28 rewards, 5982 frames, score 0, max score 3
# Completed 23 games, 29 rewards, 6163 frames, score 0, max score 3
# Completed 24 games, 30 rewards, 6344 frames, score 0, max score 3
# Completed 25 games, 32 rewards, 6696 frames, score 1, max score 3
# Completed 26 games, 37 rewards, 7882 frames, score 4, max score 4
# Completed 27 games, 38 rewards, 8090 frames, score 0, max score 4
# Completed 28 games, 39 rewards, 8271 frames, score 0, max score 4
# Completed 29 games, 41 rewards, 8768 frames, score 1, max score 4
# Completed 30 games, 42 rewards, 8949 frames, score 0, max score 4
# Completed 31 games, 44 rewards, 9316 frames, score 1, max score 4
# Completed 32 games, 45 rewards, 9570 frames, score 0, max score 4
# Completed 33 games, 47 rewards, 9975 frames, score 1, max score 4
# Completed 34 games, 48 rewards, 10229 frames, score 0, max score 4
# Completed 35 games, 49 rewards, 10410 frames, score 0, max score 4
# Completed 36 games, 51 rewards, 11072 frames, score 1, max score 4
# Completed 37 games, 52 rewards, 11253 frames, score 0, max score 4
# Completed 38 games, 54 rewards, 11594 frames, score 1, max score 4
# Completed 39 games, 56 rewards, 12196 frames, score 1, max score 4
# Completed 40 games, 57 rewards, 12377 frames, score 0, max score 4
# Completed 41 games, 58 rewards, 12558 frames, score 0, max score 4
# Completed 42 games, 60 rewards, 12974 frames, score 1, max score 4
# Completed 43 games, 61 rewards, 13182 frames, score 0, max score 4
# Completed 44 games, 62 rewards, 13363 frames, score 0, max score 4
# Completed 45 games, 63 rewards, 13617 frames, score 0, max score 4
# Completed 46 games, 64 rewards, 13825 frames, score 0, max score 4
# Completed 47 games, 65 rewards, 14006 frames, score 0, max score 4
# Completed 48 games, 66 rewards, 14260 frames, score 0, max score 4
# Completed 49 games, 67 rewards, 14468 frames, score 0, max score 4
# Completed 50 games, 68 rewards, 14722 frames, score 0, max score 4
# Completed 51 games, 69 rewards, 14976 frames, score 0, max score 4
# Completed 52 games, 71 rewards, 15473 frames, score 1, max score 4
# Completed 53 games, 72 rewards, 15654 frames, score 0, max score 4
# Completed 54 games, 73 rewards, 15862 frames, score 0, max score 4
# Completed 55 games, 74 rewards, 16070 frames, score 0, max score 4
# Completed 56 games, 75 rewards, 16278 frames, score 0, max score 4
# Completed 57 games, 76 rewards, 16486 frames, score 0, max score 4
# Completed 58 games, 79 rewards, 17110 frames, score 2, max score 4
# Completed 59 games, 81 rewards, 17515 frames, score 1, max score 4
# Completed 60 games, 82 rewards, 17696 frames, score 0, max score 4
# Completed 61 games, 83 rewards, 17950 frames, score 0, max score 4
# Completed 62 games, 84 rewards, 18131 frames, score 0, max score 4
# Completed 63 games, 86 rewards, 18498 frames, score 1, max score 4
# Completed 64 games, 89 rewards, 19180 frames, score 2, max score 4
# Completed 65 games, 90 rewards, 19388 frames, score 0, max score 4
# Completed 66 games, 92 rewards, 20050 frames, score 1, max score 4
# Completed 67 games, 93 rewards, 20258 frames, score 0, max score 4
# Completed 68 games, 95 rewards, 20809 frames, score 1, max score 4
# Completed 69 games, 96 rewards, 21063 frames, score 0, max score 4
# Completed 70 games, 97 rewards, 21271 frames, score 0, max score 4
# Completed 71 games, 98 rewards, 21452 frames, score 0, max score 4
# Completed 72 games, 99 rewards, 21660 frames, score 0, max score 4
# Completed 73 games, 100 rewards, 21914 frames, score 0, max score 4
# Completed 74 games, 101 rewards, 22122 frames, score 0, max score 4
# Completed 75 games, 104 rewards, 22867 frames, score 2, max score 4
# Completed 76 games, 106 rewards, 23786 frames, score 1, max score 4
# Completed 77 games, 108 rewards, 24127 frames, score 1, max score 4
# Completed 78 games, 109 rewards, 24335 frames, score 0, max score 4
# Completed 79 games, 111 rewards, 24795 frames, score 1, max score 4
# Completed 80 games, 114 rewards, 25397 frames, score 2, max score 4
# Completed 81 games, 116 rewards, 26059 frames, score 1, max score 4
# Completed 82 games, 117 rewards, 26267 frames, score 0, max score 4
# Completed 83 games, 120 rewards, 27067 frames, score 2, max score 4
# Completed 84 games, 121 rewards, 27275 frames, score 0, max score 4
# Completed 85 games, 122 rewards, 27483 frames, score 0, max score 4
# Completed 86 games, 124 rewards, 28073 frames, score 1, max score 4
# Completed 87 games, 125 rewards, 28281 frames, score 0, max score 4
# Completed 88 games, 126 rewards, 28535 frames, score 0, max score 4
# Completed 89 games, 127 rewards, 28716 frames, score 0, max score 4
# Completed 90 games, 128 rewards, 28897 frames, score 0, max score 4
# Completed 91 games, 129 rewards, 29151 frames, score 0, max score 4
# Completed 92 games, 130 rewards, 29359 frames, score 0, max score 4
# Completed 93 games, 131 rewards, 29613 frames, score 0, max score 4
# Completed 94 games, 132 rewards, 29821 frames, score 0, max score 4
# Completed 95 games, 133 rewards, 30029 frames, score 0, max score 4
# Completed 96 games, 134 rewards, 30237 frames, score 0, max score 4
# Completed 97 games, 135 rewards, 30491 frames, score 0, max score 4
# Completed 98 games, 137 rewards, 31225 frames, score 1, max score 4
# Completed 99 games, 139 rewards, 31873 frames, score 1, max score 4
# Completed 100 games, 140 rewards, 32127 frames, score 0, max score 4
# Completed 101 games, 141 rewards, 32381 frames, score 0, max score 4
# Completed 102 games, 145 rewards, 33254 frames, score 3, max score 4
# Completed 103 games, 146 rewards, 33435 frames, score 0, max score 4
# Completed 104 games, 147 rewards, 33689 frames, score 0, max score 4
# Completed 105 games, 154 rewards, 35114 frames, score 6, max score 6
# Completed 106 games, 155 rewards, 35322 frames, score 0, max score 6
# Completed 107 games, 156 rewards, 35576 frames, score 0, max score 6
# Completed 108 games, 157 rewards, 35784 frames, score 0, max score 6
# Completed 109 games, 158 rewards, 35965 frames, score 0, max score 6
# Completed 110 games, 159 rewards, 36146 frames, score 0, max score 6
# Completed 111 games, 160 rewards, 36354 frames, score 0, max score 6
# Completed 112 games, 161 rewards, 36608 frames, score 0, max score 6
# Completed 113 games, 162 rewards, 36862 frames, score 0, max score 6
# Completed 114 games, 164 rewards, 37596 frames, score 1, max score 6
# Completed 115 games, 165 rewards, 37850 frames, score 0, max score 6
# Completed 116 games, 166 rewards, 38058 frames, score 0, max score 6
# Completed 117 games, 168 rewards, 38792 frames, score 1, max score 6
# Completed 118 games, 169 rewards, 38973 frames, score 0, max score 6
# Completed 119 games, 170 rewards, 39181 frames, score 0, max score 6
# Completed 120 games, 173 rewards, 40627 frames, score 2, max score 6
# Completed 121 games, 175 rewards, 40979 frames, score 1, max score 6
# Completed 122 games, 176 rewards, 41187 frames, score 0, max score 6
# Completed 123 games, 177 rewards, 41395 frames, score 0, max score 6
# Completed 124 games, 178 rewards, 41649 frames, score 0, max score 6
# Completed 125 games, 180 rewards, 42200 frames, score 1, max score 6
# Completed 126 games, 181 rewards, 42454 frames, score 0, max score 6
# Completed 127 games, 183 rewards, 42910 frames, score 1, max score 6
# Completed 128 games, 184 rewards, 43164 frames, score 0, max score 6
# Completed 129 games, 185 rewards, 43372 frames, score 0, max score 6
# Completed 130 games, 190 rewards, 45912 frames, score 4, max score 6
# Completed 131 games, 192 rewards, 46375 frames, score 1, max score 6
# Completed 132 games, 193 rewards, 46556 frames, score 0, max score 6
# Completed 133 games, 195 rewards, 46984 frames, score 1, max score 6
# Completed 134 games, 196 rewards, 47238 frames, score 0, max score 6
# Completed 135 games, 197 rewards, 47419 frames, score 0, max score 6
# Completed 136 games, 198 rewards, 47673 frames, score 0, max score 6
# Completed 137 games, 199 rewards, 47881 frames, score 0, max score 6
# Completed 138 games, 200 rewards, 48089 frames, score 0, max score 6
# Completed 139 games, 201 rewards, 48343 frames, score 0, max score 6
# Completed 140 games, 203 rewards, 48734 frames, score 1, max score 6
# Completed 141 games, 204 rewards, 48915 frames, score 0, max score 6
# Completed 142 games, 205 rewards, 49096 frames, score 0, max score 6
# Completed 143 games, 206 rewards, 49277 frames, score 0, max score 6
# Completed 144 games, 207 rewards, 49458 frames, score 0, max score 6
# Completed 145 games, 208 rewards, 49639 frames, score 0, max score 6
# Completed 146 games, 210 rewards, 50045 frames, score 1, max score 6
# Completed 147 games, 212 rewards, 50542 frames, score 1, max score 6
# Completed 148 games, 213 rewards, 50796 frames, score 0, max score 6
# Completed 149 games, 214 rewards, 51050 frames, score 0, max score 6
# Completed 150 games, 215 rewards, 51258 frames, score 0, max score 6
# Completed 151 games, 216 rewards, 51466 frames, score 0, max score 6
# Completed 152 games, 220 rewards, 52784 frames, score 3, max score 6
# Completed 153 games, 221 rewards, 52965 frames, score 0, max score 6
# Completed 154 games, 222 rewards, 53219 frames, score 0, max score 6
# Completed 155 games, 223 rewards, 53400 frames, score 0, max score 6
# Completed 156 games, 228 rewards, 54659 frames, score 4, max score 6
# Completed 157 games, 229 rewards, 54840 frames, score 0, max score 6
# Completed 158 games, 230 rewards, 55048 frames, score 0, max score 6
# Completed 159 games, 233 rewards, 55771 frames, score 2, max score 6
# Completed 160 games, 234 rewards, 55979 frames, score 0, max score 6
# Completed 161 games, 235 rewards, 56233 frames, score 0, max score 6
# Completed 162 games, 237 rewards, 57152 frames, score 1, max score 6
# Completed 163 games, 238 rewards, 57406 frames, score 0, max score 6
# Completed 164 games, 243 rewards, 58515 frames, score 4, max score 6
# Completed 165 games, 245 rewards, 58867 frames, score 1, max score 6
# Completed 166 games, 246 rewards, 59075 frames, score 0, max score 6
# Completed 167 games, 247 rewards, 59256 frames, score 0, max score 6
# Completed 168 games, 248 rewards, 59510 frames, score 0, max score 6
# Completed 169 games, 250 rewards, 59921 frames, score 1, max score 6
# Completed 170 games, 251 rewards, 60175 frames, score 0, max score 6
# Completed 171 games, 252 rewards, 60383 frames, score 0, max score 6
# Completed 172 games, 253 rewards, 60637 frames, score 0, max score 6
# Completed 173 games, 254 rewards, 60818 frames, score 0, max score 6
# Completed 174 games, 255 rewards, 61072 frames, score 0, max score 6
# Completed 175 games, 256 rewards, 61253 frames, score 0, max score 6
# Completed 176 games, 257 rewards, 61461 frames, score 0, max score 6
# Completed 177 games, 258 rewards, 61669 frames, score 0, max score 6
# Completed 178 games, 259 rewards, 61850 frames, score 0, max score 6
# Completed 179 games, 260 rewards, 62058 frames, score 0, max score 6
# Completed 180 games, 264 rewards, 62959 frames, score 3, max score 6
# Completed 181 games, 266 rewards, 63342 frames, score 1, max score 6
# Completed 182 games, 267 rewards, 63550 frames, score 0, max score 6
# Completed 183 games, 270 rewards, 64257 frames, score 2, max score 6
# Completed 184 games, 274 rewards, 64826 frames, score 3, max score 6
# Completed 185 games, 275 rewards, 65007 frames, score 0, max score 6
# Completed 186 games, 276 rewards, 65215 frames, score 0, max score 6
# Completed 187 games, 277 rewards, 65423 frames, score 0, max score 6
# Completed 188 games, 278 rewards, 65677 frames, score 0, max score 6
# Completed 189 games, 279 rewards, 65858 frames, score 0, max score 6
# Completed 190 games, 280 rewards, 66112 frames, score 0, max score 6
# Completed 191 games, 281 rewards, 66293 frames, score 0, max score 6
# Completed 192 games, 282 rewards, 66547 frames, score 0, max score 6
# Completed 193 games, 283 rewards, 66801 frames, score 0, max score 6
# Completed 194 games, 284 rewards, 67009 frames, score 0, max score 6
# Completed 195 games, 286 rewards, 67560 frames, score 1, max score 6
# Completed 196 games, 287 rewards, 67741 frames, score 0, max score 6
# Completed 197 games, 288 rewards, 67995 frames, score 0, max score 6
# Completed 198 games, 289 rewards, 68176 frames, score 0, max score 6
# Completed 199 games, 290 rewards, 68357 frames, score 0, max score 6
# Completed 200 games, 291 rewards, 68565 frames, score 0, max score 6
# Completed 201 games, 292 rewards, 68746 frames, score 0, max score 6
# Completed 202 games, 294 rewards, 69408 frames, score 1, max score 6
# Completed 203 games, 295 rewards, 69589 frames, score 0, max score 6
# Completed 204 games, 296 rewards, 69770 frames, score 0, max score 6
# Completed 205 games, 297 rewards, 70024 frames, score 0, max score 6
# Completed 206 games, 299 rewards, 70429 frames, score 1, max score 6
# Completed 207 games, 300 rewards, 70610 frames, score 0, max score 6
# Completed 208 games, 301 rewards, 70791 frames, score 0, max score 6
# Completed 209 games, 302 rewards, 70999 frames, score 0, max score 6
# Completed 210 games, 305 rewards, 71544 frames, score 2, max score 6
# Completed 211 games, 306 rewards, 71725 frames, score 0, max score 6
# Completed 212 games, 307 rewards, 71933 frames, score 0, max score 6
# Completed 213 games, 309 rewards, 72430 frames, score 1, max score 6
# Completed 214 games, 310 rewards, 72684 frames, score 0, max score 6
# Completed 215 games, 311 rewards, 72892 frames, score 0, max score 6
# Completed 216 games, 312 rewards, 73146 frames, score 0, max score 6
# Completed 217 games, 313 rewards, 73354 frames, score 0, max score 6
# Completed 218 games, 314 rewards, 73535 frames, score 0, max score 6
# Completed 219 games, 316 rewards, 73922 frames, score 1, max score 6
# Completed 220 games, 317 rewards, 74176 frames, score 0, max score 6
# Completed 221 games, 318 rewards, 74357 frames, score 0, max score 6
# Completed 222 games, 319 rewards, 74565 frames, score 0, max score 6
# Completed 223 games, 320 rewards, 74819 frames, score 0, max score 6
# Completed 224 games, 321 rewards, 75027 frames, score 0, max score 6
# Completed 225 games, 322 rewards, 75208 frames, score 0, max score 6
# Completed 226 games, 323 rewards, 75416 frames, score 0, max score 6
# Completed 227 games, 324 rewards, 75624 frames, score 0, max score 6
# Completed 228 games, 325 rewards, 75878 frames, score 0, max score 6
# Completed 229 games, 326 rewards, 76132 frames, score 0, max score 6
# Completed 230 games, 328 rewards, 76620 frames, score 1, max score 6
# Completed 231 games, 329 rewards, 76874 frames, score 0, max score 6
# Completed 232 games, 330 rewards, 77128 frames, score 0, max score 6
# Completed 233 games, 331 rewards, 77336 frames, score 0, max score 6
# Completed 234 games, 332 rewards, 77544 frames, score 0, max score 6
# Completed 235 games, 333 rewards, 77725 frames, score 0, max score 6
# Completed 236 games, 336 rewards, 79039 frames, score 2, max score 6
# Completed 237 games, 337 rewards, 79220 frames, score 0, max score 6
# Completed 238 games, 338 rewards, 79428 frames, score 0, max score 6
# Completed 239 games, 339 rewards, 79636 frames, score 0, max score 6
# Completed 240 games, 340 rewards, 79817 frames, score 0, max score 6
# Completed 241 games, 341 rewards, 80025 frames, score 0, max score 6
# Completed 242 games, 342 rewards, 80206 frames, score 0, max score 6
# Completed 243 games, 344 rewards, 80669 frames, score 1, max score 6
# Completed 244 games, 346 rewards, 81166 frames, score 1, max score 6
# Completed 245 games, 347 rewards, 81347 frames, score 0, max score 6
# Completed 246 games, 348 rewards, 81555 frames, score 0, max score 6
# Completed 247 games, 350 rewards, 81965 frames, score 1, max score 6
# Completed 248 games, 351 rewards, 82219 frames, score 0, max score 6
# Completed 249 games, 352 rewards, 82473 frames, score 0, max score 6
# Completed 250 games, 353 rewards, 82727 frames, score 0, max score 6
# Completed 251 games, 355 rewards, 83095 frames, score 1, max score 6
# Completed 252 games, 358 rewards, 84670 frames, score 2, max score 6
# Completed 253 games, 360 rewards, 85035 frames, score 1, max score 6
# Completed 254 games, 361 rewards, 85216 frames, score 0, max score 6
# Completed 255 games, 362 rewards, 85470 frames, score 0, max score 6
# Completed 256 games, 363 rewards, 85651 frames, score 0, max score 6
# Completed 257 games, 365 rewards, 86253 frames, score 1, max score 6
# Completed 258 games, 367 rewards, 86690 frames, score 1, max score 6
# Completed 259 games, 368 rewards, 86944 frames, score 0, max score 6
# Completed 260 games, 370 rewards, 87441 frames, score 1, max score 6
# Completed 261 games, 371 rewards, 87695 frames, score 0, max score 6
# Completed 262 games, 372 rewards, 87876 frames, score 0, max score 6
# Completed 263 games, 373 rewards, 88084 frames, score 0, max score 6
# Completed 264 games, 374 rewards, 88292 frames, score 0, max score 6
# Completed 265 games, 375 rewards, 88473 frames, score 0, max score 6
# Completed 266 games, 377 rewards, 88856 frames, score 1, max score 6
# Completed 267 games, 378 rewards, 89037 frames, score 0, max score 6
# Completed 268 games, 379 rewards, 89218 frames, score 0, max score 6
# Completed 269 games, 380 rewards, 89426 frames, score 0, max score 6
# Completed 270 games, 382 rewards, 89938 frames, score 1, max score 6
# Completed 271 games, 383 rewards, 90119 frames, score 0, max score 6
# Completed 272 games, 384 rewards, 90327 frames, score 0, max score 6
# Completed 273 games, 385 rewards, 90508 frames, score 0, max score 6
# Completed 274 games, 386 rewards, 90716 frames, score 0, max score 6
# Completed 275 games, 387 rewards, 90924 frames, score 0, max score 6
# Completed 276 games, 388 rewards, 91132 frames, score 0, max score 6
# Completed 277 games, 389 rewards, 91313 frames, score 0, max score 6
# Completed 278 games, 391 rewards, 91810 frames, score 1, max score 6
# Completed 279 games, 394 rewards, 92373 frames, score 2, max score 6
# Completed 280 games, 395 rewards, 92581 frames, score 0, max score 6
# Completed 281 games, 396 rewards, 92835 frames, score 0, max score 6
# Completed 282 games, 398 rewards, 93249 frames, score 1, max score 6
# Completed 283 games, 399 rewards, 93503 frames, score 0, max score 6
# Completed 284 games, 400 rewards, 93757 frames, score 0, max score 6
# Completed 285 games, 401 rewards, 93965 frames, score 0, max score 6
# Completed 286 games, 403 rewards, 94884 frames, score 1, max score 6
# Completed 287 games, 404 rewards, 95138 frames, score 0, max score 6
# Completed 288 games, 405 rewards, 95392 frames, score 0, max score 6
# Completed 289 games, 406 rewards, 95646 frames, score 0, max score 6
# Completed 290 games, 407 rewards, 95827 frames, score 0, max score 6
# Completed 291 games, 408 rewards, 96008 frames, score 0, max score 6
# Completed 292 games, 410 rewards, 96479 frames, score 1, max score 6
# Completed 293 games, 411 rewards, 96660 frames, score 0, max score 6
# Completed 294 games, 413 rewards, 97123 frames, score 1, max score 6
# Completed 295 games, 414 rewards, 97377 frames, score 0, max score 6
# Completed 296 games, 415 rewards, 97585 frames, score 0, max score 6
# Completed 297 games, 416 rewards, 97766 frames, score 0, max score 6
# Completed 298 games, 417 rewards, 97974 frames, score 0, max score 6
# Completed 299 games, 418 rewards, 98155 frames, score 0, max score 6
# Completed 300 games, 419 rewards, 98409 frames, score 0, max score 6
# Completed 301 games, 420 rewards, 98590 frames, score 0, max score 6
# Completed 302 games, 422 rewards, 99252 frames, score 1, max score 6
# Completed 303 games, 423 rewards, 99460 frames, score 0, max score 6
# Completed 304 games, 424 rewards, 99714 frames, score 0, max score 6
# Completed 305 games, 425 rewards, 99968 frames, score 0, max score 6
# Completed 306 games, 426 rewards, 100176 frames, score 0, max score 6
# Completed 307 games, 427 rewards, 100430 frames, score 0, max score 6
# Completed 308 games, 428 rewards, 100684 frames, score 0, max score 6
# Completed 309 games, 429 rewards, 100892 frames, score 0, max score 6
# Completed 310 games, 430 rewards, 101073 frames, score 0, max score 6
# Completed 311 games, 431 rewards, 101254 frames, score 0, max score 6
# Completed 312 games, 432 rewards, 101462 frames, score 0, max score 6
# Completed 313 games, 434 rewards, 101996 frames, score 1, max score 6
# Completed 314 games, 435 rewards, 102250 frames, score 0, max score 6
# Completed 315 games, 436 rewards, 102458 frames, score 0, max score 6
# Completed 316 games, 438 rewards, 102640 frames, score 1, max score 6
# Completed 317 games, 439 rewards, 102894 frames, score 0, max score 6
# Completed 318 games, 440 rewards, 103075 frames, score 0, max score 6
# Completed 319 games, 441 rewards, 103329 frames, score 0, max score 6
# Completed 320 games, 443 rewards, 103841 frames, score 1, max score 6
# Completed 321 games, 444 rewards, 104049 frames, score 0, max score 6
# Completed 322 games, 447 rewards, 105014 frames, score 2, max score 6
# Completed 323 games, 448 rewards, 105195 frames, score 0, max score 6
# Completed 324 games, 453 rewards, 106137 frames, score 4, max score 6
# Completed 325 games, 454 rewards, 106318 frames, score 0, max score 6
# Completed 326 games, 456 rewards, 106686 frames, score 1, max score 6
# Completed 327 games, 457 rewards, 106894 frames, score 0, max score 6
# Completed 328 games, 458 rewards, 107102 frames, score 0, max score 6
# Completed 329 games, 459 rewards, 107356 frames, score 0, max score 6
# Completed 330 games, 460 rewards, 107564 frames, score 0, max score 6
# Completed 331 games, 461 rewards, 107772 frames, score 0, max score 6
# Completed 332 games, 462 rewards, 107980 frames, score 0, max score 6
# Completed 333 games, 463 rewards, 108161 frames, score 0, max score 6
# Completed 334 games, 464 rewards, 108369 frames, score 0, max score 6
# Completed 335 games, 467 rewards, 109470 frames, score 2, max score 6
# Completed 336 games, 468 rewards, 109724 frames, score 0, max score 6
# Completed 337 games, 470 rewards, 110161 frames, score 1, max score 6
# Completed 338 games, 471 rewards, 110342 frames, score 0, max score 6
# Completed 339 games, 473 rewards, 110756 frames, score 1, max score 6
# Completed 340 games, 475 rewards, 111268 frames, score 1, max score 6
# Completed 341 games, 477 rewards, 111819 frames, score 1, max score 6
# Completed 342 games, 478 rewards, 112027 frames, score 0, max score 6
# Completed 343 games, 479 rewards, 112235 frames, score 0, max score 6
# Completed 344 games, 480 rewards, 112443 frames, score 0, max score 6
# Completed 345 games, 481 rewards, 112697 frames, score 0, max score 6
# Completed 346 games, 482 rewards, 112878 frames, score 0, max score 6
# Completed 347 games, 483 rewards, 113132 frames, score 0, max score 6
# Completed 348 games, 484 rewards, 113313 frames, score 0, max score 6
# Completed 349 games, 485 rewards, 113521 frames, score 0, max score 6
# Completed 350 games, 487 rewards, 114183 frames, score 1, max score 6
# Completed 351 games, 489 rewards, 114566 frames, score 1, max score 6
# Completed 352 games, 490 rewards, 114747 frames, score 0, max score 6
# Completed 353 games, 491 rewards, 114928 frames, score 0, max score 6
# Completed 354 games, 492 rewards, 115136 frames, score 0, max score 6
# Completed 355 games, 493 rewards, 115390 frames, score 0, max score 6
# Completed 356 games, 494 rewards, 115644 frames, score 0, max score 6
# Completed 357 games, 496 rewards, 115985 frames, score 1, max score 6
# Completed 358 games, 497 rewards, 116239 frames, score 0, max score 6
# Completed 359 games, 499 rewards, 116637 frames, score 1, max score 6
# Completed 360 games, 501 rewards, 117108 frames, score 1, max score 6
# Completed 361 games, 502 rewards, 117289 frames, score 0, max score 6
# Completed 362 games, 503 rewards, 117543 frames, score 0, max score 6
# Completed 363 games, 504 rewards, 117797 frames, score 0, max score 6
# Completed 364 games, 505 rewards, 118005 frames, score 0, max score 6
# Completed 365 games, 506 rewards, 118213 frames, score 0, max score 6
# Completed 366 games, 508 rewards, 118747 frames, score 1, max score 6
# Completed 367 games, 509 rewards, 118955 frames, score 0, max score 6
# Completed 368 games, 510 rewards, 119136 frames, score 0, max score 6
# Completed 369 games, 511 rewards, 119344 frames, score 0, max score 6
# Completed 370 games, 512 rewards, 119552 frames, score 0, max score 6
# Completed 371 games, 513 rewards, 119760 frames, score 0, max score 6
# Completed 372 games, 514 rewards, 120014 frames, score 0, max score 6
# Completed 373 games, 515 rewards, 120268 frames, score 0, max score 6
# Completed 374 games, 521 rewards, 121685 frames, score 5, max score 6
# Completed 375 games, 522 rewards, 121893 frames, score 0, max score 6
# Completed 376 games, 524 rewards, 122427 frames, score 1, max score 6
# Completed 377 games, 526 rewards, 122978 frames, score 1, max score 6
# Completed 378 games, 529 rewards, 123815 frames, score 2, max score 6
# Completed 379 games, 530 rewards, 124069 frames, score 0, max score 6
# Completed 380 games, 531 rewards, 124277 frames, score 0, max score 6
# Completed 381 games, 532 rewards, 124531 frames, score 0, max score 6
# Completed 382 games, 533 rewards, 124739 frames, score 0, max score 6
# Completed 383 games, 534 rewards, 124920 frames, score 0, max score 6
# Completed 384 games, 536 rewards, 125582 frames, score 1, max score 6
# Completed 385 games, 538 rewards, 125943 frames, score 1, max score 6
# Completed 386 games, 539 rewards, 126197 frames, score 0, max score 6
# Completed 387 games, 540 rewards, 126378 frames, score 0, max score 6
# Completed 388 games, 541 rewards, 126559 frames, score 0, max score 6
# Completed 389 games, 542 rewards, 126813 frames, score 0, max score 6
# Completed 390 games, 543 rewards, 127067 frames, score 0, max score 6
# Completed 391 games, 544 rewards, 127248 frames, score 0, max score 6
# Completed 392 games, 547 rewards, 127859 frames, score 2, max score 6
# Completed 393 games, 548 rewards, 128040 frames, score 0, max score 6
# Completed 394 games, 550 rewards, 128408 frames, score 1, max score 6
# Completed 395 games, 552 rewards, 128920 frames, score 1, max score 6
# Completed 396 games, 553 rewards, 129128 frames, score 0, max score 6
# Completed 397 games, 554 rewards, 129336 frames, score 0, max score 6
# Completed 398 games, 558 rewards, 130154 frames, score 3, max score 6
# Completed 399 games, 559 rewards, 130408 frames, score 0, max score 6
# Completed 400 games, 560 rewards, 130616 frames, score 0, max score 6
# Completed 401 games, 561 rewards, 130870 frames, score 0, max score 6
# Completed 402 games, 563 rewards, 131211 frames, score 1, max score 6
# Completed 403 games, 564 rewards, 131392 frames, score 0, max score 6
# Completed 404 games, 565 rewards, 131573 frames, score 0, max score 6
# Completed 405 games, 566 rewards, 131827 frames, score 0, max score 6
# Completed 406 games, 568 rewards, 132290 frames, score 1, max score 6
# Completed 407 games, 569 rewards, 132471 frames, score 0, max score 6
# Completed 408 games, 570 rewards, 132679 frames, score 0, max score 6
# Completed 409 games, 572 rewards, 133191 frames, score 1, max score 6
# Completed 410 games, 573 rewards, 133399 frames, score 0, max score 6
# Completed 411 games, 574 rewards, 133607 frames, score 0, max score 6
# Completed 412 games, 576 rewards, 134158 frames, score 1, max score 6
# Completed 413 games, 578 rewards, 134760 frames, score 1, max score 6
# Completed 414 games, 579 rewards, 135014 frames, score 0, max score 6
# Completed 415 games, 580 rewards, 135195 frames, score 0, max score 6
# Completed 416 games, 582 rewards, 135797 frames, score 1, max score 6
# Completed 417 games, 584 rewards, 136202 frames, score 1, max score 6
# Completed 418 games, 585 rewards, 136383 frames, score 0, max score 6
# Completed 419 games, 587 rewards, 136880 frames, score 1, max score 6
# Completed 420 games, 589 rewards, 137248 frames, score 1, max score 6
# Completed 421 games, 590 rewards, 137429 frames, score 0, max score 6
# Completed 422 games, 591 rewards, 137683 frames, score 0, max score 6
# Completed 423 games, 595 rewards, 138832 frames, score 3, max score 6
# Completed 424 games, 597 rewards, 139292 frames, score 1, max score 6
# Completed 425 games, 601 rewards, 140044 frames, score 3, max score 6
# Completed 426 games, 602 rewards, 140225 frames, score 0, max score 6
# Completed 427 games, 603 rewards, 140433 frames, score 0, max score 6
# Completed 428 games, 604 rewards, 140641 frames, score 0, max score 6
# Completed 429 games, 605 rewards, 140822 frames, score 0, max score 6
# Completed 430 games, 607 rewards, 141205 frames, score 1, max score 6
# Completed 431 games, 609 rewards, 141610 frames, score 1, max score 6
# Completed 432 games, 610 rewards, 141791 frames, score 0, max score 6
# Completed 433 games, 611 rewards, 141999 frames, score 0, max score 6
# Completed 434 games, 612 rewards, 142207 frames, score 0, max score 6
# Completed 435 games, 613 rewards, 142415 frames, score 0, max score 6
# Completed 436 games, 615 rewards, 142949 frames, score 1, max score 6
# Completed 437 games, 617 rewards, 143332 frames, score 1, max score 6
# Completed 438 games, 619 rewards, 143760 frames, score 1, max score 6
# Completed 439 games, 620 rewards, 143941 frames, score 0, max score 6
# Completed 440 games, 621 rewards, 144149 frames, score 0, max score 6
# Completed 441 games, 622 rewards, 144330 frames, score 0, max score 6
# Completed 442 games, 623 rewards, 144538 frames, score 0, max score 6
# Completed 443 games, 625 rewards, 144879 frames, score 1, max score 6
# Completed 444 games, 626 rewards, 145133 frames, score 0, max score 6
# Completed 445 games, 627 rewards, 145314 frames, score 0, max score 6
# Completed 446 games, 628 rewards, 145495 frames, score 0, max score 6
# Completed 447 games, 630 rewards, 145958 frames, score 1, max score 6
# Completed 448 games, 631 rewards, 146139 frames, score 0, max score 6
# Completed 449 games, 632 rewards, 146347 frames, score 0, max score 6
# Completed 450 games, 633 rewards, 146528 frames, score 0, max score 6
# Completed 451 games, 634 rewards, 146736 frames, score 0, max score 6
# Completed 452 games, 635 rewards, 146944 frames, score 0, max score 6
# Completed 453 games, 636 rewards, 147152 frames, score 0, max score 6
# Completed 454 games, 637 rewards, 147360 frames, score 0, max score 6
# Completed 455 games, 639 rewards, 147728 frames, score 1, max score 6
# Completed 456 games, 640 rewards, 147936 frames, score 0, max score 6
# Completed 457 games, 641 rewards, 148144 frames, score 0, max score 6
# Completed 458 games, 642 rewards, 148325 frames, score 0, max score 6
# Completed 459 games, 643 rewards, 148579 frames, score 0, max score 6
# Completed 460 games, 644 rewards, 148833 frames, score 0, max score 6
# Completed 461 games, 645 rewards, 149087 frames, score 0, max score 6
# Completed 462 games, 646 rewards, 149268 frames, score 0, max score 6
# Completed 463 games, 647 rewards, 149476 frames, score 0, max score 6
# Completed 464 games, 648 rewards, 149684 frames, score 0, max score 6
# Completed 465 games, 649 rewards, 149938 frames, score 0, max score 6
# Completed 466 games, 650 rewards, 150146 frames, score 0, max score 6
# Completed 467 games, 652 rewards, 150574 frames, score 1, max score 6
# Completed 468 games, 654 rewards, 150915 frames, score 1, max score 6
# Completed 469 games, 655 rewards, 151096 frames, score 0, max score 6
# Completed 470 games, 657 rewards, 151593 frames, score 1, max score 6
# Completed 471 games, 658 rewards, 151847 frames, score 0, max score 6
# Completed 472 games, 659 rewards, 152028 frames, score 0, max score 6
# Completed 473 games, 662 rewards, 152508 frames, score 2, max score 6
# Completed 474 games, 663 rewards, 152762 frames, score 0, max score 6
# Completed 475 games, 664 rewards, 152943 frames, score 0, max score 6
# Completed 476 games, 666 rewards, 153326 frames, score 1, max score 6
# Completed 477 games, 667 rewards, 153580 frames, score 0, max score 6
# Completed 478 games, 668 rewards, 153788 frames, score 0, max score 6
# Completed 479 games, 669 rewards, 153996 frames, score 0, max score 6
# Completed 480 games, 670 rewards, 154204 frames, score 0, max score 6
# Completed 481 games, 671 rewards, 154412 frames, score 0, max score 6
# Completed 482 games, 672 rewards, 154593 frames, score 0, max score 6
# Completed 483 games, 675 rewards, 155176 frames, score 2, max score 6
# Completed 484 games, 676 rewards, 155430 frames, score 0, max score 6
# Completed 485 games, 677 rewards, 155638 frames, score 0, max score 6
# Completed 486 games, 678 rewards, 155892 frames, score 0, max score 6
# Completed 487 games, 679 rewards, 156100 frames, score 0, max score 6
# Completed 488 games, 680 rewards, 156281 frames, score 0, max score 6
# Completed 489 games, 681 rewards, 156489 frames, score 0, max score 6
# Completed 490 games, 682 rewards, 156670 frames, score 0, max score 6
# Completed 491 games, 683 rewards, 156878 frames, score 0, max score 6
# Completed 492 games, 684 rewards, 157059 frames, score 0, max score 6
# Completed 493 games, 685 rewards, 157240 frames, score 0, max score 6
# Completed 494 games, 687 rewards, 157608 frames, score 1, max score 6
# Completed 495 games, 689 rewards, 158079 frames, score 1, max score 6
# Completed 496 games, 691 rewards, 158493 frames, score 1, max score 6
# Completed 497 games, 693 rewards, 158930 frames, score 1, max score 6
# Completed 498 games, 694 rewards, 159138 frames, score 0, max score 6
# Completed 499 games, 695 rewards, 159392 frames, score 0, max score 6
# Completed 500 games, 696 rewards, 159600 frames, score 0, max score 6
# Completed 501 games, 698 rewards, 160006 frames, score 1, max score 6
# Completed 502 games, 699 rewards, 160214 frames, score 0, max score 6
# Completed 503 games, 700 rewards, 160422 frames, score 0, max score 6
# Completed 504 games, 701 rewards, 160603 frames, score 0, max score 6
# Completed 505 games, 702 rewards, 160784 frames, score 0, max score 6
# Completed 506 games, 703 rewards, 160992 frames, score 0, max score 6
# Completed 507 games, 705 rewards, 161402 frames, score 1, max score 6
# Completed 508 games, 706 rewards, 161656 frames, score 0, max score 6
# Completed 509 games, 707 rewards, 161864 frames, score 0, max score 6
# Completed 510 games, 709 rewards, 162231 frames, score 1, max score 6
# Completed 511 games, 710 rewards, 162485 frames, score 0, max score 6
# Completed 512 games, 712 rewards, 162667 frames, score 1, max score 6
# Completed 513 games, 714 rewards, 163133 frames, score 1, max score 6
# Completed 514 games, 715 rewards, 163387 frames, score 0, max score 6
# Completed 515 games, 716 rewards, 163568 frames, score 0, max score 6
# Completed 516 games, 717 rewards, 163776 frames, score 0, max score 6
# Completed 517 games, 721 rewards, 164812 frames, score 3, max score 6
# Completed 518 games, 722 rewards, 164993 frames, score 0, max score 6
# Completed 519 games, 723 rewards, 165247 frames, score 0, max score 6
# Completed 520 games, 724 rewards, 165428 frames, score 0, max score 6
# Completed 521 games, 725 rewards, 165609 frames, score 0, max score 6
# Completed 522 games, 726 rewards, 165790 frames, score 0, max score 6
# Completed 523 games, 727 rewards, 165971 frames, score 0, max score 6
# Completed 524 games, 730 rewards, 166610 frames, score 2, max score 6
# Completed 525 games, 731 rewards, 166791 frames, score 0, max score 6
# Completed 526 games, 733 rewards, 167367 frames, score 1, max score 6
# Completed 527 games, 734 rewards, 167548 frames, score 0, max score 6
# Completed 528 games, 735 rewards, 167729 frames, score 0, max score 6
# Completed 529 games, 738 rewards, 168381 frames, score 2, max score 6
# Completed 530 games, 739 rewards, 168589 frames, score 0, max score 6
# Completed 531 games, 740 rewards, 168797 frames, score 0, max score 6
# Completed 532 games, 741 rewards, 169051 frames, score 0, max score 6
# Completed 533 games, 743 rewards, 169461 frames, score 1, max score 6
# Completed 534 games, 745 rewards, 169828 frames, score 1, max score 6
# Completed 535 games, 746 rewards, 170009 frames, score 0, max score 6
# Completed 536 games, 747 rewards, 170190 frames, score 0, max score 6
# Completed 537 games, 748 rewards, 170398 frames, score 0, max score 6
# Completed 538 games, 750 rewards, 170932 frames, score 1, max score 6
# Completed 539 games, 751 rewards, 171140 frames, score 0, max score 6
# Completed 540 games, 752 rewards, 171394 frames, score 0, max score 6
# Completed 541 games, 753 rewards, 171575 frames, score 0, max score 6
# Completed 542 games, 755 rewards, 171942 frames, score 1, max score 6
# Completed 543 games, 757 rewards, 172348 frames, score 1, max score 6
# Completed 544 games, 758 rewards, 172529 frames, score 0, max score 6
# Completed 545 games, 759 rewards, 172710 frames, score 0, max score 6
# Completed 546 games, 760 rewards, 172964 frames, score 0, max score 6
# Completed 547 games, 761 rewards, 173218 frames, score 0, max score 6
# Completed 548 games, 762 rewards, 173399 frames, score 0, max score 6
# Completed 549 games, 763 rewards, 173607 frames, score 0, max score 6
# Completed 550 games, 765 rewards, 174341 frames, score 1, max score 6
# Completed 551 games, 766 rewards, 174549 frames, score 0, max score 6
# Completed 552 games, 767 rewards, 174730 frames, score 0, max score 6
# Completed 553 games, 768 rewards, 174938 frames, score 0, max score 6
# Completed 554 games, 769 rewards, 175146 frames, score 0, max score 6
# Completed 555 games, 770 rewards, 175354 frames, score 0, max score 6
# Completed 556 games, 771 rewards, 175608 frames, score 0, max score 6
# Completed 557 games, 773 rewards, 176159 frames, score 1, max score 6
# Completed 558 games, 775 rewards, 176656 frames, score 1, max score 6
# Completed 559 games, 776 rewards, 176837 frames, score 0, max score 6
# Completed 560 games, 777 rewards, 177018 frames, score 0, max score 6
# Completed 561 games, 778 rewards, 177199 frames, score 0, max score 6
# Completed 562 games, 779 rewards, 177380 frames, score 0, max score 6
# Completed 563 games, 780 rewards, 177634 frames, score 0, max score 6
# Completed 564 games, 781 rewards, 177842 frames, score 0, max score 6
# Completed 565 games, 782 rewards, 178096 frames, score 0, max score 6
# Completed 566 games, 783 rewards, 178304 frames, score 0, max score 6
# Completed 567 games, 784 rewards, 178512 frames, score 0, max score 6
# Completed 568 games, 785 rewards, 178766 frames, score 0, max score 6
# Completed 569 games, 786 rewards, 178947 frames, score 0, max score 6
# Completed 570 games, 788 rewards, 179330 frames, score 1, max score 6
# Completed 571 games, 789 rewards, 179511 frames, score 0, max score 6
# Completed 572 games, 790 rewards, 179692 frames, score 0, max score 6
# Completed 573 games, 792 rewards, 180180 frames, score 1, max score 6
# Completed 574 games, 793 rewards, 180388 frames, score 0, max score 6
# Completed 575 games, 795 rewards, 180786 frames, score 1, max score 6
# Completed 576 games, 796 rewards, 180994 frames, score 0, max score 6
# Completed 577 games, 797 rewards, 181202 frames, score 0, max score 6
# Completed 578 games, 800 rewards, 182220 frames, score 2, max score 6
# Completed 579 games, 801 rewards, 182428 frames, score 0, max score 6
# Completed 580 games, 803 rewards, 182865 frames, score 1, max score 6
# Completed 581 games, 805 rewards, 183467 frames, score 1, max score 6
# Completed 582 games, 810 rewards, 184770 frames, score 4, max score 6
# Completed 583 games, 811 rewards, 185024 frames, score 0, max score 6
# Completed 584 games, 812 rewards, 185205 frames, score 0, max score 6
# Completed 585 games, 813 rewards, 185413 frames, score 0, max score 6
# Completed 586 games, 814 rewards, 185621 frames, score 0, max score 6
# Completed 587 games, 815 rewards, 185802 frames, score 0, max score 6
# Completed 588 games, 816 rewards, 185983 frames, score 0, max score 6
# Completed 589 games, 817 rewards, 186237 frames, score 0, max score 6
# Completed 590 games, 819 rewards, 186734 frames, score 1, max score 6
# Completed 591 games, 820 rewards, 186915 frames, score 0, max score 6
# Completed 592 games, 821 rewards, 187123 frames, score 0, max score 6
# Completed 593 games, 823 rewards, 187635 frames, score 1, max score 6
# Completed 594 games, 824 rewards, 187843 frames, score 0, max score 6
# Completed 595 games, 827 rewards, 188407 frames, score 2, max score 6
# Completed 596 games, 828 rewards, 188588 frames, score 0, max score 6
# Completed 597 games, 829 rewards, 188796 frames, score 0, max score 6
# Completed 598 games, 831 rewards, 189248 frames, score 1, max score 6
# Completed 599 games, 833 rewards, 189615 frames, score 1, max score 6
# Completed 600 games, 834 rewards, 189869 frames, score 0, max score 6
# Completed 601 games, 835 rewards, 190077 frames, score 0, max score 6
# Completed 602 games, 836 rewards, 190285 frames, score 0, max score 6
# Completed 603 games, 837 rewards, 190539 frames, score 0, max score 6
# Completed 604 games, 838 rewards, 190747 frames, score 0, max score 6
# Completed 605 games, 839 rewards, 190955 frames, score 0, max score 6
# Completed 606 games, 840 rewards, 191209 frames, score 0, max score 6
# Completed 607 games, 841 rewards, 191463 frames, score 0, max score 6
# Completed 608 games, 842 rewards, 191671 frames, score 0, max score 6
# Completed 609 games, 843 rewards, 191852 frames, score 0, max score 6
# Completed 610 games, 844 rewards, 192106 frames, score 0, max score 6
# Completed 611 games, 845 rewards, 192360 frames, score 0, max score 6
# Completed 612 games, 846 rewards, 192614 frames, score 0, max score 6
# Completed 613 games, 847 rewards, 192868 frames, score 0, max score 6
# Completed 614 games, 848 rewards, 193049 frames, score 0, max score 6
# Completed 615 games, 849 rewards, 193257 frames, score 0, max score 6
# Completed 616 games, 850 rewards, 193511 frames, score 0, max score 6
# Completed 617 games, 852 rewards, 194008 frames, score 1, max score 6
# Completed 618 games, 853 rewards, 194262 frames, score 0, max score 6
# Completed 619 games, 854 rewards, 194516 frames, score 0, max score 6
# Completed 620 games, 855 rewards, 194697 frames, score 0, max score 6
# Completed 621 games, 856 rewards, 194951 frames, score 0, max score 6
# Completed 622 games, 857 rewards, 195132 frames, score 0, max score 6
# Completed 623 games, 859 rewards, 195666 frames, score 1, max score 6
# Completed 624 games, 862 rewards, 196197 frames, score 2, max score 6
# Completed 625 games, 864 rewards, 196799 frames, score 1, max score 6
# Completed 626 games, 865 rewards, 196980 frames, score 0, max score 6
# Completed 627 games, 866 rewards, 197234 frames, score 0, max score 6
# Completed 628 games, 867 rewards, 197488 frames, score 0, max score 6
# Completed 629 games, 870 rewards, 198174 frames, score 2, max score 6
# Completed 630 games, 871 rewards, 198355 frames, score 0, max score 6
# Completed 631 games, 872 rewards, 198536 frames, score 0, max score 6
# Completed 632 games, 873 rewards, 198717 frames, score 0, max score 6
# Completed 633 games, 877 rewards, 200252 frames, score 3, max score 6
# Completed 634 games, 879 rewards, 200749 frames, score 1, max score 6
# Completed 635 games, 880 rewards, 200957 frames, score 0, max score 6
# Completed 636 games, 881 rewards, 201165 frames, score 0, max score 6
# Completed 637 games, 885 rewards, 201967 frames, score 3, max score 6
# Completed 638 games, 886 rewards, 202175 frames, score 0, max score 6
# Completed 639 games, 887 rewards, 202429 frames, score 0, max score 6
# Completed 640 games, 888 rewards, 202637 frames, score 0, max score 6
# Completed 641 games, 889 rewards, 202845 frames, score 0, max score 6
# Completed 642 games, 890 rewards, 203099 frames, score 0, max score 6
# Completed 643 games, 893 rewards, 203640 frames, score 2, max score 6
# Completed 644 games, 894 rewards, 203894 frames, score 0, max score 6
# Completed 645 games, 895 rewards, 204148 frames, score 0, max score 6
# Completed 646 games, 896 rewards, 204356 frames, score 0, max score 6
# Completed 647 games, 898 rewards, 204761 frames, score 1, max score 6
# Completed 648 games, 900 rewards, 205113 frames, score 1, max score 6
# Completed 649 games, 901 rewards, 205321 frames, score 0, max score 6
# Completed 650 games, 902 rewards, 205502 frames, score 0, max score 6
# Completed 651 games, 903 rewards, 205710 frames, score 0, max score 6
# Completed 652 games, 905 rewards, 206162 frames, score 1, max score 6
# Completed 653 games, 906 rewards, 206343 frames, score 0, max score 6
# Completed 654 games, 907 rewards, 206597 frames, score 0, max score 6
# Completed 655 games, 910 rewards, 207287 frames, score 2, max score 6
# Completed 656 games, 911 rewards, 207495 frames, score 0, max score 6
# Completed 657 games, 912 rewards, 207676 frames, score 0, max score 6
# Completed 658 games, 914 rewards, 208017 frames, score 1, max score 6
# Completed 659 games, 915 rewards, 208271 frames, score 0, max score 6
# Completed 660 games, 916 rewards, 208452 frames, score 0, max score 6
# Completed 661 games, 918 rewards, 208880 frames, score 1, max score 6
# Completed 662 games, 919 rewards, 209134 frames, score 0, max score 6
# Completed 663 games, 920 rewards, 209388 frames, score 0, max score 6
# Completed 664 games, 921 rewards, 209642 frames, score 0, max score 6
# Completed 665 games, 922 rewards, 209823 frames, score 0, max score 6
# Completed 666 games, 923 rewards, 210077 frames, score 0, max score 6
# Completed 667 games, 924 rewards, 210331 frames, score 0, max score 6
# Completed 668 games, 926 rewards, 210729 frames, score 1, max score 6
# Completed 669 games, 927 rewards, 210910 frames, score 0, max score 6
# Completed 670 games, 928 rewards, 211164 frames, score 0, max score 6
# Completed 671 games, 929 rewards, 211418 frames, score 0, max score 6
# Completed 672 games, 930 rewards, 211672 frames, score 0, max score 6
# Completed 673 games, 931 rewards, 211926 frames, score 0, max score 6
# Completed 674 games, 932 rewards, 212107 frames, score 0, max score 6
# Completed 675 games, 933 rewards, 212288 frames, score 0, max score 6
# Completed 676 games, 935 rewards, 212655 frames, score 1, max score 6
# Completed 677 games, 936 rewards, 212909 frames, score 0, max score 6
# Completed 678 games, 939 rewards, 213549 frames, score 2, max score 6
# Completed 679 games, 940 rewards, 213803 frames, score 0, max score 6
# Completed 680 games, 941 rewards, 214057 frames, score 0, max score 6
# Completed 681 games, 942 rewards, 214311 frames, score 0, max score 6
# Completed 682 games, 943 rewards, 214519 frames, score 0, max score 6
# Completed 683 games, 944 rewards, 214773 frames, score 0, max score 6
# Completed 684 games, 945 rewards, 214954 frames, score 0, max score 6
# Completed 685 games, 946 rewards, 215162 frames, score 0, max score 6
# Completed 686 games, 947 rewards, 215370 frames, score 0, max score 6
# Completed 687 games, 948 rewards, 215551 frames, score 0, max score 6
# Completed 688 games, 949 rewards, 215732 frames, score 0, max score 6
# Completed 689 games, 950 rewards, 215986 frames, score 0, max score 6
# Completed 690 games, 951 rewards, 216194 frames, score 0, max score 6
# Completed 691 games, 952 rewards, 216402 frames, score 0, max score 6
# Completed 692 games, 954 rewards, 216953 frames, score 1, max score 6
# ...
# Completed 4783 games, 6277 rewards, 1428156 frames, score 1, max score 7
# Completed 4784 games, 6278 rewards, 1428364 frames, score 0, max score 7
# Completed 4785 games, 6279 rewards, 1428572 frames, score 0, max score 7
# Completed 4786 games, 6280 rewards, 1428780 frames, score 0, max score 7
# Completed 4787 games, 6281 rewards, 1428961 frames, score 0, max score 7
# Completed 4788 games, 6282 rewards, 1429169 frames, score 0, max score 7
# Completed 4789 games, 6284 rewards, 1429745 frames, score 1, max score 7
# Completed 4790 games, 6285 rewards, 1429926 frames, score 0, max score 7
# Completed 4791 games, 6286 rewards, 1430107 frames, score 0, max score 7
# Completed 4792 games, 6287 rewards, 1430288 frames, score 0, max score 7
# Completed 4793 games, 6288 rewards, 1430469 frames, score 0, max score 7
# Completed 4794 games, 6289 rewards, 1430677 frames, score 0, max score 7
# Completed 4795 games, 6290 rewards, 1430931 frames, score 0, max score 7
# Completed 4796 games, 6291 rewards, 1431112 frames, score 0, max score 7
# Completed 4797 games, 6292 rewards, 1431293 frames, score 0, max score 7
# Completed 4798 games, 6293 rewards, 1431547 frames, score 0, max score 7
# Completed 4799 games, 6294 rewards, 1431728 frames, score 0, max score 7
# Completed 4800 games, 6295 rewards, 1431936 frames, score 0, max score 7
# Completed 4801 games, 6296 rewards, 1432190 frames, score 0, max score 7
# Completed 4802 games, 6297 rewards, 1432398 frames, score 0, max score 7
# Completed 4803 games, 6299 rewards, 1432949 frames, score 1, max score 7
# Completed 4804 games, 6300 rewards, 1433130 frames, score 0, max score 7
# Completed 4805 games, 6301 rewards, 1433338 frames, score 0, max score 7
# Completed 4806 games, 6302 rewards, 1433592 frames, score 0, max score 7
# Completed 4807 games, 6303 rewards, 1433773 frames, score 0, max score 7
# Completed 4808 games, 6308 rewards, 1434804 frames, score 4, max score 7
# Completed 4809 games, 6309 rewards, 1435058 frames, score 0, max score 7
# Completed 4810 games, 6310 rewards, 1435312 frames, score 0, max score 7
# Completed 4811 games, 6312 rewards, 1435653 frames, score 1, max score 7
# Completed 4812 games, 6313 rewards, 1435834 frames, score 0, max score 7
# Completed 4813 games, 6315 rewards, 1436331 frames, score 1, max score 7
# Completed 4814 games, 6316 rewards, 1436512 frames, score 0, max score 7
# Completed 4815 games, 6317 rewards, 1436693 frames, score 0, max score 7
# Completed 4816 games, 6318 rewards, 1436874 frames, score 0, max score 7
# Completed 4817 games, 6319 rewards, 1437055 frames, score 0, max score 7
# Completed 4818 games, 6320 rewards, 1437263 frames, score 0, max score 7
# Completed 4819 games, 6321 rewards, 1437471 frames, score 0, max score 7
# Completed 4820 games, 6322 rewards, 1437725 frames, score 0, max score 7
# Completed 4821 games, 6323 rewards, 1437906 frames, score 0, max score 7
# Completed 4822 games, 6324 rewards, 1438160 frames, score 0, max score 7
# Completed 4823 games, 6325 rewards, 1438368 frames, score 0, max score 7
# Completed 4824 games, 6326 rewards, 1438622 frames, score 0, max score 7
# Completed 4825 games, 6327 rewards, 1438803 frames, score 0, max score 7
# Completed 4826 games, 6328 rewards, 1439011 frames, score 0, max score 7
# Completed 4827 games, 6329 rewards, 1439192 frames, score 0, max score 7
# Completed 4828 games, 6330 rewards, 1439373 frames, score 0, max score 7
# Completed 4829 games, 6331 rewards, 1439627 frames, score 0, max score 7
# Completed 4830 games, 6333 rewards, 1440023 frames, score 1, max score 7
# Completed 4831 games, 6335 rewards, 1440625 frames, score 1, max score 7
# Completed 4832 games, 6336 rewards, 1440833 frames, score 0, max score 7
# Completed 4833 games, 6337 rewards, 1441087 frames, score 0, max score 7
# Completed 4834 games, 6338 rewards, 1441268 frames, score 0, max score 7
# Completed 4835 games, 6339 rewards, 1441449 frames, score 0, max score 7
# Completed 4836 games, 6340 rewards, 1441657 frames, score 0, max score 7
# Completed 4837 games, 6343 rewards, 1442296 frames, score 2, max score 7
# Completed 4838 games, 6345 rewards, 1442733 frames, score 1, max score 7
# Completed 4839 games, 6347 rewards, 1443161 frames, score 1, max score 7
# Completed 4840 games, 6348 rewards, 1443342 frames, score 0, max score 7
# Completed 4841 games, 6349 rewards, 1443550 frames, score 0, max score 7
# Completed 4842 games, 6350 rewards, 1443731 frames, score 0, max score 7
# Completed 4843 games, 6351 rewards, 1443912 frames, score 0, max score 7
# Completed 4844 games, 6352 rewards, 1444093 frames, score 0, max score 7
# Completed 4845 games, 6353 rewards, 1444274 frames, score 0, max score 7
# Completed 4846 games, 6354 rewards, 1444455 frames, score 0, max score 7
# Completed 4847 games, 6355 rewards, 1444709 frames, score 0, max score 7
# Completed 4848 games, 6356 rewards, 1444890 frames, score 0, max score 7
# Completed 4849 games, 6357 rewards, 1445144 frames, score 0, max score 7
# Completed 4850 games, 6358 rewards, 1445398 frames, score 0, max score 7
# Completed 4851 games, 6359 rewards, 1445652 frames, score 0, max score 7
# Completed 4852 games, 6360 rewards, 1445860 frames, score 0, max score 7
# Completed 4853 games, 6361 rewards, 1446114 frames, score 0, max score 7
# Completed 4854 games, 6362 rewards, 1446322 frames, score 0, max score 7
# Completed 4855 games, 6363 rewards, 1446576 frames, score 0, max score 7
# Completed 4856 games, 6365 rewards, 1447082 frames, score 1, max score 7
# Completed 4857 games, 6366 rewards, 1447263 frames, score 0, max score 7
# Completed 4858 games, 6367 rewards, 1447517 frames, score 0, max score 7
# Completed 4859 games, 6368 rewards, 1447771 frames, score 0, max score 7
# Completed 4860 games, 6369 rewards, 1447979 frames, score 0, max score 7
# Completed 4861 games, 6370 rewards, 1448233 frames, score 0, max score 7
# Completed 4862 games, 6371 rewards, 1448414 frames, score 0, max score 7
# Completed 4863 games, 6372 rewards, 1448595 frames, score 0, max score 7
# Completed 4864 games, 6373 rewards, 1448849 frames, score 0, max score 7
# Completed 4865 games, 6379 rewards, 1449986 frames, score 5, max score 7
# Completed 4866 games, 6380 rewards, 1450240 frames, score 0, max score 7
# Completed 4867 games, 6381 rewards, 1450448 frames, score 0, max score 7
# Completed 4868 games, 6382 rewards, 1450702 frames, score 0, max score 7
# Completed 4869 games, 6384 rewards, 1451210 frames, score 1, max score 7
# Completed 4870 games, 6386 rewards, 1452386 frames, score 1, max score 7
# Completed 4871 games, 6391 rewards, 1453194 frames, score 4, max score 7
# Completed 4872 games, 6392 rewards, 1453402 frames, score 0, max score 7
# Completed 4873 games, 6395 rewards, 1454644 frames, score 2, max score 7
# Completed 4874 games, 6396 rewards, 1454825 frames, score 0, max score 7
# Completed 4875 games, 6397 rewards, 1455033 frames, score 0, max score 7
# Completed 4876 games, 6398 rewards, 1455241 frames, score 0, max score 7
# Completed 4877 games, 6399 rewards, 1455449 frames, score 0, max score 7
# Completed 4878 games, 6400 rewards, 1455630 frames, score 0, max score 7
# Completed 4879 games, 6401 rewards, 1455838 frames, score 0, max score 7
# Completed 4880 games, 6402 rewards, 1456019 frames, score 0, max score 7
# Completed 4881 games, 6404 rewards, 1456456 frames, score 1, max score 7
# Completed 4882 games, 6406 rewards, 1456944 frames, score 1, max score 7
# Completed 4883 games, 6409 rewards, 1457858 frames, score 2, max score 7
# Completed 4884 games, 6413 rewards, 1458672 frames, score 3, max score 7
# Completed 4885 games, 6414 rewards, 1458880 frames, score 0, max score 7
# Completed 4886 games, 6416 rewards, 1459308 frames, score 1, max score 7
# Completed 4887 games, 6417 rewards, 1459489 frames, score 0, max score 7
# Completed 4888 games, 6418 rewards, 1459670 frames, score 0, max score 7
# Completed 4889 games, 6419 rewards, 1459851 frames, score 0, max score 7
# Completed 4890 games, 6420 rewards, 1460059 frames, score 0, max score 7
# Completed 4891 games, 6421 rewards, 1460313 frames, score 0, max score 7
# Completed 4892 games, 6422 rewards, 1460567 frames, score 0, max score 7
# Completed 4893 games, 6423 rewards, 1460748 frames, score 0, max score 7
# Completed 4894 games, 6424 rewards, 1461002 frames, score 0, max score 7
# Completed 4895 games, 6425 rewards, 1461256 frames, score 0, max score 7
# Completed 4896 games, 6426 rewards, 1461510 frames, score 0, max score 7
# Completed 4897 games, 6427 rewards, 1461718 frames, score 0, max score 7
# Completed 4898 games, 6428 rewards, 1461899 frames, score 0, max score 7
# Completed 4899 games, 6429 rewards, 1462153 frames, score 0, max score 7
# Completed 4900 games, 6430 rewards, 1462361 frames, score 0, max score 7
# Completed 4901 games, 6431 rewards, 1462615 frames, score 0, max score 7
# Completed 4902 games, 6433 rewards, 1463166 frames, score 1, max score 7
# Completed 4903 games, 6434 rewards, 1463347 frames, score 0, max score 7
# Completed 4904 games, 6435 rewards, 1463601 frames, score 0, max score 7
# Completed 4905 games, 6436 rewards, 1463855 frames, score 0, max score 7
# Completed 4906 games, 6437 rewards, 1464063 frames, score 0, max score 7
# Completed 4907 games, 6438 rewards, 1464244 frames, score 0, max score 7
# Completed 4908 games, 6439 rewards, 1464452 frames, score 0, max score 7
# Completed 4909 games, 6440 rewards, 1464706 frames, score 0, max score 7
# Completed 4910 games, 6441 rewards, 1464887 frames, score 0, max score 7
# Completed 4911 games, 6442 rewards, 1465095 frames, score 0, max score 7
# Completed 4912 games, 6443 rewards, 1465349 frames, score 0, max score 7
# Completed 4913 games, 6444 rewards, 1465557 frames, score 0, max score 7
# Completed 4914 games, 6445 rewards, 1465738 frames, score 0, max score 7
# Completed 4915 games, 6446 rewards, 1465992 frames, score 0, max score 7
# Completed 4916 games, 6447 rewards, 1466173 frames, score 0, max score 7
# Completed 4917 games, 6449 rewards, 1466707 frames, score 1, max score 7
# Completed 4918 games, 6450 rewards, 1466888 frames, score 0, max score 7
# Completed 4919 games, 6453 rewards, 1467989 frames, score 2, max score 7
# Completed 4920 games, 6454 rewards, 1468243 frames, score 0, max score 7
# Completed 4921 games, 6455 rewards, 1468451 frames, score 0, max score 7
# Completed 4922 games, 6456 rewards, 1468659 frames, score 0, max score 7
# Completed 4923 games, 6458 rewards, 1469096 frames, score 1, max score 7
# Completed 4924 games, 6459 rewards, 1469277 frames, score 0, max score 7
# Completed 4925 games, 6461 rewards, 1469939 frames, score 1, max score 7
# Completed 4926 games, 6462 rewards, 1470193 frames, score 0, max score 7
# Completed 4927 games, 6463 rewards, 1470401 frames, score 0, max score 7
# Completed 4928 games, 6466 rewards, 1471093 frames, score 2, max score 7
# Completed 4929 games, 6467 rewards, 1471301 frames, score 0, max score 7
# Completed 4930 games, 6469 rewards, 1471813 frames, score 1, max score 7
# Completed 4931 games, 6470 rewards, 1472067 frames, score 0, max score 7
# Completed 4932 games, 6471 rewards, 1472321 frames, score 0, max score 7
# Completed 4933 games, 6472 rewards, 1472575 frames, score 0, max score 7
# Completed 4934 games, 6475 rewards, 1473205 frames, score 2, max score 7
# Completed 4935 games, 6476 rewards, 1473413 frames, score 0, max score 7
# Completed 4936 games, 6477 rewards, 1473594 frames, score 0, max score 7
# Completed 4937 games, 6478 rewards, 1473775 frames, score 0, max score 7
# Completed 4938 games, 6479 rewards, 1473956 frames, score 0, max score 7
# Completed 4939 games, 6480 rewards, 1474164 frames, score 0, max score 7
# Completed 4940 games, 6481 rewards, 1474418 frames, score 0, max score 7
# Completed 4941 games, 6482 rewards, 1474599 frames, score 0, max score 7
# Completed 4942 games, 6483 rewards, 1474780 frames, score 0, max score 7
# Completed 4943 games, 6484 rewards, 1474988 frames, score 0, max score 7
# Completed 4944 games, 6488 rewards, 1476049 frames, score 3, max score 7
# Completed 4945 games, 6489 rewards, 1476257 frames, score 0, max score 7
# Completed 4946 games, 6490 rewards, 1476438 frames, score 0, max score 7
# Completed 4947 games, 6491 rewards, 1476646 frames, score 0, max score 7
# Completed 4948 games, 6492 rewards, 1476900 frames, score 0, max score 7
# Completed 4949 games, 6493 rewards, 1477108 frames, score 0, max score 7
# Completed 4950 games, 6494 rewards, 1477289 frames, score 0, max score 7
# Completed 4951 games, 6495 rewards, 1477497 frames, score 0, max score 7
# Completed 4952 games, 6496 rewards, 1477678 frames, score 0, max score 7
# Completed 4953 games, 6497 rewards, 1477859 frames, score 0, max score 7
# Completed 4954 games, 6498 rewards, 1478067 frames, score 0, max score 7
# Completed 4955 games, 6500 rewards, 1478556 frames, score 1, max score 7
# Completed 4956 games, 6503 rewards, 1479262 frames, score 2, max score 7
# Completed 4957 games, 6504 rewards, 1479516 frames, score 0, max score 7
# Completed 4958 games, 6505 rewards, 1479724 frames, score 0, max score 7
# Completed 4959 games, 6506 rewards, 1479978 frames, score 0, max score 7
# Completed 4960 games, 6507 rewards, 1480232 frames, score 0, max score 7
# Completed 4961 games, 6508 rewards, 1480486 frames, score 0, max score 7
# Completed 4962 games, 6509 rewards, 1480667 frames, score 0, max score 7
# Completed 4963 games, 6510 rewards, 1480875 frames, score 0, max score 7
# Completed 4964 games, 6511 rewards, 1481083 frames, score 0, max score 7
# Completed 4965 games, 6512 rewards, 1481291 frames, score 0, max score 7
# Completed 4966 games, 6513 rewards, 1481472 frames, score 0, max score 7
# Completed 4967 games, 6514 rewards, 1481680 frames, score 0, max score 7
# Completed 4968 games, 6515 rewards, 1481861 frames, score 0, max score 7
# Completed 4969 games, 6516 rewards, 1482042 frames, score 0, max score 7
# Completed 4970 games, 6517 rewards, 1482223 frames, score 0, max score 7
# Completed 4971 games, 6519 rewards, 1482610 frames, score 1, max score 7
# Completed 4972 games, 6520 rewards, 1482791 frames, score 0, max score 7
# Completed 4973 games, 6521 rewards, 1482999 frames, score 0, max score 7
# Completed 4974 games, 6522 rewards, 1483180 frames, score 0, max score 7
# Completed 4975 games, 6523 rewards, 1483361 frames, score 0, max score 7
# Completed 4976 games, 6525 rewards, 1483849 frames, score 1, max score 7
# Completed 4977 games, 6526 rewards, 1484057 frames, score 0, max score 7
# Completed 4978 games, 6527 rewards, 1484238 frames, score 0, max score 7
# Completed 4979 games, 6528 rewards, 1484492 frames, score 0, max score 7
# Completed 4980 games, 6530 rewards, 1484955 frames, score 1, max score 7
# Completed 4981 games, 6534 rewards, 1485607 frames, score 3, max score 7
# Completed 4982 games, 6535 rewards, 1485861 frames, score 0, max score 7
# Completed 4983 games, 6536 rewards, 1486042 frames, score 0, max score 7
# Completed 4984 games, 6537 rewards, 1486223 frames, score 0, max score 7
# Completed 4985 games, 6540 rewards, 1486762 frames, score 2, max score 7
# Completed 4986 games, 6541 rewards, 1487016 frames, score 0, max score 7
# Completed 4987 games, 6542 rewards, 1487224 frames, score 0, max score 7
# Completed 4988 games, 6543 rewards, 1487432 frames, score 0, max score 7
# Completed 4989 games, 6545 rewards, 1487944 frames, score 1, max score 7
# Completed 4990 games, 6548 rewards, 1488901 frames, score 2, max score 7
# Completed 4991 games, 6549 rewards, 1489109 frames, score 0, max score 7
# Completed 4992 games, 6550 rewards, 1489317 frames, score 0, max score 7
# Completed 4993 games, 6551 rewards, 1489571 frames, score 0, max score 7
# Completed 4994 games, 6552 rewards, 1489752 frames, score 0, max score 7
# Completed 4995 games, 6553 rewards, 1489960 frames, score 0, max score 7
# Completed 4996 games, 6554 rewards, 1490168 frames, score 0, max score 7
# Completed 4997 games, 6556 rewards, 1490665 frames, score 1, max score 7
# Completed 4998 games, 6557 rewards, 1490919 frames, score 0, max score 7
# Completed 4999 games, 6559 rewards, 1491347 frames, score 1, max score 7
# The number of games played was 5000
# The number of video frames was 5000
# The size of each returned Q-matrix was (0,)

# %% [markdown]
# Now let's plot the score, to see if it improved over time.  We will also plot the local average, averaged over 10 consecutive games, to see if that has improved.  Notice that we can use `np.convolve` to compute the local average.
#
# These numbers are really noisy, with a really large maximum.  We will plot `np.log10(1+x)`, rather than x, so that we can better see the average numbers, and ignore the very large noisy spikes.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(14,9),layout='tight')
ax = [ fig.add_subplot(3,1,x) for x in range(1,4) ]
ax[0].plot(np.arange(0,len(scores)),np.log10(1+np.array(scores)))
ax[0].plot([0,5000],np.log10([7,7]),'k--')
ax[0].set_title('Game scores')
ax[1].plot(np.arange(4991),np.log10(1+np.convolve(np.ones(10)/10,scores,mode='valid')))
ax[1].plot([0,4991],np.log10([7,7]),'k--')
ax[1].set_title('Game scores, average 10 consecutive games')
ax[2].plot(np.arange(0,len(q_achieved)),q_achieved)
ax[2].set_title('Q values of state achieved at each time')
ax[2].set_ylabel('Game number')
# Out:
# Text(0, 0.5, 'Game number')

# %% [markdown]
# Hooray, it has learned!  If you are getting a ten-game average score of better than 6, then you are ready to submit your model for grading.   In order to do that, you need to save the model:

# %%
q_learner.save('trained_model.npz')

# %% [markdown]
# <a id='section9'></a>

# %% [markdown]
# ## Extra Credit

# %% [markdown]
# For extra credit, download the file <a href="mp11_extra.zip">mp11_extra.zip</a>.  The only important file in this package is:
# * `tests/test_extra.py`: this contains extra tests that will evaluate your pre-trained `deep_q` learner, which should be in a file called `trained_model.pkl`.  For full credit, your model should achieve an average score of greater than 20, averaged over 10 consecutive games.
#
# With a quantized lookup table, it's probably not possible to achieve an average score of 20.  With a deep-Q learner, however, it is eminently possible.  In order to do the extra credit, therefore, you should just fill in the part of `submitted.py` that implements the `deep_q` learner, using pytorch to define a model structure, train it, save it, load it, and act on it.  This learner only needs to have five methods: `__init__`, `act`, `learn`, `save`, and `load`:

# %%
importlib.reload(submitted)
help(submitted.deep_q.__init__)
# Out:
# Help on function __init__ in module submitted:
#
# __init__(self, alpha, epsilon, gamma, nfirst)
#     Create a new deep_q learner.
#     Your q_learner object should store the provided values of alpha,
#     epsilon, gamma, and nfirst.
#     It should also create a deep learning model that will accept
#     (state,action) as input, and estimate Q as the output.
#
#     @params:
#     alpha (scalar) - learning rate of the Q-learner
#     epsilon (scalar) - probability of taking a random action
#     gamma (scalar) - discount factor
#     nfirst (scalar) - exploring each state/action pair nfirst times before exploiting
#
#     @return:
#     None

# %%
help(submitted.deep_q.act)
# Out:
# Help on function act in module submitted:
#
# act(self, state)
#     Decide what action to take in the current state.
#     You are free to determine your own exploration/exploitation policy --
#     you don't need to use the epsilon and nfirst provided to you.
#
#     @params:
#     state: a list of 5 floats: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#
#     @return:
#     -1 if the paddle should move upward
#     0 if the paddle should be stationary
#     1 if the paddle should move downward

# %%
help(submitted.deep_q.learn)
# Out:
# Help on function learn in module submitted:
#
# learn(self, state, action, reward, newstate)
#     Perform one iteration of training on a deep-Q model.
#
#     @params:
#     state: a list of 5 floats: ball_x, ball_y, ball_vx, ball_vy, paddle_y
#     action: an integer, one of -1, 0, or +1
#     reward: a reward; positive for hitting the ball, negative for losing a game
#     newstate: a list of 5 floats, in the same format as state
#
#     @return:
#     None

# %%
help(submitted.deep_q.save)
# Out:
# Help on function save in module submitted:
#
# save(self, filename)
#     Save your trained deep-Q model to a file.
#     This can save in any format you like, as long as your "load"
#     function uses the same file format.
#
#     @params:
#     filename (str) - filename to which it should be saved
#     @return:
#     None

# %%
help(submitted.deep_q.load)
# Out:
# Help on function load in module submitted:
#
# load(self, filename)
#     Load your deep-Q model from a file.
#     This should load from whatever file format your save function
#     used.
#
#     @params:
#     filename (str) - filename from which it should be loaded
#     @return:
#     None

# %% [markdown]
# <a id='grade'></a>

# %% [markdown]
# ## Grade your homework

# %% [markdown]
# If you've reached this point, and all of the above sections work, then you're ready to try grading your homework!  Before you submit it to Gradescope, try grading it on your own machine.  This will run some visible test cases (which you can read in `tests/test_visible.py`), and compare the results to the solutions (which you can read in `solution.json`).
#
# The exclamation point (!) tells python to run the following as a shell command.  Obviously you don't need to run the code this way -- this usage is here just to remind you that you can also, if you wish, run this command in a terminal window.

# %%
# !python grade.py
# Out:
# Completed 0 games, 1 rewards, 209 frames, score 0, max score 0
# Completed 1 games, 2 rewards, 463 frames, score 0, max score 0
# Completed 2 games, 3 rewards, 644 frames, score 0, max score 0
# Completed 3 games, 4 rewards, 825 frames, score 0, max score 0
# Completed 4 games, 5 rewards, 1033 frames, score 0, max score 0
# Completed 5 games, 7 rewards, 1635 frames, score 1, max score 1
# Completed 6 games, 8 rewards, 1816 frames, score 0, max score 1
# Completed 7 games, 12 rewards, 3115 frames, score 3, max score 3
# Completed 8 games, 13 rewards, 3296 frames, score 0, max score 3
# Completed 9 games, 15 rewards, 3710 frames, score 1, max score 3
# .F...F
# ======================================================================
# FAIL: test_choose_unexplored_action (test_visible.TestStep.test_choose_unexplored_action)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "c:\Users\mycol\CS440\MP11-Dictionary-Version\tests\test_visible.py", line 13, in test_choose_unexplored_action
#     self.assertEqual(np.count_nonzero([y==1 for y in actions[:3]]),1,
# AssertionError: 0 != 1 : action==1 should occur once in the first 3 calls to act: [0, 0, -1]
#
#
# ======================================================================
# FAIL: test_trained_model (test_visible.TestStep.test_trained_model)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "c:\Users\mycol\CS440\MP11-Dictionary-Version\tests\test_visible.py", line 88, in test_trained_model
#     self.assertGreater(np.average(scores),6,
# AssertionError: 0.5 not greater than 6 : trained_model.npz average score is 0.5 which is not above 6
#
#
# ----------------------------------------------------------------------
# Ran 6 tests in 0.061s
#
# FAILED (failures=2)

# %% [markdown]
# Now you should try uploading your code to <a href="https://www.gradescope.com/courses/486387">Gradescope</a>.
#
# **Warning:** For this MP you need to update two files, not just one.
# * `trained_model.npz` should contain your trained model
# * `submitted.py` should contain your code that loads and runs your trained model.
#
# **Warning:** The autograder calculates the average score over ten random games.  If you are getting an average score above 10 almost all the time on your own computer, and if the autograder says you had a score below 10, try resubmitting to see if the next round of random games is better.
#
# **Extra Credit:** Your extra credit should also be uploaded as two files,
# * `trained_model.pkl` should contain your trained model
# * `submitted.py` should contain your code that loads and runs your trained model.
