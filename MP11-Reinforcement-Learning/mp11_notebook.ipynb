# %% [markdown]
# # CS440/ECE448 Spring 2023
# # MP11: Reinforcement Learning

# %% [markdown]
# The first thing you need to do is to download this file: <a href="mp11.zip">mp11.zip</a>.  If you want, you can also download <a href="mp11_extra.zip">mp11_extra.zip</a>, the extra credit assignment.  `mp11.zip` has the following content:
#
# * `submitted.py`: Your homework. Edit, and then submit to <a href="https://www.gradescope.com/courses/486387">Gradescope</a>.
# * `mp11_notebook.ipynb`: This is a <a href="https://anaconda.org/anaconda/jupyter">Jupyter</a> notebook to help you debug.  You can completely ignore it if you want, although you might find that it gives you useful instructions.
# * `pong.py`: This is a program that plays Pong.  If called interactively, it will call the module `pong_display.py` to create a display, so that you can play.  If told to use a Q-learner, it will call your `submitted.py` to do Q-learning.
# * `grade.py`: Once your homework seems to be working, you can test it by typing `python grade.py`, which will run the tests in `tests/tests_visible.py`.
# * `tests/test_visible.py`: This file contains about half of the <a href="https://docs.python.org/3/library/unittest.html">unit tests</a> that Gradescope will run in order to grade your homework.  If you can get a perfect score on these tests, then you should also get a perfect score on the additional hidden tests that Gradescope uses.
# * `requirements.txt`: This tells you which python packages you need to have installed, in order to run `grade.py`.  You can install all of those packages by typing `pip install -r requirements.txt` or `pip3 install -r requirements.txt`.

# %% [markdown]
# This file (`mp11_notebook.ipynb`) will walk you through the whole MP, giving you instructions and debugging tips as you go.
#
# ### Table of Contents
#
# 1. <a href="#section1">Playing Pong</a>
# 1. <a href="#section2">Creating a Q-Learner Object</a>
# 1. <a href="#section3">Epsilon-First Exploration</a>
# 1. <a href="#section4">Q-Learning</a>
# 1. <a href="#section5">Saving and Loading Your Q and N Tables</a>
# 1. <a href="#section6">Exploitation</a>
# 1. <a href="#section7">Acting</a>
# 1. <a href="#section8">Training</a>
# 1. <a href="#section9">Extra Credit</a>
# 1. <a href="#grade">Grade Your Homework</a>

# %% [markdown]
# <a id='section1'></a>

# %% [markdown]
# ## Playing Pong

# %% [markdown]
# Pong was the <a href="https://en.wikipedia.org/wiki/Pong">first video game produced by Atari.</a>  It is a simple game, based on table tennis.  Here is a two-person version of the game: https://commons.wikimedia.org/wiki/File:Pong_Game_Test2.gif
#
# We will be playing a one-person version of the game:
#
# * When the ball hits the top, bottom, or left wall of the playing field, it bounces.
# * The right end of the playing field is open, except for the paddle.  If the ball hits the paddle, it bounces, and the player's score increments by one.  If the ball hits the open space, the game is over; the score resets to zero, and a new game begins.
#
# The game is pretty simple, but in order to get a better feeling for it, you may want to try playing it yourself.  Use the up arrow to move the paddle upward, and the down arrow to move the paddle downward.  See how high you can make your score:

# %%
# !python pong.py
# Out:
# pygame 2.1.3 (SDL 2.0.22, Python 3.11.1)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Completed 0 games, 2 rewards, 369 frames, score 1, max score 1

# %% [markdown]
# Once you figure out how to use the arrow keys to control your paddle, we hope you will find that the game is not too hard for a human to play.  However, for a computer, it's difficult to know: where should the paddle be moved at each time step?  In order to see how difficult it is for a computer to play, let's ask the "random" player to play the game.
#
# **WARNING:** The following line will open a pygame window.  The pygame window will be hidden by this window -- in order to see it, you will need to minimize this window.  The pygame window will consume a lot of CPU time just waiting for the processor, so in order to kill it, you will need to come back to this window, click on the block below, then click the Jupyter "stop" button (the square button at the top of this window) in order to stop processing.

# %%
# !python pong.py --player random
# Out:
# ^C
# pygame 2.1.3 (SDL 2.0.22, Python 3.11.1)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Completed 0 games, 1 rewards, 255 frames, score 0, max score 0
# Completed 1 games, 2 rewards, 509 frames, score 0, max score 0
# Completed 2 games, 3 rewards, 690 frames, score 0, max score 0
# Completed 3 games, 4 rewards, 871 frames, score 0, max score 0

# %% [markdown]
# <a id='section2'></a>

# %% [markdown]
# ## Creating a Q-Learner Object

# %% [markdown]
# The first thing you will do is to create a `q_learner` object that can store your learned Q table and your N table (table of exploration counts).
#
# Like any other object-oriented language, python permits you to create new object classes in order to store data that will be needed from time to time.  If you are not already very, very familiar with python classes, you might want to study the python class tutorial: https://docs.python.org/3/tutorial/classes.html
#
# Like any other object in python, a `q_learner` object is created by calling its name as a function, e.g., `my_q_learner=submitted.q_learner()`.  Doing so calls the function `submitted.q_learner.__init__()`.  Let's look at the docstring to see what it should do.

# %%
import submitted, importlib
importlib.reload(submitted)
help(submitted.q_learner.__init__)
# Out:
# Help on function __init__ in module submitted:
#
# __init__(self, alpha, epsilon, gamma, nfirst, state_cardinality)
#     Create a new q_learner object.
#     Your q_learner object should store the provided values of alpha,
#     epsilon, gamma, and nfirst.
#     It should also create a Q table and an N table.
#     Q[...state..., ...action...] = expected utility of state/action pair.
#     N[...state..., ...action...] = # times state/action has been explored.
#     Both are initialized to all zeros.
#     Up to you: how will you encode the state and action in order to
#     define these two lookup tables?  The state will be a list of 5 integers,
#     such that 0 <= state[i] < state_cardinality[i] for 0 <= i < 5.
#
#     The action will be either -1, 0, or 1.
#     It is up to you to decide how to convert an input state and action
#     into indices that you can use to access your stored Q and N tables.
#
#     @params:
#     alpha (scalar) - learning rate of the Q-learner
#     epsilon (scalar) - probability of taking a random action
#     gamma (scalar) - discount factor
#     nfirst (scalar) - exploring each state/action pair nfirst times before exploiting
#     state_cardinality (list) - cardinality of each of the quantized state variables
#
#     @return:
#     None

# %% [markdown]
# Write your `__init__` function to meet the requirements specified in the docstring.  Once you have completed it, the following code should run without errors:

# %%
importlib.reload(submitted)

q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])

print(q_learner)
# Out:
# <submitted.q_learner object at 0x00000184722F7D90>

# %% [markdown]
# <a id='section3'></a>

# %% [markdown]
# ## Epsilon-First Exploration

# %% [markdown]
# In order to manage the exploration/exploitation tradeoff, we will be using both "epsilon-first" and "epsilon-greedy" (https://en.wikipedia.org/wiki/Multi-armed_bandit#Semi-uniform_strategies).
#
# The epsilon-first strategy explores every state/action pair at least `nfirst` times before it ever starts to exploit any strategy.  Your `q_learner` should have a table to keep track of how many times it has explored a state/action pair prior to the start of any exploitation.  The method for storing that table is up to you; in order to have some standardized API, therefore, you need to write a method called `report_exploration_counts` that returns a list of the three exploration counts for a given state.

# %%
importlib.reload(submitted)
help(submitted.q_learner.report_exploration_counts)
# Out:
# Help on function report_exploration_counts in module submitted:
#
# report_exploration_counts(self, state)
#     Check to see how many times each action has been explored in this state.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     explored_count (array of 3 ints):
#       number of times that each action has been explored from this state.
#       The mapping from actions to integers is up to you, but there must be three of them.

# %% [markdown]
# Write `report_exploration_counts` so that it returns a list or array for any given state.  Test your code with the following:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('This is how many times state [0,0,0,0,0] has been explored so far:')
print(q_learner.report_exploration_counts([0,0,0,0,0]))
print('This is how many times state [9,9,1,1,9] has been explored so far:')
print(q_learner.report_exploration_counts([9,9,1,1,9]))
# Out:
# This is how many times state [0,0,0,0,0] has been explored so far:
# [0.0, 0.0, 0.0]
# This is how many times state [9,9,1,1,9] has been explored so far:
# [0.0, 0.0, 0.0]

# %% [markdown]
# When your learner first starts learning, it will call the function `choose_unexplored_action` to choose an unexplored action.  This function should choose a function uniformly at random from the set of unexplored actions in a given state, if there are any:

# %%
importlib.reload(submitted)
help(submitted.q_learner.choose_unexplored_action)
# Out:
# Help on function choose_unexplored_action in module submitted:
#
# choose_unexplored_action(self, state)
#     Choose an action that has been explored less than nfirst times.
#     If many actions are underexplored, you should choose uniformly
#     from among those actions; don't just choose the first one all
#     the time.
#
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#        These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     action (scalar): either -1, or 0, or 1, or None
#       If all actions have been explored at least n_explore times, return None.
#       Otherwise, choose one uniformly at random from those w/count less than n_explore.
#       When you choose an action, you should increment its count in your counter table.

# %% [markdown]
# If this has been written correctly, the following block should generate a random sequence of actions.  If the next block produces the same action 5 times in a row, that is the wrong result, and the result would be that your code does not pass the autograder.

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
# Out:
# [-1, 0, 1]
# Next action: -1
# [-1, 0, 1]
# Next action: 0
# [-1, 0, 1]
# Next action: 1
# [-1, 0, 1]
# Next action: 0
# [-1, 0, 1]
# Next action: -1

# %% [markdown]
# After all three actions have been explored `nfirst` times, the function `choose_unexplored_action` should return `None`, as shown here:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,1,[10,10,2,2,10])
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
# Out:
# Next action: 1
# Next action: -1
# Next action: 0
# Next action: None

# %% [markdown]
# <a id='section4'></a>

# %% [markdown]
# ## Q-Learning

# %% [markdown]
# The reinforcement learning we are implementing is called Q-learning (https://en.wikipedia.org/wiki/Q-learning).
#
# Q-learning keeps a table $Q[s,a]$ that specifies the expected utility of action $a$ in state $s$.  The organization of this table is up to you.  In order to have a standard API, the first thing you should implement is a function `report_q` with the following docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.report_q)
# Out:
# Help on function report_q in module submitted:
#
# report_q(self, state)
#     Report the current Q values for the given state.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     Q (array of 3 floats):
#       reward plus expected future utility of each of the three actions.
#       The mapping from actions to integers is up to you, but there must be three of them.

# %% [markdown]
# When your `q_learner` is first initialized, the value of $Q[state,action]$ should be zero for all state/action pairs, thus the `report_q` function should return lists of zeros:

# %%
importlib.reload(submitted)
q_learner=submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Q[0,0,0,0,0] is now:',q_learner.report_q([0,0,0,0,0]))
print('Q[9,9,1,1,9] is now:',q_learner.report_q([9,9,1,1,9]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[186], line 3
#       1 importlib.reload(submitted)
#       2 q_learner=submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
# ----> 3 print('Q[0,0,0,0,0] is now:',q_learner.report_q([0,0,0,0,0]))
#       4 print('Q[9,9,1,1,9] is now:',q_learner.report_q([9,9,1,1,9]))
#
# File c:\Users\mycol\CS440\MP11-Reinforcement-Learning\submitted.py:188, in q_learner.report_q(self, state)
#     185 qValues = []
#     187 for action in actions:
# --> 188   qValues.append(self.qTable[key][action])
#     190 return qValues
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %% [markdown]
# There are actually many different Q-learning algorithms available, but when people refer to Q-learning with no modifier, they usually mean the time-difference (TD) algorithm.  For example, this is the algorithm that's described on the wikipedia page (https://en.wikipedia.org/wiki/Q-learning).  This is the algorithm you will implement for this MP.
#
# In supervised machine learning, the learner tries to imitate a reference label.  In reinforcement learning, there is no reference label.  Q-learning replaces the reference label with a "local Q" value, which is the utility that was obtained by performing action $a$ in state $s$ one time.  It is usually calculated like this:
#
# $$Q_{local}(s_t,a_t) = r_t + \gamma\max_{a_{t+1}}Q(s_{t+1},a_{t+1})$$
#
# where $r_t$ is the reward that was achieved by performing action $a_t$ in state $s_t$, $s_{t+1}$ is the state into which the game transitioned, and $a_{t+1}$ is one of the actions that could be performed in that state.  $Q_{local}$ is computed by your `q_local` function, which has this docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.q_local)
# Out:
# Help on function q_local in module submitted:
#
# q_local(self, reward, newstate)
#     The update to Q estimated from a single step of game play:
#     reward plus gamma times the max of Q[newstate, ...].
#
#     @param:
#     reward (scalar float): the reward achieved from the current step of game play.
#     newstate (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     Q_local (scalar float): the local value of Q
#
#     {
#       key: {
#         1: 2,
#         2: 4,
#         5: 1
#       }
#     }

# %% [markdown]
# Initially, `q_local` should just return the given reward, because initially, all Q values are 0:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,10,10])
print('Q_local(6.25,[9,9,1,1,9]) is currently:',q_learner.q_local(6.25,[9,9,1,1,9]))
# Out:
# Q_local(6.25,[9,9,1,1,9]) is currently: 6.25

# %% [markdown]
# Now you can use `q_learner.q_local` as the target for `q_learner.learn`.  The basic algorithm is
#
# $$Q(s,a) = Q(s,a) + \alpha (Q_{local}(s,a)-Q(s,a))$$
#
# Here is the docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.learn)
# Out:
# Help on function learn in module submitted:
#
# learn(self, state, action, reward, newstate)
#     Update the internal Q-table on the basis of an observed
#     state, action, reward, newstate sequence.
#
#     @params:
#     state: a list of 5 numbers: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle.
#     action: an integer, one of -1, 0, or +1
#     reward: a reward; positive for hitting the ball, negative for losing a game
#     newstate: a list of 5 numbers, in the same format as state
#
#     @return:
#     None

# %% [markdown]
# The following block checks a sequence of Q updates:
#
# 1. First, $Q([9,9,1,1,9],-1)$ is updated.  Since all Q values start at zero, it will be updated to just have a value equal to $\alpha$ (0.05) times the given reward (6.25) for a total value of 0.3125.
# 1. When we print out $Q([9,9,1,1,9],:)$, we see that one of the elements has been updated.
# 1. Next, update $Q([9,9,1,1,8],1)$ with a given reward, and with $[9,9,1,1,9]$ as the given next state.  Since $Q([9,9,1,1,9],-1)$ is larger than zero, the next-state Q-value should be multiplied by $\gamma$ (0.99) and added to the reward (3.1), then multiplied by $\alpha$, giving a total value of 0.17046875.
# 1. The resulting Q-value is reported.

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
q_learner.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('Q[9,9,1,1,9] is now',q_learner.report_q([9,9,1,1,9]))
q_learner.learn([9,9,1,1,8],1,3.1,[9,9,1,1,9])
print('Q[9,9,1,1,8] is now',q_learner.report_q([9,9,1,1,8]))
# Out:
# Q[9,9,1,1,9] is now [0.3125, 0.0, 0.0]
# Q[9,9,1,1,8] is now [0.0, 0.0, 0.17046875000000003]

# %% [markdown]
# <a id='section5'></a>

# %% [markdown]
# ## Saving and Loading your Q and N Tables

# %% [markdown]
# After you've spent a long time training your `q_learner`, you will want to save your Q and N tables so that you can reload them later.  The format of Q and N is up to you, therefore it's also up to you to write the `save` and `load` functions.  Here are the docstrings:

# %%
importlib.reload(submitted)
help(submitted.q_learner.save)
# Out:
# Help on function save in module submitted:
#
# save(self, filename)
#     Save your Q and N tables to a file.
#     This can save in any format you like, as long as your "load"
#     function uses the same file format.  We recommend numpy.savez,
#     but you can use something else if you prefer.
#
#     @params:
#     filename (str) - filename to which it should be saved
#     @return:
#     None

# %%
importlib.reload(submitted)
help(submitted.q_learner.load)
# Out:
# Help on function load in module submitted:
#
# load(self, filename)
#     Load the Q and N tables from a file.
#     This should load from whatever file format your save function
#     used.  We recommend numpy.load, but you can use something
#     else if you prefer.
#
#     @params:
#     filename (str) - filename from which it should be loaded
#     @return:
#     None

# %% [markdown]
# These functions can be tested by doing one step of training one `q_learner`, then saving its results, then loading them into another `q_learner`:

# %%
importlib.reload(submitted)
q_learner1 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Next action:',q_learner1.choose_unexplored_action([9,9,1,1,9]))
q_learner1.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('N1[9,9,1,1,8] is now',q_learner1.report_exploration_counts([9,9,1,1,9]))
print('Q1[9,9,1,1,8] is now',q_learner1.report_q([9,9,1,1,9]))
q_learner1.save('test.npz')

q_learner2 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('N2[9,9,1,1,8] starts out as',q_learner2.report_exploration_counts([9,9,1,1,9]))
print('Q2[9,9,1,1,8] starts out as',q_learner2.report_q([9,9,1,1,9]))
q_learner2.load('test.npz')
print('N2[9,9,1,1,8] is now',q_learner2.report_exploration_counts([9,9,1,1,9]))
print('Q2[9,9,1,1,8] is now',q_learner2.report_q([9,9,1,1,9]))
# Out:
# Next action: -1
# N1[9,9,1,1,8] is now [0.0, 0.0, 1.0]
# Q1[9,9,1,1,8] is now [0.3125, 0.0, 0.0]
# N2[9,9,1,1,8] starts out as [0.0, 0.0, 0.0]
# Q2[9,9,1,1,8] starts out as [0.0, 0.0, 0.0]
# N2[9,9,1,1,8] is now [0.0, 0.0, 0.0]
# Q2[9,9,1,1,8] is now [0.0, 0.0, 0.0]

# %% [markdown]
# <a id='section6'></a>

# %% [markdown]
# ## Exploitation

# %% [markdown]
# A reinforcement learner always has to trade off between exploration (choosing an action at random) versus exploitation (choosing the action with the maximum expected utility).  Before we worry about that tradeoff, though, let's first make sure that exploitation works.

# %%
importlib.reload(submitted)
help(submitted.q_learner.exploit)
# Out:
# Help on function exploit in module submitted:
#
# exploit(self, state)
#     Return the action that has the highest Q-value for the current state, and its Q-value.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     action (scalar int): either -1, or 0, or 1.
#       The action that has the highest Q-value.  Ties can be broken any way you want.
#     Q (scalar float):
#       The Q-value of the selected action

# %%
importlib.reload(submitted)
q_learner1 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
q_learner1.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('Q1[9,9,1,1,9] is now',q_learner1.report_q([9,9,1,1,9]))
print('The best action and Q from state [9,9,1,1,9] are',q_learner1.exploit([9,9,1,1,9]))
# Out:
# Q1[9,9,1,1,9] is now [0.3125, 0.0, 0.0]
# The best action and Q from state [9,9,1,1,9] are (-1, 0.3125)

# %% [markdown]
# <a id='section7'></a>

# %% [markdown]
# ## Acting

# %% [markdown]
# When your learner decides which action to perform, it should trade off exploration vs. exploitation using both the epsilon-first and the epsilon-greedy strategies:
# 1. If there is any action that has been explored fewer than `nfirst` times, then choose one of those actions at random.  Otherwise...
# 1. With probability `epsilon`, choose an action at random.  Otherwise...
# 1. Exploit.

# %%
importlib.reload(submitted)
help(submitted.q_learner.act)
# Out:
# Help on function act in module submitted:
#
# act(self, state)
#     Decide what action to take in the current state.
#     If any action has been taken less than nfirst times, then choose one of those
#     actions, uniformly at random.
#     Otherwise, with probability epsilon, choose an action uniformly at random.
#     Otherwise, choose the action with the best Q(state,action).
#
#     @params:
#     state: a list of 5 integers: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     -1 if the paddle should move upward
#     0 if the paddle should be stationary
#     1 if the paddle should move downward

# %% [markdown]
# In order to test all three types of action (epsilon-first exploration, epsilon-greedy exploration, and exploitation), let's create a learner with `nfirst=1` and `epsilon=0.25`, and set it so that the best action from state `[9,9,1,1,9]` is `-1`.  With these settings, a sequence of calls to `q_learner.act` should produce the following sequence of actions:
#
# 1. The first three actions should include each possible action once.
# 1. After the first three actions, 3/4 of the remaining actions should be `-1`.  The remaining 1/4 should be randomly chosen.

# %%
importlib.reload(submitted)
q_learner=submitted.q_learner(0.05,0.25,0.99,1,[10,10,2,2,10])
q_learner.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
# Out:
# An epsilon-first action: 0
# An epsilon-first action: -1
# An epsilon-first action: 1
# An epsilon-greedy explore/exploit action: None
# An epsilon-greedy explore/exploit action: None
# An epsilon-greedy explore/exploit action: None
# An epsilon-greedy explore/exploit action: None
# An epsilon-greedy explore/exploit action: None
# An epsilon-greedy explore/exploit action: None
# An epsilon-greedy explore/exploit action: None
# An epsilon-greedy explore/exploit action: None
# An epsilon-greedy explore/exploit action: None
# An epsilon-greedy explore/exploit action: None
# An epsilon-greedy explore/exploit action: None
# An epsilon-greedy explore/exploit action: None

# %% [markdown]
# <a id='section8'></a>

# %% [markdown]
# ## Training

# %% [markdown]
# Now that all of your components work, you can try training your algorithm.  Do this by giving your `q_learner` as a player to a new `pong.PongGame` object.  Set `visibility=False` so that the `PongGame` doesn't create a new window.

# %%
import pong, importlib, submitted
importlib.reload(pong)
help(pong.PongGame.__init__)
# Out:
# Help on function __init__ in module pong:
#
# __init__(self, ball_speed=4, paddle_speed=8, learner=None, visible=True, state_quantization=[10, 10, 2, 2, 10])
#     Create a new pong game, with a specified player.
#
#     @params:
#     ball_speed (scalar int) - average ball speed in pixels/frame
#     paddle_speed (scalar int) - paddle moves 0, +paddle_speed, or -paddle_speed
#     learner - can be None if the player is human.  If not None, should be an
#       object of type random_learner, submitted.q_learner, or submitted.deep_q.
#     visible (bool) - should this game have an attached pygame window?
#     state_quantization (list) - if not None, state variables are quantized
#       into integers of these cardinalities before being passed to the learner.

# %% [markdown]
# As you can see, we should set `visibility=False` so that the `PongGame` doesn't create a new window.  We should also make sure that the PongGame uses the same state quantization as the learner.

# %%
importlib.reload(pong)
importlib.reload(submitted)
state_quantization = [10,10,2,2,10]
q_learner=submitted.q_learner(0.05,0.05,0.99,5,state_quantization)

pong_game = pong.PongGame(learner=q_learner, visible=False, state_quantization=state_quantization)
print(pong_game)
# Out:
# <pong.PongGame object at 0x00000184956A4A10>

# %% [markdown]
# In order to train our learner, we want it to play the game many times.  To do that we use the PongGame.run function:

# %%
help(pong_game.run)
# Out:
# Help on method run in module pong:
#
# run(m_rewards=inf, m_games=inf, m_frames=inf, states=[]) method of pong.PongGame instance
#     Run the game.
#     @param
#     m_frames (scalar int): maximum number of frames to be played
#     m_rewards (scalar int): maximum number of rewards earned (+ or -)
#     m_games (scalar int): maximum number of games
#     states (list): list of states whose Q-values should be returned
#        each state is a list of 5 ints: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#        These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#        and the y-position of the paddle, all quantized.
#        0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#
#     @return
#     scores (list): list of scores of all completed games
#
#     The following will be returned only if the player is q_learning or deep_q.
#     New elements will be added to these lists once/frame if m_frames is specified,
#     else once/reward if m_rewards is specified, else once/game:
#       q_achieved (list): list of the q-values of the moves that were taken
#       q_states (list): list of the q-values of requested states

# %% [markdown]
# In order to make sure our learner is learning, let's tell `pong_game.run` to output all 3 Q-values of all of the 4000 states in every time step.
#
# To make sure that's not an outrageous amount of data, let's tell it to only output the Q values once/reward, and ask it to only collect 5000 rewards:

# %%
states = [[x,y,vx,vy,py] for x in range(10) for y in range(10) for vx in range(2) for vy in range(2) for py in range(10) ]

scores, q_achieved, q_states = pong_game.run(m_rewards=500, states=states)

print('The number of games played was',len(scores))
print('The number of rewards was',len(q_states))
print('The size of each returned Q-matrix was',q_states[0].shape)
# Out:
# Completed 0 games, 2 rewards, 353 frames, score 1, max score 1
# Completed 1 games, 3 rewards, 561 frames, score 0, max score 1
# Completed 2 games, 5 rewards, 989 frames, score 1, max score 1
# Completed 3 games, 6 rewards, 1197 frames, score 0, max score 1
# Completed 4 games, 7 rewards, 1378 frames, score 0, max score 1
# Completed 5 games, 9 rewards, 1838 frames, score 1, max score 1
# Completed 6 games, 10 rewards, 2046 frames, score 0, max score 1
# Completed 7 games, 11 rewards, 2254 frames, score 0, max score 1
# Completed 8 games, 12 rewards, 2508 frames, score 0, max score 1
# Completed 9 games, 13 rewards, 2762 frames, score 0, max score 1
# Completed 10 games, 14 rewards, 2943 frames, score 0, max score 1
# Completed 11 games, 15 rewards, 3124 frames, score 0, max score 1
# Completed 12 games, 18 rewards, 3707 frames, score 2, max score 2
# Completed 13 games, 19 rewards, 3915 frames, score 0, max score 2
# Completed 14 games, 20 rewards, 4169 frames, score 0, max score 2
# Completed 15 games, 21 rewards, 4350 frames, score 0, max score 2
# Completed 16 games, 22 rewards, 4558 frames, score 0, max score 2
# Completed 17 games, 25 rewards, 5173 frames, score 2, max score 2
# Completed 18 games, 26 rewards, 5354 frames, score 0, max score 2
# Completed 19 games, 27 rewards, 5562 frames, score 0, max score 2
# Completed 20 games, 28 rewards, 5743 frames, score 0, max score 2
# Completed 21 games, 29 rewards, 5997 frames, score 0, max score 2
# Completed 22 games, 30 rewards, 6251 frames, score 0, max score 2
# Completed 23 games, 31 rewards, 6432 frames, score 0, max score 2
# Completed 24 games, 32 rewards, 6640 frames, score 0, max score 2
# Completed 25 games, 34 rewards, 7128 frames, score 1, max score 2
# Completed 26 games, 35 rewards, 7336 frames, score 0, max score 2
# Completed 27 games, 36 rewards, 7544 frames, score 0, max score 2
# Completed 28 games, 38 rewards, 7968 frames, score 1, max score 2
# Completed 29 games, 40 rewards, 8336 frames, score 1, max score 2
# Completed 30 games, 42 rewards, 9070 frames, score 1, max score 2
# Completed 31 games, 43 rewards, 9324 frames, score 0, max score 2
# Completed 32 games, 45 rewards, 9761 frames, score 1, max score 2
# Completed 33 games, 46 rewards, 10015 frames, score 0, max score 2
# Completed 34 games, 49 rewards, 10764 frames, score 2, max score 2
# Completed 35 games, 50 rewards, 10945 frames, score 0, max score 2
# Completed 36 games, 51 rewards, 11199 frames, score 0, max score 2
# Completed 37 games, 53 rewards, 11789 frames, score 1, max score 2
# Completed 38 games, 54 rewards, 12043 frames, score 0, max score 2
# Completed 39 games, 57 rewards, 12677 frames, score 2, max score 2
# Completed 40 games, 59 rewards, 13045 frames, score 1, max score 2
# Completed 41 games, 61 rewards, 13505 frames, score 1, max score 2
# Completed 42 games, 62 rewards, 13713 frames, score 0, max score 2
# Completed 43 games, 64 rewards, 14054 frames, score 1, max score 2
# Completed 44 games, 65 rewards, 14262 frames, score 0, max score 2
# Completed 45 games, 67 rewards, 14759 frames, score 1, max score 2
# Completed 46 games, 68 rewards, 15013 frames, score 0, max score 2
# Completed 47 games, 69 rewards, 15194 frames, score 0, max score 2
# Completed 48 games, 70 rewards, 15448 frames, score 0, max score 2
# Completed 49 games, 73 rewards, 16215 frames, score 2, max score 2
# Completed 50 games, 74 rewards, 16423 frames, score 0, max score 2
# Completed 51 games, 75 rewards, 16631 frames, score 0, max score 2
# Completed 52 games, 76 rewards, 16812 frames, score 0, max score 2
# Completed 53 games, 77 rewards, 17066 frames, score 0, max score 2
# Completed 54 games, 78 rewards, 17247 frames, score 0, max score 2
# Completed 55 games, 80 rewards, 17847 frames, score 1, max score 2
# Completed 56 games, 81 rewards, 18055 frames, score 0, max score 2
# Completed 57 games, 82 rewards, 18263 frames, score 0, max score 2
# Completed 58 games, 84 rewards, 18646 frames, score 1, max score 2
# Completed 59 games, 85 rewards, 18900 frames, score 0, max score 2
# Completed 60 games, 86 rewards, 19108 frames, score 0, max score 2
# Completed 61 games, 87 rewards, 19316 frames, score 0, max score 2
# Completed 62 games, 88 rewards, 19524 frames, score 0, max score 2
# Completed 63 games, 92 rewards, 20301 frames, score 3, max score 3
# Completed 64 games, 93 rewards, 20482 frames, score 0, max score 3
# Completed 65 games, 94 rewards, 20690 frames, score 0, max score 3
# Completed 66 games, 95 rewards, 20898 frames, score 0, max score 3
# Completed 67 games, 96 rewards, 21079 frames, score 0, max score 3
# Completed 68 games, 97 rewards, 21333 frames, score 0, max score 3
# Completed 69 games, 99 rewards, 21884 frames, score 1, max score 3
# Completed 70 games, 101 rewards, 22546 frames, score 1, max score 3
# Completed 71 games, 103 rewards, 22898 frames, score 1, max score 3
# Completed 72 games, 104 rewards, 23106 frames, score 0, max score 3
# Completed 73 games, 107 rewards, 23842 frames, score 2, max score 3
# Completed 74 games, 108 rewards, 24050 frames, score 0, max score 3
# Completed 75 games, 109 rewards, 24258 frames, score 0, max score 3
# Completed 76 games, 112 rewards, 24738 frames, score 2, max score 3
# Completed 77 games, 114 rewards, 25235 frames, score 1, max score 3
# Completed 78 games, 117 rewards, 26549 frames, score 2, max score 3
# Completed 79 games, 118 rewards, 26757 frames, score 0, max score 3
# Completed 80 games, 119 rewards, 26938 frames, score 0, max score 3
# Completed 81 games, 120 rewards, 27119 frames, score 0, max score 3
# Completed 82 games, 121 rewards, 27373 frames, score 0, max score 3
# Completed 83 games, 122 rewards, 27627 frames, score 0, max score 3
# Completed 84 games, 123 rewards, 27881 frames, score 0, max score 3
# Completed 85 games, 124 rewards, 28089 frames, score 0, max score 3
# Completed 86 games, 125 rewards, 28343 frames, score 0, max score 3
# Completed 87 games, 126 rewards, 28524 frames, score 0, max score 3
# Completed 88 games, 127 rewards, 28705 frames, score 0, max score 3
# Completed 89 games, 128 rewards, 28959 frames, score 0, max score 3
# Completed 90 games, 129 rewards, 29213 frames, score 0, max score 3
# Completed 91 games, 130 rewards, 29467 frames, score 0, max score 3
# Completed 92 games, 131 rewards, 29648 frames, score 0, max score 3
# Completed 93 games, 133 rewards, 29989 frames, score 1, max score 3
# Completed 94 games, 134 rewards, 30197 frames, score 0, max score 3
# Completed 95 games, 135 rewards, 30378 frames, score 0, max score 3
# Completed 96 games, 136 rewards, 30632 frames, score 0, max score 3
# Completed 97 games, 137 rewards, 30813 frames, score 0, max score 3
# Completed 98 games, 138 rewards, 31021 frames, score 0, max score 3
# Completed 99 games, 139 rewards, 31275 frames, score 0, max score 3
# Completed 100 games, 142 rewards, 31909 frames, score 2, max score 3
# Completed 101 games, 144 rewards, 32421 frames, score 1, max score 3
# Completed 102 games, 148 rewards, 33132 frames, score 3, max score 3
# Completed 103 games, 150 rewards, 33734 frames, score 1, max score 3
# Completed 104 games, 151 rewards, 33942 frames, score 0, max score 3
# Completed 105 games, 152 rewards, 34150 frames, score 0, max score 3
# Completed 106 games, 156 rewards, 35312 frames, score 3, max score 3
# Completed 107 games, 157 rewards, 35520 frames, score 0, max score 3
# Completed 108 games, 158 rewards, 35774 frames, score 0, max score 3
# Completed 109 games, 160 rewards, 36245 frames, score 1, max score 3
# Completed 110 games, 161 rewards, 36499 frames, score 0, max score 3
# Completed 111 games, 163 rewards, 36851 frames, score 1, max score 3
# Completed 112 games, 165 rewards, 37192 frames, score 1, max score 3
# Completed 113 games, 166 rewards, 37373 frames, score 0, max score 3
# Completed 114 games, 167 rewards, 37554 frames, score 0, max score 3
# Completed 115 games, 168 rewards, 37735 frames, score 0, max score 3
# Completed 116 games, 169 rewards, 37943 frames, score 0, max score 3
# Completed 117 games, 170 rewards, 38124 frames, score 0, max score 3
# Completed 118 games, 171 rewards, 38332 frames, score 0, max score 3
# Completed 119 games, 172 rewards, 38513 frames, score 0, max score 3
# Completed 120 games, 173 rewards, 38767 frames, score 0, max score 3
# Completed 121 games, 176 rewards, 39630 frames, score 2, max score 3
# Completed 122 games, 177 rewards, 39838 frames, score 0, max score 3
# Completed 123 games, 178 rewards, 40046 frames, score 0, max score 3
# Completed 124 games, 179 rewards, 40227 frames, score 0, max score 3
# Completed 125 games, 180 rewards, 40408 frames, score 0, max score 3
# Completed 126 games, 181 rewards, 40662 frames, score 0, max score 3
# Completed 127 games, 183 rewards, 41213 frames, score 1, max score 3
# Completed 128 games, 184 rewards, 41394 frames, score 0, max score 3
# Completed 129 games, 185 rewards, 41648 frames, score 0, max score 3
# Completed 130 games, 186 rewards, 41829 frames, score 0, max score 3
# Completed 131 games, 187 rewards, 42083 frames, score 0, max score 3
# Completed 132 games, 188 rewards, 42291 frames, score 0, max score 3
# Completed 133 games, 190 rewards, 42953 frames, score 1, max score 3
# Completed 134 games, 191 rewards, 43161 frames, score 0, max score 3
# Completed 135 games, 194 rewards, 44538 frames, score 2, max score 3
# Completed 136 games, 195 rewards, 44719 frames, score 0, max score 3
# Completed 137 games, 196 rewards, 44973 frames, score 0, max score 3
# Completed 138 games, 197 rewards, 45227 frames, score 0, max score 3
# Completed 139 games, 198 rewards, 45435 frames, score 0, max score 3
# Completed 140 games, 199 rewards, 45689 frames, score 0, max score 3
# Completed 141 games, 200 rewards, 45897 frames, score 0, max score 3
# Completed 142 games, 201 rewards, 46105 frames, score 0, max score 3
# Completed 143 games, 203 rewards, 46473 frames, score 1, max score 3
# Completed 144 games, 205 rewards, 46841 frames, score 1, max score 3
# Completed 145 games, 206 rewards, 47095 frames, score 0, max score 3
# Completed 146 games, 207 rewards, 47276 frames, score 0, max score 3
# Completed 147 games, 208 rewards, 47457 frames, score 0, max score 3
# Completed 148 games, 210 rewards, 47867 frames, score 1, max score 3
# Completed 149 games, 213 rewards, 48416 frames, score 2, max score 3
# Completed 150 games, 214 rewards, 48670 frames, score 0, max score 3
# Completed 151 games, 215 rewards, 48851 frames, score 0, max score 3
# Completed 152 games, 216 rewards, 49032 frames, score 0, max score 3
# Completed 153 games, 219 rewards, 49795 frames, score 2, max score 3
# Completed 154 games, 220 rewards, 50049 frames, score 0, max score 3
# Completed 155 games, 222 rewards, 50567 frames, score 1, max score 3
# Completed 156 games, 226 rewards, 51416 frames, score 3, max score 3
# Completed 157 games, 227 rewards, 51597 frames, score 0, max score 3
# Completed 158 games, 228 rewards, 51805 frames, score 0, max score 3
# Completed 159 games, 229 rewards, 51986 frames, score 0, max score 3
# Completed 160 games, 230 rewards, 52240 frames, score 0, max score 3
# Completed 161 games, 231 rewards, 52421 frames, score 0, max score 3
# Completed 162 games, 234 rewards, 53278 frames, score 2, max score 3
# Completed 163 games, 235 rewards, 53459 frames, score 0, max score 3
# Completed 164 games, 236 rewards, 53667 frames, score 0, max score 3
# Completed 165 games, 237 rewards, 53875 frames, score 0, max score 3
# Completed 166 games, 238 rewards, 54129 frames, score 0, max score 3
# Completed 167 games, 239 rewards, 54310 frames, score 0, max score 3
# Completed 168 games, 240 rewards, 54491 frames, score 0, max score 3
# Completed 169 games, 241 rewards, 54745 frames, score 0, max score 3
# Completed 170 games, 242 rewards, 54953 frames, score 0, max score 3
# Completed 171 games, 243 rewards, 55134 frames, score 0, max score 3
# Completed 172 games, 244 rewards, 55315 frames, score 0, max score 3
# Completed 173 games, 245 rewards, 55569 frames, score 0, max score 3
# Completed 174 games, 246 rewards, 55823 frames, score 0, max score 3
# Completed 175 games, 247 rewards, 56004 frames, score 0, max score 3
# Completed 176 games, 248 rewards, 56258 frames, score 0, max score 3
# Completed 177 games, 249 rewards, 56466 frames, score 0, max score 3
# Completed 178 games, 251 rewards, 56926 frames, score 1, max score 3
# Completed 179 games, 252 rewards, 57107 frames, score 0, max score 3
# Completed 180 games, 253 rewards, 57361 frames, score 0, max score 3
# Completed 181 games, 254 rewards, 57615 frames, score 0, max score 3
# Completed 182 games, 255 rewards, 57823 frames, score 0, max score 3
# Completed 183 games, 256 rewards, 58077 frames, score 0, max score 3
# Completed 184 games, 257 rewards, 58258 frames, score 0, max score 3
# Completed 185 games, 258 rewards, 58512 frames, score 0, max score 3
# Completed 186 games, 262 rewards, 59448 frames, score 3, max score 3
# Completed 187 games, 263 rewards, 59629 frames, score 0, max score 3
# Completed 188 games, 264 rewards, 59883 frames, score 0, max score 3
# Completed 189 games, 266 rewards, 60545 frames, score 1, max score 3
# Completed 190 games, 267 rewards, 60753 frames, score 0, max score 3
# Completed 191 games, 268 rewards, 60961 frames, score 0, max score 3
# Completed 192 games, 269 rewards, 61142 frames, score 0, max score 3
# Completed 193 games, 270 rewards, 61396 frames, score 0, max score 3
# Completed 194 games, 271 rewards, 61650 frames, score 0, max score 3
# Completed 195 games, 272 rewards, 61831 frames, score 0, max score 3
# Completed 196 games, 273 rewards, 62039 frames, score 0, max score 3
# Completed 197 games, 274 rewards, 62220 frames, score 0, max score 3
# Completed 198 games, 275 rewards, 62474 frames, score 0, max score 3
# Completed 199 games, 276 rewards, 62728 frames, score 0, max score 3
# Completed 200 games, 277 rewards, 62982 frames, score 0, max score 3
# Completed 201 games, 282 rewards, 64011 frames, score 4, max score 4
# Completed 202 games, 285 rewards, 64641 frames, score 2, max score 4
# Completed 203 games, 286 rewards, 64849 frames, score 0, max score 4
# Completed 204 games, 287 rewards, 65103 frames, score 0, max score 4
# Completed 205 games, 289 rewards, 66022 frames, score 1, max score 4
# Completed 206 games, 290 rewards, 66230 frames, score 0, max score 4
# Completed 207 games, 291 rewards, 66411 frames, score 0, max score 4
# Completed 208 games, 292 rewards, 66619 frames, score 0, max score 4
# Completed 209 games, 294 rewards, 67079 frames, score 1, max score 4
# Completed 210 games, 295 rewards, 67333 frames, score 0, max score 4
# Completed 211 games, 296 rewards, 67541 frames, score 0, max score 4
# Completed 212 games, 297 rewards, 67749 frames, score 0, max score 4
# Completed 213 games, 298 rewards, 67957 frames, score 0, max score 4
# Completed 214 games, 300 rewards, 68491 frames, score 1, max score 4
# Completed 215 games, 301 rewards, 68745 frames, score 0, max score 4
# Completed 216 games, 302 rewards, 68953 frames, score 0, max score 4
# Completed 217 games, 303 rewards, 69161 frames, score 0, max score 4
# Completed 218 games, 304 rewards, 69369 frames, score 0, max score 4
# Completed 219 games, 305 rewards, 69623 frames, score 0, max score 4
# Completed 220 games, 306 rewards, 69877 frames, score 0, max score 4
# Completed 221 games, 307 rewards, 70085 frames, score 0, max score 4
# Completed 222 games, 308 rewards, 70266 frames, score 0, max score 4
# Completed 223 games, 309 rewards, 70447 frames, score 0, max score 4
# Completed 224 games, 310 rewards, 70628 frames, score 0, max score 4
# Completed 225 games, 311 rewards, 70836 frames, score 0, max score 4
# Completed 226 games, 312 rewards, 71044 frames, score 0, max score 4
# Completed 227 games, 313 rewards, 71252 frames, score 0, max score 4
# Completed 228 games, 314 rewards, 71460 frames, score 0, max score 4
# Completed 229 games, 315 rewards, 71714 frames, score 0, max score 4
# Completed 230 games, 316 rewards, 71968 frames, score 0, max score 4
# Completed 231 games, 317 rewards, 72149 frames, score 0, max score 4
# Completed 232 games, 318 rewards, 72330 frames, score 0, max score 4
# Completed 233 games, 319 rewards, 72511 frames, score 0, max score 4
# Completed 234 games, 320 rewards, 72719 frames, score 0, max score 4
# Completed 235 games, 321 rewards, 72973 frames, score 0, max score 4
# Completed 236 games, 322 rewards, 73154 frames, score 0, max score 4
# Completed 237 games, 323 rewards, 73408 frames, score 0, max score 4
# Completed 238 games, 324 rewards, 73616 frames, score 0, max score 4
# Completed 239 games, 325 rewards, 73824 frames, score 0, max score 4
# Completed 240 games, 326 rewards, 74032 frames, score 0, max score 4
# Completed 241 games, 327 rewards, 74240 frames, score 0, max score 4
# Completed 242 games, 328 rewards, 74448 frames, score 0, max score 4
# Completed 243 games, 330 rewards, 75182 frames, score 1, max score 4
# Completed 244 games, 331 rewards, 75390 frames, score 0, max score 4
# Completed 245 games, 333 rewards, 75861 frames, score 1, max score 4
# Completed 246 games, 334 rewards, 76042 frames, score 0, max score 4
# Completed 247 games, 335 rewards, 76223 frames, score 0, max score 4
# Completed 248 games, 336 rewards, 76477 frames, score 0, max score 4
# Completed 249 games, 337 rewards, 76731 frames, score 0, max score 4
# Completed 250 games, 338 rewards, 76939 frames, score 0, max score 4
# Completed 251 games, 340 rewards, 77451 frames, score 1, max score 4
# Completed 252 games, 341 rewards, 77705 frames, score 0, max score 4
# Completed 253 games, 342 rewards, 77886 frames, score 0, max score 4
# Completed 254 games, 343 rewards, 78140 frames, score 0, max score 4
# Completed 255 games, 344 rewards, 78394 frames, score 0, max score 4
# Completed 256 games, 346 rewards, 78831 frames, score 1, max score 4
# Completed 257 games, 348 rewards, 79268 frames, score 1, max score 4
# Completed 258 games, 349 rewards, 79522 frames, score 0, max score 4
# Completed 259 games, 350 rewards, 79730 frames, score 0, max score 4
# Completed 260 games, 351 rewards, 79911 frames, score 0, max score 4
# Completed 261 games, 352 rewards, 80119 frames, score 0, max score 4
# Completed 262 games, 353 rewards, 80373 frames, score 0, max score 4
# Completed 263 games, 357 rewards, 81011 frames, score 3, max score 4
# Completed 264 games, 358 rewards, 81192 frames, score 0, max score 4
# Completed 265 games, 359 rewards, 81446 frames, score 0, max score 4
# Completed 266 games, 360 rewards, 81700 frames, score 0, max score 4
# Completed 267 games, 361 rewards, 81908 frames, score 0, max score 4
# Completed 268 games, 362 rewards, 82089 frames, score 0, max score 4
# Completed 269 games, 363 rewards, 82270 frames, score 0, max score 4
# Completed 270 games, 366 rewards, 82898 frames, score 2, max score 4
# Completed 271 games, 367 rewards, 83106 frames, score 0, max score 4
# Completed 272 games, 369 rewards, 83543 frames, score 1, max score 4
# Completed 273 games, 370 rewards, 83797 frames, score 0, max score 4
# Completed 274 games, 371 rewards, 84051 frames, score 0, max score 4
# Completed 275 games, 372 rewards, 84232 frames, score 0, max score 4
# Completed 276 games, 374 rewards, 84692 frames, score 1, max score 4
# Completed 277 games, 375 rewards, 84946 frames, score 0, max score 4
# Completed 278 games, 377 rewards, 85608 frames, score 1, max score 4
# Completed 279 games, 378 rewards, 85862 frames, score 0, max score 4
# Completed 280 games, 379 rewards, 86043 frames, score 0, max score 4
# Completed 281 games, 381 rewards, 86594 frames, score 1, max score 4
# Completed 282 games, 382 rewards, 86802 frames, score 0, max score 4
# Completed 283 games, 383 rewards, 87056 frames, score 0, max score 4
# Completed 284 games, 384 rewards, 87310 frames, score 0, max score 4
# Completed 285 games, 385 rewards, 87518 frames, score 0, max score 4
# Completed 286 games, 386 rewards, 87772 frames, score 0, max score 4
# Completed 287 games, 387 rewards, 87980 frames, score 0, max score 4
# Completed 288 games, 388 rewards, 88234 frames, score 0, max score 4
# Completed 289 games, 390 rewards, 88648 frames, score 1, max score 4
# Completed 290 games, 391 rewards, 88829 frames, score 0, max score 4
# Completed 291 games, 392 rewards, 89083 frames, score 0, max score 4
# Completed 292 games, 393 rewards, 89291 frames, score 0, max score 4
# Completed 293 games, 394 rewards, 89499 frames, score 0, max score 4
# Completed 294 games, 395 rewards, 89753 frames, score 0, max score 4
# Completed 295 games, 396 rewards, 89934 frames, score 0, max score 4
# Completed 296 games, 397 rewards, 90142 frames, score 0, max score 4
# Completed 297 games, 398 rewards, 90350 frames, score 0, max score 4
# Completed 298 games, 399 rewards, 90604 frames, score 0, max score 4
# Completed 299 games, 400 rewards, 90812 frames, score 0, max score 4
# Completed 300 games, 401 rewards, 91020 frames, score 0, max score 4
# Completed 301 games, 402 rewards, 91228 frames, score 0, max score 4
# Completed 302 games, 404 rewards, 91611 frames, score 1, max score 4
# Completed 303 games, 405 rewards, 91792 frames, score 0, max score 4
# Completed 304 games, 406 rewards, 92000 frames, score 0, max score 4
# Completed 305 games, 408 rewards, 92383 frames, score 1, max score 4
# Completed 306 games, 409 rewards, 92564 frames, score 0, max score 4
# Completed 307 games, 410 rewards, 92745 frames, score 0, max score 4
# Completed 308 games, 411 rewards, 92953 frames, score 0, max score 4
# Completed 309 games, 412 rewards, 93134 frames, score 0, max score 4
# Completed 310 games, 414 rewards, 93685 frames, score 1, max score 4
# Completed 311 games, 415 rewards, 93893 frames, score 0, max score 4
# Completed 312 games, 416 rewards, 94147 frames, score 0, max score 4
# Completed 313 games, 417 rewards, 94355 frames, score 0, max score 4
# Completed 314 games, 419 rewards, 95089 frames, score 1, max score 4
# Completed 315 games, 420 rewards, 95270 frames, score 0, max score 4
# Completed 316 games, 421 rewards, 95478 frames, score 0, max score 4
# Completed 317 games, 422 rewards, 95732 frames, score 0, max score 4
# Completed 318 games, 423 rewards, 95913 frames, score 0, max score 4
# Completed 319 games, 424 rewards, 96167 frames, score 0, max score 4
# Completed 320 games, 425 rewards, 96421 frames, score 0, max score 4
# Completed 321 games, 427 rewards, 96773 frames, score 1, max score 4
# Completed 322 games, 429 rewards, 97236 frames, score 1, max score 4
# Completed 323 games, 430 rewards, 97417 frames, score 0, max score 4
# Completed 324 games, 431 rewards, 97671 frames, score 0, max score 4
# Completed 325 games, 432 rewards, 97852 frames, score 0, max score 4
# Completed 326 games, 433 rewards, 98106 frames, score 0, max score 4
# Completed 327 games, 435 rewards, 98534 frames, score 1, max score 4
# Completed 328 games, 436 rewards, 98715 frames, score 0, max score 4
# Completed 329 games, 437 rewards, 98923 frames, score 0, max score 4
# Completed 330 games, 439 rewards, 99291 frames, score 1, max score 4
# Completed 331 games, 440 rewards, 99472 frames, score 0, max score 4
# Completed 332 games, 441 rewards, 99653 frames, score 0, max score 4
# Completed 333 games, 443 rewards, 100051 frames, score 1, max score 4
# Completed 334 games, 444 rewards, 100259 frames, score 0, max score 4
# Completed 335 games, 445 rewards, 100513 frames, score 0, max score 4
# Completed 336 games, 446 rewards, 100721 frames, score 0, max score 4
# Completed 337 games, 447 rewards, 100975 frames, score 0, max score 4
# Completed 338 games, 448 rewards, 101156 frames, score 0, max score 4
# Completed 339 games, 449 rewards, 101410 frames, score 0, max score 4
# Completed 340 games, 450 rewards, 101664 frames, score 0, max score 4
# Completed 341 games, 452 rewards, 102124 frames, score 1, max score 4
# Completed 342 games, 453 rewards, 102378 frames, score 0, max score 4
# Completed 343 games, 454 rewards, 102632 frames, score 0, max score 4
# Completed 344 games, 455 rewards, 102840 frames, score 0, max score 4
# Completed 345 games, 458 rewards, 103405 frames, score 2, max score 4
# Completed 346 games, 459 rewards, 103613 frames, score 0, max score 4
# Completed 347 games, 463 rewards, 104466 frames, score 3, max score 4
# Completed 348 games, 465 rewards, 104880 frames, score 1, max score 4
# Completed 349 games, 467 rewards, 105317 frames, score 1, max score 4
# Completed 350 games, 468 rewards, 105498 frames, score 0, max score 4
# Completed 351 games, 469 rewards, 105752 frames, score 0, max score 4
# Completed 352 games, 470 rewards, 105960 frames, score 0, max score 4
# Completed 353 games, 473 rewards, 106568 frames, score 2, max score 4
# Completed 354 games, 474 rewards, 106749 frames, score 0, max score 4
# Completed 355 games, 475 rewards, 106957 frames, score 0, max score 4
# Completed 356 games, 476 rewards, 107138 frames, score 0, max score 4
# Completed 357 games, 477 rewards, 107392 frames, score 0, max score 4
# Completed 358 games, 478 rewards, 107646 frames, score 0, max score 4
# Completed 359 games, 480 rewards, 107987 frames, score 1, max score 4
# Completed 360 games, 481 rewards, 108168 frames, score 0, max score 4
# Completed 361 games, 482 rewards, 108376 frames, score 0, max score 4
# Completed 362 games, 483 rewards, 108557 frames, score 0, max score 4
# Completed 363 games, 484 rewards, 108738 frames, score 0, max score 4
# Completed 364 games, 485 rewards, 108919 frames, score 0, max score 4
# Completed 365 games, 486 rewards, 109127 frames, score 0, max score 4
# Completed 366 games, 488 rewards, 109635 frames, score 1, max score 4
# Completed 367 games, 489 rewards, 109843 frames, score 0, max score 4
# Completed 368 games, 490 rewards, 110024 frames, score 0, max score 4
# Completed 369 games, 491 rewards, 110278 frames, score 0, max score 4
# Completed 370 games, 492 rewards, 110486 frames, score 0, max score 4
# Completed 371 games, 493 rewards, 110740 frames, score 0, max score 4
# Completed 372 games, 495 rewards, 111145 frames, score 1, max score 4
# Completed 373 games, 496 rewards, 111353 frames, score 0, max score 4
# Completed 374 games, 497 rewards, 111607 frames, score 0, max score 4
# Completed 375 games, 498 rewards, 111815 frames, score 0, max score 4
# Completed 376 games, 499 rewards, 112069 frames, score 0, max score 4
# The number of games played was 378
# The number of rewards was 500
# The size of each returned Q-matrix was (4000, 3)

# %% [markdown]
# The returned value of `q_states` is a list of 4000x3 numpy arrays (20 states, 3 actions).  The list contains `m_rewards` of these. We want to convert it into something that matplotlib can plot.

# %%
import numpy as np

Q = np.array([np.reshape(q,-1) for q in q_states])
print('Q is now of shape',Q.shape)
print('the max absolute value of Q is ',np.amax(abs(Q)))
# Out:
# Q is now of shape (500, 12000)
# the max absolute value of Q is  1.42625

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(14,6),layout='tight')
ax = [ fig.add_subplot(2,1,x) for x in range(1,3) ]
ax[0].plot(np.arange(0,len(q_states)),Q)
ax[0].set_title('Q values of all states')
ax[1].plot(np.arange(0,len(q_states)),q_achieved)
ax[1].set_title('Q values of state achieved at each time')
ax[1].set_ylabel('Reward number')
# Out:
# Text(0, 0.5, 'Reward number')

# %% [markdown]
# OK, now let's try running it for a much longer period -- say, 5000 complete games.  We won't ask it to print out any states this time.

# %%
scores, q_achieved, q_states = pong_game.run(m_games=5000, states=[])

print('The number of games played was',len(scores))
print('The number of video frames was',len(q_states))
print('The size of each returned Q-matrix was',q_states[0].shape)
# Out:
# Completed 0 games, 1 rewards, 209 frames, score 1, max score 4
# Completed 1 games, 2 rewards, 463 frames, score 0, max score 4
# Completed 2 games, 3 rewards, 717 frames, score 0, max score 4
# Completed 3 games, 4 rewards, 898 frames, score 0, max score 4
# Completed 4 games, 5 rewards, 1079 frames, score 0, max score 4
# Completed 5 games, 6 rewards, 1287 frames, score 0, max score 4
# Completed 6 games, 7 rewards, 1468 frames, score 0, max score 4
# Completed 7 games, 8 rewards, 1722 frames, score 0, max score 4
# Completed 8 games, 9 rewards, 1903 frames, score 0, max score 4
# Completed 9 games, 10 rewards, 2157 frames, score 0, max score 4
# Completed 10 games, 11 rewards, 2411 frames, score 0, max score 4
# Completed 11 games, 12 rewards, 2592 frames, score 0, max score 4
# Completed 12 games, 13 rewards, 2773 frames, score 0, max score 4
# Completed 13 games, 15 rewards, 3307 frames, score 1, max score 4
# Completed 14 games, 16 rewards, 3561 frames, score 0, max score 4
# Completed 15 games, 17 rewards, 3742 frames, score 0, max score 4
# Completed 16 games, 18 rewards, 3923 frames, score 0, max score 4
# Completed 17 games, 19 rewards, 4131 frames, score 0, max score 4
# Completed 18 games, 20 rewards, 4385 frames, score 0, max score 4
# Completed 19 games, 21 rewards, 4639 frames, score 0, max score 4
# Completed 20 games, 22 rewards, 4820 frames, score 0, max score 4
# Completed 21 games, 23 rewards, 5001 frames, score 0, max score 4
# Completed 22 games, 24 rewards, 5209 frames, score 0, max score 4
# Completed 23 games, 26 rewards, 5811 frames, score 1, max score 4
# Completed 24 games, 27 rewards, 5992 frames, score 0, max score 4
# Completed 25 games, 28 rewards, 6173 frames, score 0, max score 4
# Completed 26 games, 29 rewards, 6427 frames, score 0, max score 4
# Completed 27 games, 30 rewards, 6635 frames, score 0, max score 4
# Completed 28 games, 31 rewards, 6843 frames, score 0, max score 4
# Completed 29 games, 32 rewards, 7097 frames, score 0, max score 4
# Completed 30 games, 33 rewards, 7278 frames, score 0, max score 4
# Completed 31 games, 34 rewards, 7486 frames, score 0, max score 4
# Completed 32 games, 36 rewards, 7983 frames, score 1, max score 4
# Completed 33 games, 37 rewards, 8164 frames, score 0, max score 4
# Completed 34 games, 38 rewards, 8418 frames, score 0, max score 4
# Completed 35 games, 40 rewards, 8952 frames, score 1, max score 4
# Completed 36 games, 41 rewards, 9206 frames, score 0, max score 4
# Completed 37 games, 46 rewards, 10021 frames, score 4, max score 4
# Completed 38 games, 47 rewards, 10275 frames, score 0, max score 4
# Completed 39 games, 48 rewards, 10483 frames, score 0, max score 4
# Completed 40 games, 50 rewards, 10980 frames, score 1, max score 4
# Completed 41 games, 51 rewards, 11234 frames, score 0, max score 4
# Completed 42 games, 52 rewards, 11415 frames, score 0, max score 4
# Completed 43 games, 53 rewards, 11623 frames, score 0, max score 4
# Completed 44 games, 54 rewards, 11831 frames, score 0, max score 4
# Completed 45 games, 55 rewards, 12039 frames, score 0, max score 4
# Completed 46 games, 58 rewards, 12556 frames, score 2, max score 4
# Completed 47 games, 59 rewards, 12764 frames, score 0, max score 4
# Completed 48 games, 60 rewards, 12945 frames, score 0, max score 4
# Completed 49 games, 63 rewards, 13769 frames, score 2, max score 4
# Completed 50 games, 64 rewards, 13950 frames, score 0, max score 4
# Completed 51 games, 65 rewards, 14158 frames, score 0, max score 4
# Completed 52 games, 66 rewards, 14412 frames, score 0, max score 4
# Completed 53 games, 67 rewards, 14666 frames, score 0, max score 4
# Completed 54 games, 68 rewards, 14847 frames, score 0, max score 4
# Completed 55 games, 69 rewards, 15101 frames, score 0, max score 4
# Completed 56 games, 72 rewards, 15744 frames, score 2, max score 4
# Completed 57 games, 73 rewards, 15925 frames, score 0, max score 4
# Completed 58 games, 74 rewards, 16106 frames, score 0, max score 4
# Completed 59 games, 75 rewards, 16314 frames, score 0, max score 4
# Completed 60 games, 76 rewards, 16522 frames, score 0, max score 4
# Completed 61 games, 77 rewards, 16730 frames, score 0, max score 4
# Completed 62 games, 78 rewards, 16938 frames, score 0, max score 4
# Completed 63 games, 79 rewards, 17192 frames, score 0, max score 4
# Completed 64 games, 80 rewards, 17446 frames, score 0, max score 4
# Completed 65 games, 81 rewards, 17627 frames, score 0, max score 4
# Completed 66 games, 83 rewards, 18203 frames, score 1, max score 4
# Completed 67 games, 85 rewards, 18555 frames, score 1, max score 4
# Completed 68 games, 86 rewards, 18809 frames, score 0, max score 4
# Completed 69 games, 87 rewards, 18990 frames, score 0, max score 4
# Completed 70 games, 88 rewards, 19198 frames, score 0, max score 4
# Completed 71 games, 89 rewards, 19379 frames, score 0, max score 4
# Completed 72 games, 90 rewards, 19587 frames, score 0, max score 4
# Completed 73 games, 92 rewards, 20050 frames, score 1, max score 4
# Completed 74 games, 94 rewards, 20456 frames, score 1, max score 4
# Completed 75 games, 95 rewards, 20637 frames, score 0, max score 4
# Completed 76 games, 96 rewards, 20891 frames, score 0, max score 4
# Completed 77 games, 98 rewards, 21297 frames, score 1, max score 4
# Completed 78 games, 99 rewards, 21478 frames, score 0, max score 4
# Completed 79 games, 100 rewards, 21732 frames, score 0, max score 4
# Completed 80 games, 101 rewards, 21913 frames, score 0, max score 4
# Completed 81 games, 102 rewards, 22094 frames, score 0, max score 4
# Completed 82 games, 104 rewards, 22696 frames, score 1, max score 4
# Completed 83 games, 105 rewards, 22950 frames, score 0, max score 4
# Completed 84 games, 106 rewards, 23131 frames, score 0, max score 4
# Completed 85 games, 107 rewards, 23312 frames, score 0, max score 4
# Completed 86 games, 108 rewards, 23493 frames, score 0, max score 4
# Completed 87 games, 111 rewards, 24154 frames, score 2, max score 4
# Completed 88 games, 112 rewards, 24335 frames, score 0, max score 4
# Completed 89 games, 114 rewards, 24886 frames, score 1, max score 4
# Completed 90 games, 115 rewards, 25067 frames, score 0, max score 4
# Completed 91 games, 117 rewards, 25527 frames, score 1, max score 4
# Completed 92 games, 119 rewards, 26078 frames, score 1, max score 4
# Completed 93 games, 120 rewards, 26332 frames, score 0, max score 4
# Completed 94 games, 121 rewards, 26513 frames, score 0, max score 4
# Completed 95 games, 122 rewards, 26694 frames, score 0, max score 4
# Completed 96 games, 123 rewards, 26948 frames, score 0, max score 4
# Completed 97 games, 124 rewards, 27202 frames, score 0, max score 4
# Completed 98 games, 125 rewards, 27383 frames, score 0, max score 4
# Completed 99 games, 127 rewards, 27750 frames, score 1, max score 4
# Completed 100 games, 128 rewards, 28004 frames, score 0, max score 4
# Completed 101 games, 129 rewards, 28212 frames, score 0, max score 4
# Completed 102 games, 130 rewards, 28466 frames, score 0, max score 4
# Completed 103 games, 131 rewards, 28647 frames, score 0, max score 4
# Completed 104 games, 132 rewards, 28855 frames, score 0, max score 4
# Completed 105 games, 133 rewards, 29063 frames, score 0, max score 4
# Completed 106 games, 134 rewards, 29244 frames, score 0, max score 4
# Completed 107 games, 135 rewards, 29452 frames, score 0, max score 4
# Completed 108 games, 136 rewards, 29633 frames, score 0, max score 4
# Completed 109 games, 138 rewards, 30367 frames, score 1, max score 4
# Completed 110 games, 139 rewards, 30548 frames, score 0, max score 4
# Completed 111 games, 140 rewards, 30756 frames, score 0, max score 4
# Completed 112 games, 141 rewards, 30937 frames, score 0, max score 4
# Completed 113 games, 142 rewards, 31145 frames, score 0, max score 4
# Completed 114 games, 143 rewards, 31326 frames, score 0, max score 4
# Completed 115 games, 144 rewards, 31534 frames, score 0, max score 4
# Completed 116 games, 145 rewards, 31788 frames, score 0, max score 4
# Completed 117 games, 146 rewards, 31996 frames, score 0, max score 4
# Completed 118 games, 147 rewards, 32250 frames, score 0, max score 4
# Completed 119 games, 148 rewards, 32458 frames, score 0, max score 4
# Completed 120 games, 150 rewards, 32921 frames, score 1, max score 4
# Completed 121 games, 151 rewards, 33175 frames, score 0, max score 4
# Completed 122 games, 152 rewards, 33429 frames, score 0, max score 4
# Completed 123 games, 153 rewards, 33683 frames, score 0, max score 4
# Completed 124 games, 154 rewards, 33937 frames, score 0, max score 4
# Completed 125 games, 155 rewards, 34118 frames, score 0, max score 4
# Completed 126 games, 156 rewards, 34372 frames, score 0, max score 4
# Completed 127 games, 158 rewards, 34740 frames, score 1, max score 4
# Completed 128 games, 160 rewards, 35145 frames, score 1, max score 4
# Completed 129 games, 161 rewards, 35326 frames, score 0, max score 4
# Completed 130 games, 162 rewards, 35507 frames, score 0, max score 4
# Completed 131 games, 163 rewards, 35715 frames, score 0, max score 4
# Completed 132 games, 164 rewards, 35923 frames, score 0, max score 4
# Completed 133 games, 167 rewards, 37781 frames, score 2, max score 4
# Completed 134 games, 170 rewards, 38335 frames, score 2, max score 4
# Completed 135 games, 171 rewards, 38543 frames, score 0, max score 4
# Completed 136 games, 172 rewards, 38797 frames, score 0, max score 4
# Completed 137 games, 173 rewards, 38978 frames, score 0, max score 4
# Completed 138 games, 174 rewards, 39159 frames, score 0, max score 4
# Completed 139 games, 175 rewards, 39413 frames, score 0, max score 4
# Completed 140 games, 176 rewards, 39667 frames, score 0, max score 4
# Completed 141 games, 177 rewards, 39848 frames, score 0, max score 4
# Completed 142 games, 179 rewards, 40510 frames, score 1, max score 4
# Completed 143 games, 184 rewards, 41428 frames, score 4, max score 4
# Completed 144 games, 185 rewards, 41636 frames, score 0, max score 4
# Completed 145 games, 186 rewards, 41890 frames, score 0, max score 4
# Completed 146 games, 187 rewards, 42144 frames, score 0, max score 4
# Completed 147 games, 188 rewards, 42352 frames, score 0, max score 4
# Completed 148 games, 189 rewards, 42560 frames, score 0, max score 4
# Completed 149 games, 191 rewards, 43020 frames, score 1, max score 4
# Completed 150 games, 192 rewards, 43228 frames, score 0, max score 4
# Completed 151 games, 195 rewards, 43812 frames, score 2, max score 4
# Completed 152 games, 196 rewards, 43993 frames, score 0, max score 4
# Completed 153 games, 197 rewards, 44201 frames, score 0, max score 4
# Completed 154 games, 198 rewards, 44455 frames, score 0, max score 4
# Completed 155 games, 199 rewards, 44636 frames, score 0, max score 4
# Completed 156 games, 200 rewards, 44844 frames, score 0, max score 4
# Completed 157 games, 203 rewards, 45551 frames, score 2, max score 4
# Completed 158 games, 204 rewards, 45805 frames, score 0, max score 4
# Completed 159 games, 205 rewards, 45986 frames, score 0, max score 4
# Completed 160 games, 206 rewards, 46194 frames, score 0, max score 4
# Completed 161 games, 207 rewards, 46375 frames, score 0, max score 4
# Completed 162 games, 209 rewards, 47109 frames, score 1, max score 4
# Completed 163 games, 210 rewards, 47363 frames, score 0, max score 4
# Completed 164 games, 211 rewards, 47617 frames, score 0, max score 4
# Completed 165 games, 212 rewards, 47871 frames, score 0, max score 4
# Completed 166 games, 213 rewards, 48125 frames, score 0, max score 4
# Completed 167 games, 214 rewards, 48333 frames, score 0, max score 4
# Completed 168 games, 216 rewards, 48716 frames, score 1, max score 4
# Completed 169 games, 217 rewards, 48970 frames, score 0, max score 4
# Completed 170 games, 218 rewards, 49178 frames, score 0, max score 4
# Completed 171 games, 220 rewards, 49675 frames, score 1, max score 4
# Completed 172 games, 222 rewards, 50112 frames, score 1, max score 4
# Completed 173 games, 223 rewards, 50320 frames, score 0, max score 4
# Completed 174 games, 224 rewards, 50501 frames, score 0, max score 4
# Completed 175 games, 225 rewards, 50682 frames, score 0, max score 4
# Completed 176 games, 227 rewards, 51049 frames, score 1, max score 4
# Completed 177 games, 228 rewards, 51230 frames, score 0, max score 4
# Completed 178 games, 230 rewards, 51628 frames, score 1, max score 4
# Completed 179 games, 231 rewards, 51809 frames, score 0, max score 4
# Completed 180 games, 233 rewards, 52150 frames, score 1, max score 4
# Completed 181 games, 234 rewards, 52331 frames, score 0, max score 4
# Completed 182 games, 235 rewards, 52539 frames, score 0, max score 4
# Completed 183 games, 236 rewards, 52747 frames, score 0, max score 4
# Completed 184 games, 237 rewards, 52955 frames, score 0, max score 4
# Completed 185 games, 238 rewards, 53136 frames, score 0, max score 4
# Completed 186 games, 240 rewards, 53738 frames, score 1, max score 4
# Completed 187 games, 241 rewards, 53946 frames, score 0, max score 4
# Completed 188 games, 244 rewards, 54627 frames, score 2, max score 4
# Completed 189 games, 245 rewards, 54881 frames, score 0, max score 4
# Completed 190 games, 248 rewards, 55703 frames, score 2, max score 4
# Completed 191 games, 249 rewards, 55884 frames, score 0, max score 4
# Completed 192 games, 250 rewards, 56092 frames, score 0, max score 4
# Completed 193 games, 251 rewards, 56346 frames, score 0, max score 4
# Completed 194 games, 252 rewards, 56600 frames, score 0, max score 4
# Completed 195 games, 253 rewards, 56854 frames, score 0, max score 4
# Completed 196 games, 254 rewards, 57062 frames, score 0, max score 4
# Completed 197 games, 255 rewards, 57243 frames, score 0, max score 4
# Completed 198 games, 258 rewards, 58182 frames, score 2, max score 4
# Completed 199 games, 261 rewards, 58968 frames, score 2, max score 4
# Completed 200 games, 262 rewards, 59149 frames, score 0, max score 4
# Completed 201 games, 263 rewards, 59330 frames, score 0, max score 4
# Completed 202 games, 264 rewards, 59584 frames, score 0, max score 4
# Completed 203 games, 265 rewards, 59792 frames, score 0, max score 4
# Completed 204 games, 266 rewards, 60000 frames, score 0, max score 4
# Completed 205 games, 268 rewards, 60551 frames, score 1, max score 4
# Completed 206 games, 270 rewards, 61048 frames, score 1, max score 4
# Completed 207 games, 271 rewards, 61302 frames, score 0, max score 4
# Completed 208 games, 272 rewards, 61510 frames, score 0, max score 4
# Completed 209 games, 274 rewards, 62061 frames, score 1, max score 4
# Completed 210 games, 275 rewards, 62315 frames, score 0, max score 4
# Completed 211 games, 276 rewards, 62523 frames, score 0, max score 4
# Completed 212 games, 278 rewards, 62875 frames, score 1, max score 4
# Completed 213 games, 280 rewards, 63388 frames, score 1, max score 4
# Completed 214 games, 282 rewards, 63939 frames, score 1, max score 4
# Completed 215 games, 283 rewards, 64120 frames, score 0, max score 4
# Completed 216 games, 284 rewards, 64328 frames, score 0, max score 4
# Completed 217 games, 285 rewards, 64582 frames, score 0, max score 4
# Completed 218 games, 287 rewards, 65006 frames, score 1, max score 4
# Completed 219 games, 288 rewards, 65187 frames, score 0, max score 4
# Completed 220 games, 290 rewards, 65624 frames, score 1, max score 4
# Completed 221 games, 291 rewards, 65805 frames, score 0, max score 4
# Completed 222 games, 292 rewards, 66059 frames, score 0, max score 4
# Completed 223 games, 293 rewards, 66267 frames, score 0, max score 4
# Completed 224 games, 294 rewards, 66521 frames, score 0, max score 4
# Completed 225 games, 295 rewards, 66775 frames, score 0, max score 4
# Completed 226 games, 296 rewards, 67029 frames, score 0, max score 4
# Completed 227 games, 298 rewards, 67691 frames, score 1, max score 4
# Completed 228 games, 299 rewards, 67872 frames, score 0, max score 4
# Completed 229 games, 302 rewards, 68826 frames, score 2, max score 4
# Completed 230 games, 303 rewards, 69007 frames, score 0, max score 4
# Completed 231 games, 304 rewards, 69215 frames, score 0, max score 4
# Completed 232 games, 305 rewards, 69469 frames, score 0, max score 4
# Completed 233 games, 306 rewards, 69650 frames, score 0, max score 4
# Completed 234 games, 307 rewards, 69904 frames, score 0, max score 4
# Completed 235 games, 308 rewards, 70112 frames, score 0, max score 4
# Completed 236 games, 310 rewards, 70624 frames, score 1, max score 4
# Completed 237 games, 311 rewards, 70878 frames, score 0, max score 4
# Completed 238 games, 313 rewards, 71429 frames, score 1, max score 4
# Completed 239 games, 314 rewards, 71683 frames, score 0, max score 4
# Completed 240 games, 315 rewards, 71937 frames, score 0, max score 4
# Completed 241 games, 316 rewards, 72191 frames, score 0, max score 4
# Completed 242 games, 317 rewards, 72445 frames, score 0, max score 4
# Completed 243 games, 318 rewards, 72653 frames, score 0, max score 4
# Completed 244 games, 319 rewards, 72834 frames, score 0, max score 4
# Completed 245 games, 320 rewards, 73042 frames, score 0, max score 4
# Completed 246 games, 321 rewards, 73250 frames, score 0, max score 4
# Completed 247 games, 322 rewards, 73458 frames, score 0, max score 4
# Completed 248 games, 323 rewards, 73712 frames, score 0, max score 4
# Completed 249 games, 324 rewards, 73966 frames, score 0, max score 4
# Completed 250 games, 325 rewards, 74220 frames, score 0, max score 4
# Completed 251 games, 326 rewards, 74428 frames, score 0, max score 4
# Completed 252 games, 328 rewards, 74795 frames, score 1, max score 4
# Completed 253 games, 330 rewards, 75529 frames, score 1, max score 4
# Completed 254 games, 332 rewards, 75992 frames, score 1, max score 4
# Completed 255 games, 333 rewards, 76173 frames, score 0, max score 4
# Completed 256 games, 334 rewards, 76381 frames, score 0, max score 4
# Completed 257 games, 335 rewards, 76562 frames, score 0, max score 4
# Completed 258 games, 336 rewards, 76770 frames, score 0, max score 4
# Completed 259 games, 338 rewards, 77360 frames, score 1, max score 4
# Completed 260 games, 339 rewards, 77568 frames, score 0, max score 4
# Completed 261 games, 340 rewards, 77822 frames, score 0, max score 4
# Completed 262 games, 342 rewards, 78228 frames, score 1, max score 4
# Completed 263 games, 343 rewards, 78482 frames, score 0, max score 4
# Completed 264 games, 344 rewards, 78690 frames, score 0, max score 4
# Completed 265 games, 345 rewards, 78944 frames, score 0, max score 4
# Completed 266 games, 346 rewards, 79198 frames, score 0, max score 4
# Completed 267 games, 347 rewards, 79379 frames, score 0, max score 4
# Completed 268 games, 348 rewards, 79587 frames, score 0, max score 4
# Completed 269 games, 349 rewards, 79841 frames, score 0, max score 4
# Completed 270 games, 350 rewards, 80022 frames, score 0, max score 4
# Completed 271 games, 351 rewards, 80276 frames, score 0, max score 4
# Completed 272 games, 352 rewards, 80530 frames, score 0, max score 4
# Completed 273 games, 353 rewards, 80738 frames, score 0, max score 4
# Completed 274 games, 354 rewards, 80946 frames, score 0, max score 4
# Completed 275 games, 356 rewards, 81344 frames, score 1, max score 4
# Completed 276 games, 359 rewards, 82013 frames, score 2, max score 4
# Completed 277 games, 360 rewards, 82221 frames, score 0, max score 4
# Completed 278 games, 361 rewards, 82402 frames, score 0, max score 4
# Completed 279 games, 362 rewards, 82583 frames, score 0, max score 4
# Completed 280 games, 363 rewards, 82764 frames, score 0, max score 4
# Completed 281 games, 364 rewards, 82972 frames, score 0, max score 4
# Completed 282 games, 365 rewards, 83153 frames, score 0, max score 4
# Completed 283 games, 366 rewards, 83334 frames, score 0, max score 4
# Completed 284 games, 367 rewards, 83515 frames, score 0, max score 4
# Completed 285 games, 368 rewards, 83723 frames, score 0, max score 4
# Completed 286 games, 369 rewards, 83931 frames, score 0, max score 4
# Completed 287 games, 370 rewards, 84139 frames, score 0, max score 4
# Completed 288 games, 371 rewards, 84347 frames, score 0, max score 4
# Completed 289 games, 373 rewards, 84714 frames, score 1, max score 4
# Completed 290 games, 374 rewards, 84922 frames, score 0, max score 4
# Completed 291 games, 375 rewards, 85176 frames, score 0, max score 4
# Completed 292 games, 376 rewards, 85357 frames, score 0, max score 4
# Completed 293 games, 377 rewards, 85538 frames, score 0, max score 4
# Completed 294 games, 378 rewards, 85746 frames, score 0, max score 4
# Completed 295 games, 380 rewards, 86217 frames, score 1, max score 4
# Completed 296 games, 381 rewards, 86425 frames, score 0, max score 4
# Completed 297 games, 383 rewards, 86853 frames, score 1, max score 4
# Completed 298 games, 384 rewards, 87061 frames, score 0, max score 4
# Completed 299 games, 385 rewards, 87315 frames, score 0, max score 4
# Completed 300 games, 387 rewards, 87775 frames, score 1, max score 4
# Completed 301 games, 388 rewards, 88029 frames, score 0, max score 4
# Completed 302 games, 389 rewards, 88283 frames, score 0, max score 4
# Completed 303 games, 391 rewards, 88754 frames, score 1, max score 4
# Completed 304 games, 392 rewards, 88962 frames, score 0, max score 4
# Completed 305 games, 393 rewards, 89216 frames, score 0, max score 4
# Completed 306 games, 394 rewards, 89397 frames, score 0, max score 4
# Completed 307 games, 395 rewards, 89605 frames, score 0, max score 4
# Completed 308 games, 396 rewards, 89786 frames, score 0, max score 4
# Completed 309 games, 397 rewards, 90040 frames, score 0, max score 4
# Completed 310 games, 398 rewards, 90221 frames, score 0, max score 4
# Completed 311 games, 399 rewards, 90402 frames, score 0, max score 4
# Completed 312 games, 400 rewards, 90583 frames, score 0, max score 4
# Completed 313 games, 402 rewards, 90951 frames, score 1, max score 4
# Completed 314 games, 404 rewards, 91373 frames, score 1, max score 4
# Completed 315 games, 407 rewards, 92295 frames, score 2, max score 4
# Completed 316 games, 409 rewards, 92829 frames, score 1, max score 4
# Completed 317 games, 411 rewards, 93234 frames, score 1, max score 4
# Completed 318 games, 412 rewards, 93415 frames, score 0, max score 4
# Completed 319 games, 413 rewards, 93596 frames, score 0, max score 4
# Completed 320 games, 415 rewards, 94130 frames, score 1, max score 4
# Completed 321 games, 416 rewards, 94338 frames, score 0, max score 4
# Completed 322 games, 417 rewards, 94546 frames, score 0, max score 4
# Completed 323 games, 418 rewards, 94727 frames, score 0, max score 4
# Completed 324 games, 420 rewards, 95215 frames, score 1, max score 4
# Completed 325 games, 421 rewards, 95469 frames, score 0, max score 4
# Completed 326 games, 422 rewards, 95723 frames, score 0, max score 4
# Completed 327 games, 424 rewards, 96064 frames, score 1, max score 4
# Completed 328 games, 425 rewards, 96272 frames, score 0, max score 4
# Completed 329 games, 426 rewards, 96526 frames, score 0, max score 4
# Completed 330 games, 427 rewards, 96734 frames, score 0, max score 4
# Completed 331 games, 428 rewards, 96988 frames, score 0, max score 4
# Completed 332 games, 429 rewards, 97196 frames, score 0, max score 4
# Completed 333 games, 431 rewards, 98115 frames, score 1, max score 4
# Completed 334 games, 432 rewards, 98296 frames, score 0, max score 4
# Completed 335 games, 434 rewards, 98958 frames, score 1, max score 4
# Completed 336 games, 435 rewards, 99212 frames, score 0, max score 4
# Completed 337 games, 436 rewards, 99393 frames, score 0, max score 4
# Completed 338 games, 438 rewards, 99995 frames, score 1, max score 4
# Completed 339 games, 440 rewards, 100423 frames, score 1, max score 4
# Completed 340 games, 441 rewards, 100604 frames, score 0, max score 4
# Completed 341 games, 443 rewards, 101067 frames, score 1, max score 4
# Completed 342 games, 444 rewards, 101321 frames, score 0, max score 4
# Completed 343 games, 445 rewards, 101575 frames, score 0, max score 4
# Completed 344 games, 446 rewards, 101829 frames, score 0, max score 4
# Completed 345 games, 447 rewards, 102010 frames, score 0, max score 4
# Completed 346 games, 448 rewards, 102264 frames, score 0, max score 4
# Completed 347 games, 449 rewards, 102518 frames, score 0, max score 4
# Completed 348 games, 450 rewards, 102699 frames, score 0, max score 4
# Completed 349 games, 451 rewards, 102953 frames, score 0, max score 4
# Completed 350 games, 453 rewards, 103504 frames, score 1, max score 4
# Completed 351 games, 455 rewards, 103910 frames, score 1, max score 4
# Completed 352 games, 456 rewards, 104164 frames, score 0, max score 4
# Completed 353 games, 457 rewards, 104418 frames, score 0, max score 4
# Completed 354 games, 459 rewards, 104906 frames, score 1, max score 4
# Completed 355 games, 460 rewards, 105160 frames, score 0, max score 4
# Completed 356 games, 461 rewards, 105341 frames, score 0, max score 4
# Completed 357 games, 462 rewards, 105595 frames, score 0, max score 4
# Completed 358 games, 464 rewards, 106129 frames, score 1, max score 4
# Completed 359 games, 465 rewards, 106337 frames, score 0, max score 4
# Completed 360 games, 466 rewards, 106545 frames, score 0, max score 4
# Completed 361 games, 467 rewards, 106799 frames, score 0, max score 4
# Completed 362 games, 471 rewards, 108025 frames, score 3, max score 4
# Completed 363 games, 472 rewards, 108206 frames, score 0, max score 4
# Completed 364 games, 473 rewards, 108460 frames, score 0, max score 4
# Completed 365 games, 474 rewards, 108641 frames, score 0, max score 4
# Completed 366 games, 475 rewards, 108895 frames, score 0, max score 4
# Completed 367 games, 477 rewards, 109557 frames, score 1, max score 4
# Completed 368 games, 479 rewards, 110291 frames, score 1, max score 4
# Completed 369 games, 480 rewards, 110499 frames, score 0, max score 4
# Completed 370 games, 481 rewards, 110680 frames, score 0, max score 4
# Completed 371 games, 482 rewards, 110934 frames, score 0, max score 4
# Completed 372 games, 483 rewards, 111188 frames, score 0, max score 4
# Completed 373 games, 485 rewards, 111722 frames, score 1, max score 4
# Completed 374 games, 487 rewards, 112273 frames, score 1, max score 4
# Completed 375 games, 488 rewards, 112527 frames, score 0, max score 4
# Completed 376 games, 489 rewards, 112735 frames, score 0, max score 4
# Completed 377 games, 491 rewards, 113325 frames, score 1, max score 4
# Completed 378 games, 492 rewards, 113506 frames, score 0, max score 4
# Completed 379 games, 493 rewards, 113714 frames, score 0, max score 4
# Completed 380 games, 496 rewards, 114525 frames, score 2, max score 4
# Completed 381 games, 497 rewards, 114706 frames, score 0, max score 4
# Completed 382 games, 498 rewards, 114887 frames, score 0, max score 4
# Completed 383 games, 499 rewards, 115141 frames, score 0, max score 4
# Completed 384 games, 501 rewards, 115604 frames, score 1, max score 4
# Completed 385 games, 503 rewards, 116206 frames, score 1, max score 4
# Completed 386 games, 504 rewards, 116387 frames, score 0, max score 4
# Completed 387 games, 506 rewards, 117049 frames, score 1, max score 4
# Completed 388 games, 507 rewards, 117230 frames, score 0, max score 4
# Completed 389 games, 508 rewards, 117484 frames, score 0, max score 4
# Completed 390 games, 509 rewards, 117665 frames, score 0, max score 4
# Completed 391 games, 510 rewards, 117873 frames, score 0, max score 4
# Completed 392 games, 511 rewards, 118127 frames, score 0, max score 4
# Completed 393 games, 512 rewards, 118381 frames, score 0, max score 4
# Completed 394 games, 513 rewards, 118562 frames, score 0, max score 4
# Completed 395 games, 514 rewards, 118816 frames, score 0, max score 4
# Completed 396 games, 515 rewards, 118997 frames, score 0, max score 4
# Completed 397 games, 518 rewards, 120008 frames, score 2, max score 4
# Completed 398 games, 519 rewards, 120262 frames, score 0, max score 4
# Completed 399 games, 520 rewards, 120470 frames, score 0, max score 4
# Completed 400 games, 521 rewards, 120678 frames, score 0, max score 4
# Completed 401 games, 523 rewards, 121106 frames, score 1, max score 4
# Completed 402 games, 524 rewards, 121314 frames, score 0, max score 4
# Completed 403 games, 525 rewards, 121522 frames, score 0, max score 4
# Completed 404 games, 526 rewards, 121730 frames, score 0, max score 4
# Completed 405 games, 528 rewards, 122392 frames, score 1, max score 4
# Completed 406 games, 529 rewards, 122646 frames, score 0, max score 4
# Completed 407 games, 531 rewards, 123109 frames, score 1, max score 4
# Completed 408 games, 532 rewards, 123363 frames, score 0, max score 4
# Completed 409 games, 533 rewards, 123617 frames, score 0, max score 4
# Completed 410 games, 534 rewards, 123798 frames, score 0, max score 4
# Completed 411 games, 535 rewards, 124052 frames, score 0, max score 4
# Completed 412 games, 538 rewards, 124665 frames, score 2, max score 4
# Completed 413 games, 539 rewards, 124846 frames, score 0, max score 4
# Completed 414 games, 540 rewards, 125054 frames, score 0, max score 4
# Completed 415 games, 541 rewards, 125262 frames, score 0, max score 4
# Completed 416 games, 544 rewards, 126372 frames, score 2, max score 4
# Completed 417 games, 548 rewards, 127157 frames, score 3, max score 4
# Completed 418 games, 550 rewards, 127654 frames, score 1, max score 4
# Completed 419 games, 551 rewards, 127835 frames, score 0, max score 4
# Completed 420 games, 552 rewards, 128043 frames, score 0, max score 4
# Completed 421 games, 553 rewards, 128251 frames, score 0, max score 4
# Completed 422 games, 554 rewards, 128459 frames, score 0, max score 4
# Completed 423 games, 556 rewards, 128842 frames, score 1, max score 4
# Completed 424 games, 557 rewards, 129023 frames, score 0, max score 4
# Completed 425 games, 558 rewards, 129204 frames, score 0, max score 4
# Completed 426 games, 559 rewards, 129385 frames, score 0, max score 4
# Completed 427 games, 560 rewards, 129593 frames, score 0, max score 4
# Completed 428 games, 561 rewards, 129847 frames, score 0, max score 4
# Completed 429 games, 562 rewards, 130101 frames, score 0, max score 4
# Completed 430 games, 563 rewards, 130282 frames, score 0, max score 4
# Completed 431 games, 565 rewards, 130833 frames, score 1, max score 4
# Completed 432 games, 566 rewards, 131041 frames, score 0, max score 4
# Completed 433 games, 567 rewards, 131295 frames, score 0, max score 4
# Completed 434 games, 569 rewards, 132214 frames, score 1, max score 4
# Completed 435 games, 570 rewards, 132395 frames, score 0, max score 4
# Completed 436 games, 571 rewards, 132649 frames, score 0, max score 4
# Completed 437 games, 572 rewards, 132903 frames, score 0, max score 4
# Completed 438 games, 573 rewards, 133084 frames, score 0, max score 4
# Completed 439 games, 574 rewards, 133292 frames, score 0, max score 4
# Completed 440 games, 576 rewards, 133843 frames, score 1, max score 4
# Completed 441 games, 577 rewards, 134097 frames, score 0, max score 4
# Completed 442 games, 579 rewards, 134570 frames, score 1, max score 4
# Completed 443 games, 581 rewards, 135489 frames, score 1, max score 4
# Completed 444 games, 582 rewards, 135743 frames, score 0, max score 4
# Completed 445 games, 583 rewards, 135997 frames, score 0, max score 4
# Completed 446 games, 584 rewards, 136205 frames, score 0, max score 4
# Completed 447 games, 585 rewards, 136413 frames, score 0, max score 4
# Completed 448 games, 587 rewards, 136910 frames, score 1, max score 4
# Completed 449 games, 588 rewards, 137118 frames, score 0, max score 4
# Completed 450 games, 589 rewards, 137326 frames, score 0, max score 4
# Completed 451 games, 591 rewards, 137988 frames, score 1, max score 4
# Completed 452 games, 593 rewards, 138425 frames, score 1, max score 4
# Completed 453 games, 594 rewards, 138679 frames, score 0, max score 4
# Completed 454 games, 596 rewards, 139077 frames, score 1, max score 4
# Completed 455 games, 598 rewards, 139444 frames, score 1, max score 4
# Completed 456 games, 599 rewards, 139652 frames, score 0, max score 4
# Completed 457 games, 602 rewards, 140644 frames, score 2, max score 4
# Completed 458 games, 603 rewards, 140852 frames, score 0, max score 4
# Completed 459 games, 604 rewards, 141033 frames, score 0, max score 4
# Completed 460 games, 605 rewards, 141214 frames, score 0, max score 4
# Completed 461 games, 606 rewards, 141395 frames, score 0, max score 4
# Completed 462 games, 607 rewards, 141576 frames, score 0, max score 4
# Completed 463 games, 608 rewards, 141784 frames, score 0, max score 4
# Completed 464 games, 609 rewards, 142038 frames, score 0, max score 4
# Completed 465 games, 610 rewards, 142246 frames, score 0, max score 4
# Completed 466 games, 611 rewards, 142427 frames, score 0, max score 4
# Completed 467 games, 612 rewards, 142635 frames, score 0, max score 4
# Completed 468 games, 614 rewards, 143041 frames, score 1, max score 4
# Completed 469 games, 615 rewards, 143249 frames, score 0, max score 4
# Completed 470 games, 618 rewards, 143850 frames, score 2, max score 4
# Completed 471 games, 619 rewards, 144058 frames, score 0, max score 4
# Completed 472 games, 620 rewards, 144312 frames, score 0, max score 4
# Completed 473 games, 622 rewards, 145046 frames, score 1, max score 4
# Completed 474 games, 623 rewards, 145300 frames, score 0, max score 4
# Completed 475 games, 624 rewards, 145508 frames, score 0, max score 4
# Completed 476 games, 625 rewards, 145716 frames, score 0, max score 4
# Completed 477 games, 626 rewards, 145924 frames, score 0, max score 4
# Completed 478 games, 628 rewards, 146352 frames, score 1, max score 4
# Completed 479 games, 629 rewards, 146560 frames, score 0, max score 4
# Completed 480 games, 630 rewards, 146741 frames, score 0, max score 4
# Completed 481 games, 631 rewards, 146995 frames, score 0, max score 4
# Completed 482 games, 632 rewards, 147176 frames, score 0, max score 4
# Completed 483 games, 633 rewards, 147430 frames, score 0, max score 4
# Completed 484 games, 634 rewards, 147638 frames, score 0, max score 4
# Completed 485 games, 635 rewards, 147819 frames, score 0, max score 4
# Completed 486 games, 636 rewards, 148000 frames, score 0, max score 4
# Completed 487 games, 637 rewards, 148181 frames, score 0, max score 4
# Completed 488 games, 638 rewards, 148362 frames, score 0, max score 4
# Completed 489 games, 640 rewards, 148874 frames, score 1, max score 4
# Completed 490 games, 641 rewards, 149082 frames, score 0, max score 4
# Completed 491 games, 642 rewards, 149290 frames, score 0, max score 4
# Completed 492 games, 645 rewards, 150035 frames, score 2, max score 4
# Completed 493 games, 646 rewards, 150216 frames, score 0, max score 4
# Completed 494 games, 647 rewards, 150470 frames, score 0, max score 4
# Completed 495 games, 648 rewards, 150678 frames, score 0, max score 4
# Completed 496 games, 649 rewards, 150932 frames, score 0, max score 4
# Completed 497 games, 651 rewards, 151466 frames, score 1, max score 4
# Completed 498 games, 652 rewards, 151647 frames, score 0, max score 4
# Completed 499 games, 653 rewards, 151828 frames, score 0, max score 4
# Completed 500 games, 655 rewards, 152490 frames, score 1, max score 4
# Completed 501 games, 656 rewards, 152744 frames, score 0, max score 4
# Completed 502 games, 657 rewards, 152998 frames, score 0, max score 4
# Completed 503 games, 658 rewards, 153179 frames, score 0, max score 4
# Completed 504 games, 661 rewards, 153976 frames, score 2, max score 4
# Completed 505 games, 663 rewards, 154387 frames, score 1, max score 4
# Completed 506 games, 664 rewards, 154595 frames, score 0, max score 4
# Completed 507 games, 665 rewards, 154849 frames, score 0, max score 4
# Completed 508 games, 667 rewards, 155217 frames, score 1, max score 4
# Completed 509 games, 668 rewards, 155398 frames, score 0, max score 4
# Completed 510 games, 669 rewards, 155579 frames, score 0, max score 4
# Completed 511 games, 670 rewards, 155787 frames, score 0, max score 4
# Completed 512 games, 671 rewards, 156041 frames, score 0, max score 4
# Completed 513 games, 672 rewards, 156295 frames, score 0, max score 4
# Completed 514 games, 673 rewards, 156549 frames, score 0, max score 4
# Completed 515 games, 674 rewards, 156757 frames, score 0, max score 4
# Completed 516 games, 675 rewards, 156938 frames, score 0, max score 4
# Completed 517 games, 676 rewards, 157146 frames, score 0, max score 4
# Completed 518 games, 677 rewards, 157354 frames, score 0, max score 4
# Completed 519 games, 678 rewards, 157608 frames, score 0, max score 4
# Completed 520 games, 679 rewards, 157789 frames, score 0, max score 4
# Completed 521 games, 680 rewards, 158043 frames, score 0, max score 4
# Completed 522 games, 681 rewards, 158224 frames, score 0, max score 4
# Completed 523 games, 682 rewards, 158432 frames, score 0, max score 4
# Completed 524 games, 683 rewards, 158613 frames, score 0, max score 4
# Completed 525 games, 684 rewards, 158794 frames, score 0, max score 4
# Completed 526 games, 687 rewards, 159398 frames, score 2, max score 4
# Completed 527 games, 688 rewards, 159652 frames, score 0, max score 4
# Completed 528 games, 689 rewards, 159860 frames, score 0, max score 4
# Completed 529 games, 690 rewards, 160068 frames, score 0, max score 4
# Completed 530 games, 692 rewards, 160505 frames, score 1, max score 4
# Completed 531 games, 693 rewards, 160713 frames, score 0, max score 4
# Completed 532 games, 694 rewards, 160894 frames, score 0, max score 4
# Completed 533 games, 696 rewards, 161445 frames, score 1, max score 4
# Completed 534 games, 697 rewards, 161653 frames, score 0, max score 4
# Completed 535 games, 698 rewards, 161907 frames, score 0, max score 4
# Completed 536 games, 699 rewards, 162088 frames, score 0, max score 4
# Completed 537 games, 700 rewards, 162342 frames, score 0, max score 4
# Completed 538 games, 701 rewards, 162596 frames, score 0, max score 4
# Completed 539 games, 702 rewards, 162850 frames, score 0, max score 4
# Completed 540 games, 704 rewards, 163248 frames, score 1, max score 4
# Completed 541 games, 705 rewards, 163429 frames, score 0, max score 4
# Completed 542 games, 707 rewards, 164005 frames, score 1, max score 4
# Completed 543 games, 708 rewards, 164186 frames, score 0, max score 4
# Completed 544 games, 709 rewards, 164367 frames, score 0, max score 4
# Completed 545 games, 710 rewards, 164575 frames, score 0, max score 4
# Completed 546 games, 711 rewards, 164756 frames, score 0, max score 4
# Completed 547 games, 712 rewards, 165010 frames, score 0, max score 4
# Completed 548 games, 713 rewards, 165264 frames, score 0, max score 4
# Completed 549 games, 714 rewards, 165518 frames, score 0, max score 4
# Completed 550 games, 715 rewards, 165772 frames, score 0, max score 4
# Completed 551 games, 716 rewards, 165953 frames, score 0, max score 4
# Completed 552 games, 717 rewards, 166207 frames, score 0, max score 4
# Completed 553 games, 718 rewards, 166388 frames, score 0, max score 4
# Completed 554 games, 719 rewards, 166596 frames, score 0, max score 4
# Completed 555 games, 720 rewards, 166850 frames, score 0, max score 4
# Completed 556 games, 721 rewards, 167104 frames, score 0, max score 4
# Completed 557 games, 725 rewards, 168454 frames, score 3, max score 4
# Completed 558 games, 726 rewards, 168708 frames, score 0, max score 4
# Completed 559 games, 727 rewards, 168962 frames, score 0, max score 4
# Completed 560 games, 728 rewards, 169170 frames, score 0, max score 4
# Completed 561 games, 730 rewards, 169581 frames, score 1, max score 4
# Completed 562 games, 732 rewards, 170018 frames, score 1, max score 4
# Completed 563 games, 733 rewards, 170272 frames, score 0, max score 4
# Completed 564 games, 734 rewards, 170526 frames, score 0, max score 4
# Completed 565 games, 735 rewards, 170734 frames, score 0, max score 4
# Completed 566 games, 736 rewards, 170988 frames, score 0, max score 4
# Completed 567 games, 737 rewards, 171196 frames, score 0, max score 4
# Completed 568 games, 739 rewards, 171602 frames, score 1, max score 4
# Completed 569 games, 741 rewards, 172008 frames, score 1, max score 4
# Completed 570 games, 742 rewards, 172262 frames, score 0, max score 4
# Completed 571 games, 743 rewards, 172516 frames, score 0, max score 4
# Completed 572 games, 745 rewards, 173106 frames, score 1, max score 4
# Completed 573 games, 746 rewards, 173287 frames, score 0, max score 4
# Completed 574 games, 747 rewards, 173468 frames, score 0, max score 4
# Completed 575 games, 748 rewards, 173649 frames, score 0, max score 4
# Completed 576 games, 753 rewards, 174613 frames, score 4, max score 4
# Completed 577 games, 754 rewards, 174794 frames, score 0, max score 4
# Completed 578 games, 755 rewards, 175002 frames, score 0, max score 4
# Completed 579 games, 758 rewards, 175572 frames, score 2, max score 4
# Completed 580 games, 759 rewards, 175753 frames, score 0, max score 4
# Completed 581 games, 761 rewards, 176415 frames, score 1, max score 4
# Completed 582 games, 762 rewards, 176596 frames, score 0, max score 4
# Completed 583 games, 763 rewards, 176850 frames, score 0, max score 4
# Completed 584 games, 764 rewards, 177104 frames, score 0, max score 4
# Completed 585 games, 765 rewards, 177312 frames, score 0, max score 4
# Completed 586 games, 767 rewards, 177699 frames, score 1, max score 4
# Completed 587 games, 768 rewards, 177953 frames, score 0, max score 4
# Completed 588 games, 769 rewards, 178161 frames, score 0, max score 4
# Completed 589 games, 770 rewards, 178342 frames, score 0, max score 4
# Completed 590 games, 771 rewards, 178596 frames, score 0, max score 4
# Completed 591 games, 772 rewards, 178850 frames, score 0, max score 4
# Completed 592 games, 774 rewards, 179202 frames, score 1, max score 4
# Completed 593 games, 775 rewards, 179456 frames, score 0, max score 4
# Completed 594 games, 776 rewards, 179664 frames, score 0, max score 4
# Completed 595 games, 777 rewards, 179872 frames, score 0, max score 4
# Completed 596 games, 778 rewards, 180126 frames, score 0, max score 4
# Completed 597 games, 779 rewards, 180380 frames, score 0, max score 4
# Completed 598 games, 780 rewards, 180634 frames, score 0, max score 4
# Completed 599 games, 782 rewards, 181131 frames, score 1, max score 4
# Completed 600 games, 783 rewards, 181339 frames, score 0, max score 4
# Completed 601 games, 784 rewards, 181547 frames, score 0, max score 4
# Completed 602 games, 785 rewards, 181801 frames, score 0, max score 4
# Completed 603 games, 786 rewards, 181982 frames, score 0, max score 4
# Completed 604 games, 788 rewards, 182410 frames, score 1, max score 4
# Completed 605 games, 789 rewards, 182664 frames, score 0, max score 4
# Completed 606 games, 790 rewards, 182918 frames, score 0, max score 4
# Completed 607 games, 791 rewards, 183099 frames, score 0, max score 4
# Completed 608 games, 792 rewards, 183353 frames, score 0, max score 4
# Completed 609 games, 793 rewards, 183561 frames, score 0, max score 4
# Completed 610 games, 794 rewards, 183769 frames, score 0, max score 4
# Completed 611 games, 795 rewards, 184023 frames, score 0, max score 4
# Completed 612 games, 796 rewards, 184204 frames, score 0, max score 4
# Completed 613 games, 797 rewards, 184458 frames, score 0, max score 4
# Completed 614 games, 798 rewards, 184666 frames, score 0, max score 4
# Completed 615 games, 799 rewards, 184874 frames, score 0, max score 4
# Completed 616 games, 800 rewards, 185128 frames, score 0, max score 4
# Completed 617 games, 801 rewards, 185336 frames, score 0, max score 4
# Completed 618 games, 802 rewards, 185590 frames, score 0, max score 4
# Completed 619 games, 803 rewards, 185798 frames, score 0, max score 4
# Completed 620 games, 805 rewards, 186212 frames, score 1, max score 4
# Completed 621 games, 806 rewards, 186393 frames, score 0, max score 4
# Completed 622 games, 807 rewards, 186647 frames, score 0, max score 4
# Completed 623 games, 808 rewards, 186855 frames, score 0, max score 4
# Completed 624 games, 809 rewards, 187109 frames, score 0, max score 4
# Completed 625 games, 810 rewards, 187363 frames, score 0, max score 4
# Completed 626 games, 814 rewards, 188403 frames, score 3, max score 4
# Completed 627 games, 815 rewards, 188657 frames, score 0, max score 4
# Completed 628 games, 816 rewards, 188911 frames, score 0, max score 4
# Completed 629 games, 817 rewards, 189119 frames, score 0, max score 4
# Completed 630 games, 820 rewards, 189920 frames, score 2, max score 4
# Completed 631 games, 821 rewards, 190174 frames, score 0, max score 4
# Completed 632 games, 822 rewards, 190428 frames, score 0, max score 4
# Completed 633 games, 823 rewards, 190609 frames, score 0, max score 4
# Completed 634 games, 824 rewards, 190790 frames, score 0, max score 4
# Completed 635 games, 826 rewards, 191324 frames, score 1, max score 4
# Completed 636 games, 827 rewards, 191505 frames, score 0, max score 4
# Completed 637 games, 828 rewards, 191686 frames, score 0, max score 4
# Completed 638 games, 829 rewards, 191940 frames, score 0, max score 4
# Completed 639 games, 830 rewards, 192121 frames, score 0, max score 4
# Completed 640 games, 831 rewards, 192329 frames, score 0, max score 4
# Completed 641 games, 832 rewards, 192510 frames, score 0, max score 4
# Completed 642 games, 833 rewards, 192691 frames, score 0, max score 4
# Completed 643 games, 834 rewards, 192899 frames, score 0, max score 4
# Completed 644 games, 835 rewards, 193153 frames, score 0, max score 4
# Completed 645 games, 836 rewards, 193334 frames, score 0, max score 4
# Completed 646 games, 837 rewards, 193515 frames, score 0, max score 4
# Completed 647 games, 838 rewards, 193769 frames, score 0, max score 4
# Completed 648 games, 839 rewards, 193950 frames, score 0, max score 4
# Completed 649 games, 841 rewards, 194291 frames, score 1, max score 4
# Completed 650 games, 842 rewards, 194472 frames, score 0, max score 4
# Completed 651 games, 843 rewards, 194680 frames, score 0, max score 4
# Completed 652 games, 845 rewards, 195063 frames, score 1, max score 4
# Completed 653 games, 846 rewards, 195244 frames, score 0, max score 4
# Completed 654 games, 847 rewards, 195425 frames, score 0, max score 4
# Completed 655 games, 848 rewards, 195679 frames, score 0, max score 4
# Completed 656 games, 849 rewards, 195860 frames, score 0, max score 4
# Completed 657 games, 850 rewards, 196041 frames, score 0, max score 4
# Completed 658 games, 851 rewards, 196222 frames, score 0, max score 4
# Completed 659 games, 852 rewards, 196476 frames, score 0, max score 4
# Completed 660 games, 853 rewards, 196730 frames, score 0, max score 4
# Completed 661 games, 854 rewards, 196984 frames, score 0, max score 4
# Completed 662 games, 859 rewards, 198240 frames, score 4, max score 4
# Completed 663 games, 860 rewards, 198494 frames, score 0, max score 4
# Completed 664 games, 861 rewards, 198748 frames, score 0, max score 4
# Completed 665 games, 862 rewards, 198956 frames, score 0, max score 4
# Completed 666 games, 863 rewards, 199137 frames, score 0, max score 4
# Completed 667 games, 868 rewards, 199987 frames, score 4, max score 4
# Completed 668 games, 869 rewards, 200168 frames, score 0, max score 4
# Completed 669 games, 870 rewards, 200376 frames, score 0, max score 4
# Completed 670 games, 871 rewards, 200557 frames, score 0, max score 4
# Completed 671 games, 872 rewards, 200765 frames, score 0, max score 4
# Completed 672 games, 873 rewards, 200973 frames, score 0, max score 4
# Completed 673 games, 874 rewards, 201154 frames, score 0, max score 4
# Completed 674 games, 876 rewards, 201666 frames, score 1, max score 4
# Completed 675 games, 877 rewards, 201847 frames, score 0, max score 4
# Completed 676 games, 878 rewards, 202101 frames, score 0, max score 4
# Completed 677 games, 879 rewards, 202282 frames, score 0, max score 4
# Completed 678 games, 880 rewards, 202490 frames, score 0, max score 4
# Completed 679 games, 881 rewards, 202698 frames, score 0, max score 4
# Completed 680 games, 882 rewards, 202906 frames, score 0, max score 4
# Completed 681 games, 883 rewards, 203087 frames, score 0, max score 4
# Completed 682 games, 884 rewards, 203341 frames, score 0, max score 4
# Completed 683 games, 885 rewards, 203522 frames, score 0, max score 4
# Completed 684 games, 888 rewards, 204457 frames, score 2, max score 4
# Completed 685 games, 889 rewards, 204638 frames, score 0, max score 4
# Completed 686 games, 890 rewards, 204846 frames, score 0, max score 4
# Completed 687 games, 892 rewards, 205251 frames, score 1, max score 4
# Completed 688 games, 893 rewards, 205432 frames, score 0, max score 4
# Completed 689 games, 894 rewards, 205613 frames, score 0, max score 4
# Completed 690 games, 895 rewards, 205821 frames, score 0, max score 4
# Completed 691 games, 896 rewards, 206002 frames, score 0, max score 4
# Completed 692 games, 897 rewards, 206183 frames, score 0, max score 4
# ...
# Completed 4783 games, 6161 rewards, 1395417 frames, score 0, max score 4
# Completed 4784 games, 6165 rewards, 1396255 frames, score 3, max score 4
# Completed 4785 games, 6166 rewards, 1396509 frames, score 0, max score 4
# Completed 4786 games, 6167 rewards, 1396763 frames, score 0, max score 4
# Completed 4787 games, 6168 rewards, 1396944 frames, score 0, max score 4
# Completed 4788 games, 6169 rewards, 1397198 frames, score 0, max score 4
# Completed 4789 games, 6171 rewards, 1397732 frames, score 1, max score 4
# Completed 4790 games, 6172 rewards, 1397986 frames, score 0, max score 4
# Completed 4791 games, 6173 rewards, 1398194 frames, score 0, max score 4
# Completed 4792 games, 6174 rewards, 1398375 frames, score 0, max score 4
# Completed 4793 games, 6175 rewards, 1398583 frames, score 0, max score 4
# Completed 4794 games, 6178 rewards, 1399958 frames, score 2, max score 4
# Completed 4795 games, 6180 rewards, 1400395 frames, score 1, max score 4
# Completed 4796 games, 6181 rewards, 1400603 frames, score 0, max score 4
# Completed 4797 games, 6183 rewards, 1401040 frames, score 1, max score 4
# Completed 4798 games, 6184 rewards, 1401294 frames, score 0, max score 4
# Completed 4799 games, 6185 rewards, 1401502 frames, score 0, max score 4
# Completed 4800 games, 6186 rewards, 1401710 frames, score 0, max score 4
# Completed 4801 games, 6187 rewards, 1401891 frames, score 0, max score 4
# Completed 4802 games, 6188 rewards, 1402145 frames, score 0, max score 4
# Completed 4803 games, 6189 rewards, 1402399 frames, score 0, max score 4
# Completed 4804 games, 6190 rewards, 1402580 frames, score 0, max score 4
# Completed 4805 games, 6191 rewards, 1402761 frames, score 0, max score 4
# Completed 4806 games, 6192 rewards, 1402969 frames, score 0, max score 4
# Completed 4807 games, 6193 rewards, 1403223 frames, score 0, max score 4
# Completed 4808 games, 6194 rewards, 1403431 frames, score 0, max score 4
# Completed 4809 games, 6195 rewards, 1403612 frames, score 0, max score 4
# Completed 4810 games, 6196 rewards, 1403820 frames, score 0, max score 4
# Completed 4811 games, 6197 rewards, 1404001 frames, score 0, max score 4
# Completed 4812 games, 6198 rewards, 1404255 frames, score 0, max score 4
# Completed 4813 games, 6199 rewards, 1404509 frames, score 0, max score 4
# Completed 4814 games, 6200 rewards, 1404763 frames, score 0, max score 4
# Completed 4815 games, 6201 rewards, 1404971 frames, score 0, max score 4
# Completed 4816 games, 6202 rewards, 1405152 frames, score 0, max score 4
# Completed 4817 games, 6203 rewards, 1405333 frames, score 0, max score 4
# Completed 4818 games, 6204 rewards, 1405514 frames, score 0, max score 4
# Completed 4819 games, 6205 rewards, 1405695 frames, score 0, max score 4
# Completed 4820 games, 6206 rewards, 1405876 frames, score 0, max score 4
# Completed 4821 games, 6207 rewards, 1406084 frames, score 0, max score 4
# Completed 4822 games, 6208 rewards, 1406265 frames, score 0, max score 4
# Completed 4823 games, 6209 rewards, 1406446 frames, score 0, max score 4
# Completed 4824 games, 6211 rewards, 1406906 frames, score 1, max score 4
# Completed 4825 games, 6212 rewards, 1407114 frames, score 0, max score 4
# Completed 4826 games, 6213 rewards, 1407295 frames, score 0, max score 4
# Completed 4827 games, 6214 rewards, 1407549 frames, score 0, max score 4
# Completed 4828 games, 6215 rewards, 1407803 frames, score 0, max score 4
# Completed 4829 games, 6217 rewards, 1408217 frames, score 1, max score 4
# Completed 4830 games, 6218 rewards, 1408425 frames, score 0, max score 4
# Completed 4831 games, 6219 rewards, 1408679 frames, score 0, max score 4
# Completed 4832 games, 6220 rewards, 1408933 frames, score 0, max score 4
# Completed 4833 games, 6221 rewards, 1409114 frames, score 0, max score 4
# Completed 4834 games, 6222 rewards, 1409322 frames, score 0, max score 4
# Completed 4835 games, 6223 rewards, 1409576 frames, score 0, max score 4
# Completed 4836 games, 6224 rewards, 1409784 frames, score 0, max score 4
# Completed 4837 games, 6225 rewards, 1409965 frames, score 0, max score 4
# Completed 4838 games, 6229 rewards, 1410755 frames, score 3, max score 4
# Completed 4839 games, 6230 rewards, 1410963 frames, score 0, max score 4
# Completed 4840 games, 6231 rewards, 1411171 frames, score 0, max score 4
# Completed 4841 games, 6232 rewards, 1411425 frames, score 0, max score 4
# Completed 4842 games, 6233 rewards, 1411633 frames, score 0, max score 4
# Completed 4843 games, 6234 rewards, 1411841 frames, score 0, max score 4
# Completed 4844 games, 6235 rewards, 1412049 frames, score 0, max score 4
# Completed 4845 games, 6236 rewards, 1412230 frames, score 0, max score 4
# Completed 4846 games, 6237 rewards, 1412438 frames, score 0, max score 4
# Completed 4847 games, 6238 rewards, 1412692 frames, score 0, max score 4
# Completed 4848 games, 6240 rewards, 1413075 frames, score 1, max score 4
# Completed 4849 games, 6241 rewards, 1413256 frames, score 0, max score 4
# Completed 4850 games, 6244 rewards, 1413978 frames, score 2, max score 4
# Completed 4851 games, 6245 rewards, 1414186 frames, score 0, max score 4
# Completed 4852 games, 6246 rewards, 1414440 frames, score 0, max score 4
# Completed 4853 games, 6248 rewards, 1415042 frames, score 1, max score 4
# Completed 4854 games, 6249 rewards, 1415223 frames, score 0, max score 4
# Completed 4855 games, 6250 rewards, 1415404 frames, score 0, max score 4
# Completed 4856 games, 6251 rewards, 1415612 frames, score 0, max score 4
# Completed 4857 games, 6252 rewards, 1415866 frames, score 0, max score 4
# Completed 4858 games, 6253 rewards, 1416074 frames, score 0, max score 4
# Completed 4859 games, 6254 rewards, 1416282 frames, score 0, max score 4
# Completed 4860 games, 6255 rewards, 1416463 frames, score 0, max score 4
# Completed 4861 games, 6256 rewards, 1416644 frames, score 0, max score 4
# Completed 4862 games, 6257 rewards, 1416852 frames, score 0, max score 4
# Completed 4863 games, 6259 rewards, 1417193 frames, score 1, max score 4
# Completed 4864 games, 6260 rewards, 1417374 frames, score 0, max score 4
# Completed 4865 games, 6261 rewards, 1417582 frames, score 0, max score 4
# Completed 4866 games, 6262 rewards, 1417836 frames, score 0, max score 4
# Completed 4867 games, 6263 rewards, 1418044 frames, score 0, max score 4
# Completed 4868 games, 6264 rewards, 1418225 frames, score 0, max score 4
# Completed 4869 games, 6265 rewards, 1418433 frames, score 0, max score 4
# Completed 4870 games, 6266 rewards, 1418614 frames, score 0, max score 4
# Completed 4871 games, 6267 rewards, 1418822 frames, score 0, max score 4
# Completed 4872 games, 6269 rewards, 1419205 frames, score 1, max score 4
# Completed 4873 games, 6271 rewards, 1419557 frames, score 1, max score 4
# Completed 4874 games, 6273 rewards, 1420054 frames, score 1, max score 4
# Completed 4875 games, 6275 rewards, 1420482 frames, score 1, max score 4
# Completed 4876 games, 6276 rewards, 1420690 frames, score 0, max score 4
# Completed 4877 games, 6277 rewards, 1420944 frames, score 0, max score 4
# Completed 4878 games, 6278 rewards, 1421152 frames, score 0, max score 4
# Completed 4879 games, 6279 rewards, 1421360 frames, score 0, max score 4
# Completed 4880 games, 6280 rewards, 1421568 frames, score 0, max score 4
# Completed 4881 games, 6281 rewards, 1421776 frames, score 0, max score 4
# Completed 4882 games, 6282 rewards, 1422030 frames, score 0, max score 4
# Completed 4883 games, 6283 rewards, 1422238 frames, score 0, max score 4
# Completed 4884 games, 6284 rewards, 1422446 frames, score 0, max score 4
# Completed 4885 games, 6285 rewards, 1422627 frames, score 0, max score 4
# Completed 4886 games, 6286 rewards, 1422835 frames, score 0, max score 4
# Completed 4887 games, 6287 rewards, 1423089 frames, score 0, max score 4
# Completed 4888 games, 6288 rewards, 1423270 frames, score 0, max score 4
# Completed 4889 games, 6289 rewards, 1423524 frames, score 0, max score 4
# Completed 4890 games, 6291 rewards, 1423984 frames, score 1, max score 4
# Completed 4891 games, 6292 rewards, 1424165 frames, score 0, max score 4
# Completed 4892 games, 6293 rewards, 1424373 frames, score 0, max score 4
# Completed 4893 games, 6294 rewards, 1424554 frames, score 0, max score 4
# Completed 4894 games, 6296 rewards, 1424965 frames, score 1, max score 4
# Completed 4895 games, 6299 rewards, 1425704 frames, score 2, max score 4
# Completed 4896 games, 6300 rewards, 1425912 frames, score 0, max score 4
# Completed 4897 games, 6301 rewards, 1426120 frames, score 0, max score 4
# Completed 4898 games, 6302 rewards, 1426328 frames, score 0, max score 4
# Completed 4899 games, 6303 rewards, 1426509 frames, score 0, max score 4
# Completed 4900 games, 6304 rewards, 1426717 frames, score 0, max score 4
# Completed 4901 games, 6305 rewards, 1426925 frames, score 0, max score 4
# Completed 4902 games, 6306 rewards, 1427133 frames, score 0, max score 4
# Completed 4903 games, 6307 rewards, 1427341 frames, score 0, max score 4
# Completed 4904 games, 6309 rewards, 1427755 frames, score 1, max score 4
# Completed 4905 games, 6310 rewards, 1428009 frames, score 0, max score 4
# Completed 4906 games, 6312 rewards, 1428671 frames, score 1, max score 4
# Completed 4907 games, 6314 rewards, 1429108 frames, score 1, max score 4
# Completed 4908 games, 6315 rewards, 1429316 frames, score 0, max score 4
# Completed 4909 games, 6316 rewards, 1429497 frames, score 0, max score 4
# Completed 4910 games, 6317 rewards, 1429678 frames, score 0, max score 4
# Completed 4911 games, 6321 rewards, 1430749 frames, score 3, max score 4
# Completed 4912 games, 6322 rewards, 1430957 frames, score 0, max score 4
# Completed 4913 games, 6323 rewards, 1431211 frames, score 0, max score 4
# Completed 4914 games, 6324 rewards, 1431419 frames, score 0, max score 4
# Completed 4915 games, 6325 rewards, 1431600 frames, score 0, max score 4
# Completed 4916 games, 6326 rewards, 1431781 frames, score 0, max score 4
# Completed 4917 games, 6327 rewards, 1431989 frames, score 0, max score 4
# Completed 4918 games, 6331 rewards, 1433026 frames, score 3, max score 4
# Completed 4919 games, 6332 rewards, 1433280 frames, score 0, max score 4
# Completed 4920 games, 6333 rewards, 1433488 frames, score 0, max score 4
# Completed 4921 games, 6334 rewards, 1433669 frames, score 0, max score 4
# Completed 4922 games, 6335 rewards, 1433877 frames, score 0, max score 4
# Completed 4923 games, 6336 rewards, 1434058 frames, score 0, max score 4
# Completed 4924 games, 6337 rewards, 1434312 frames, score 0, max score 4
# Completed 4925 games, 6338 rewards, 1434520 frames, score 0, max score 4
# Completed 4926 games, 6339 rewards, 1434728 frames, score 0, max score 4
# Completed 4927 games, 6340 rewards, 1434936 frames, score 0, max score 4
# Completed 4928 games, 6342 rewards, 1435342 frames, score 1, max score 4
# Completed 4929 games, 6343 rewards, 1435523 frames, score 0, max score 4
# Completed 4930 games, 6345 rewards, 1436257 frames, score 1, max score 4
# Completed 4931 games, 6346 rewards, 1436438 frames, score 0, max score 4
# Completed 4932 games, 6347 rewards, 1436646 frames, score 0, max score 4
# Completed 4933 games, 6348 rewards, 1436854 frames, score 0, max score 4
# Completed 4934 games, 6350 rewards, 1437362 frames, score 1, max score 4
# Completed 4935 games, 6351 rewards, 1437570 frames, score 0, max score 4
# Completed 4936 games, 6352 rewards, 1437751 frames, score 0, max score 4
# Completed 4937 games, 6353 rewards, 1437932 frames, score 0, max score 4
# Completed 4938 games, 6354 rewards, 1438140 frames, score 0, max score 4
# Completed 4939 games, 6356 rewards, 1438492 frames, score 1, max score 4
# Completed 4940 games, 6357 rewards, 1438746 frames, score 0, max score 4
# Completed 4941 games, 6358 rewards, 1438927 frames, score 0, max score 4
# Completed 4942 games, 6359 rewards, 1439181 frames, score 0, max score 4
# Completed 4943 games, 6360 rewards, 1439362 frames, score 0, max score 4
# Completed 4944 games, 6361 rewards, 1439616 frames, score 0, max score 4
# Completed 4945 games, 6362 rewards, 1439870 frames, score 0, max score 4
# Completed 4946 games, 6365 rewards, 1440444 frames, score 2, max score 4
# Completed 4947 games, 6366 rewards, 1440625 frames, score 0, max score 4
# Completed 4948 games, 6367 rewards, 1440833 frames, score 0, max score 4
# Completed 4949 games, 6368 rewards, 1441014 frames, score 0, max score 4
# Completed 4950 games, 6369 rewards, 1441268 frames, score 0, max score 4
# Completed 4951 games, 6370 rewards, 1441522 frames, score 0, max score 4
# Completed 4952 games, 6371 rewards, 1441703 frames, score 0, max score 4
# Completed 4953 games, 6372 rewards, 1441884 frames, score 0, max score 4
# Completed 4954 games, 6374 rewards, 1442312 frames, score 1, max score 4
# Completed 4955 games, 6375 rewards, 1442493 frames, score 0, max score 4
# Completed 4956 games, 6377 rewards, 1443005 frames, score 1, max score 4
# Completed 4957 games, 6378 rewards, 1443259 frames, score 0, max score 4
# Completed 4958 games, 6379 rewards, 1443513 frames, score 0, max score 4
# Completed 4959 games, 6380 rewards, 1443767 frames, score 0, max score 4
# Completed 4960 games, 6382 rewards, 1444343 frames, score 1, max score 4
# Completed 4961 games, 6383 rewards, 1444597 frames, score 0, max score 4
# Completed 4962 games, 6384 rewards, 1444851 frames, score 0, max score 4
# Completed 4963 games, 6385 rewards, 1445032 frames, score 0, max score 4
# Completed 4964 games, 6386 rewards, 1445286 frames, score 0, max score 4
# Completed 4965 games, 6387 rewards, 1445540 frames, score 0, max score 4
# Completed 4966 games, 6388 rewards, 1445748 frames, score 0, max score 4
# Completed 4967 games, 6389 rewards, 1445929 frames, score 0, max score 4
# Completed 4968 games, 6392 rewards, 1446572 frames, score 2, max score 4
# Completed 4969 games, 6393 rewards, 1446780 frames, score 0, max score 4
# Completed 4970 games, 6394 rewards, 1447034 frames, score 0, max score 4
# Completed 4971 games, 6395 rewards, 1447242 frames, score 0, max score 4
# Completed 4972 games, 6396 rewards, 1447423 frames, score 0, max score 4
# Completed 4973 games, 6397 rewards, 1447677 frames, score 0, max score 4
# Completed 4974 games, 6399 rewards, 1448189 frames, score 1, max score 4
# Completed 4975 games, 6401 rewards, 1448677 frames, score 1, max score 4
# Completed 4976 games, 6402 rewards, 1448931 frames, score 0, max score 4
# Completed 4977 games, 6403 rewards, 1449112 frames, score 0, max score 4
# Completed 4978 games, 6404 rewards, 1449366 frames, score 0, max score 4
# Completed 4979 games, 6405 rewards, 1449620 frames, score 0, max score 4
# Completed 4980 games, 6406 rewards, 1449801 frames, score 0, max score 4
# Completed 4981 games, 6407 rewards, 1449982 frames, score 0, max score 4
# Completed 4982 games, 6408 rewards, 1450190 frames, score 0, max score 4
# Completed 4983 games, 6409 rewards, 1450398 frames, score 0, max score 4
# Completed 4984 games, 6410 rewards, 1450606 frames, score 0, max score 4
# Completed 4985 games, 6411 rewards, 1450787 frames, score 0, max score 4
# Completed 4986 games, 6412 rewards, 1450995 frames, score 0, max score 4
# Completed 4987 games, 6413 rewards, 1451249 frames, score 0, max score 4
# Completed 4988 games, 6414 rewards, 1451503 frames, score 0, max score 4
# Completed 4989 games, 6415 rewards, 1451684 frames, score 0, max score 4
# Completed 4990 games, 6416 rewards, 1451865 frames, score 0, max score 4
# Completed 4991 games, 6418 rewards, 1452287 frames, score 1, max score 4
# Completed 4992 games, 6422 rewards, 1453494 frames, score 3, max score 4
# Completed 4993 games, 6423 rewards, 1453675 frames, score 0, max score 4
# Completed 4994 games, 6424 rewards, 1453929 frames, score 0, max score 4
# Completed 4995 games, 6426 rewards, 1454441 frames, score 1, max score 4
# Completed 4996 games, 6427 rewards, 1454622 frames, score 0, max score 4
# Completed 4997 games, 6429 rewards, 1455134 frames, score 1, max score 4
# Completed 4998 games, 6430 rewards, 1455315 frames, score 0, max score 4
# Completed 4999 games, 6431 rewards, 1455569 frames, score 0, max score 4
# The number of games played was 5000
# The number of video frames was 5000
# The size of each returned Q-matrix was (0,)

# %% [markdown]
# Now let's plot the score, to see if it improved over time.  We will also plot the local average, averaged over 10 consecutive games, to see if that has improved.  Notice that we can use `np.convolve` to compute the local average.
#
# These numbers are really noisy, with a really large maximum.  We will plot `np.log10(1+x)`, rather than x, so that we can better see the average numbers, and ignore the very large noisy spikes.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(14,9),layout='tight')
ax = [ fig.add_subplot(3,1,x) for x in range(1,4) ]
ax[0].plot(np.arange(0,len(scores)),np.log10(1+np.array(scores)))
ax[0].plot([0,5000],np.log10([7,7]),'k--')
ax[0].set_title('Game scores')
ax[1].plot(np.arange(4991),np.log10(1+np.convolve(np.ones(10)/10,scores,mode='valid')))
ax[1].plot([0,4991],np.log10([7,7]),'k--')
ax[1].set_title('Game scores, average 10 consecutive games')
ax[2].plot(np.arange(0,len(q_achieved)),q_achieved)
ax[2].set_title('Q values of state achieved at each time')
ax[2].set_ylabel('Game number')
# Out:
# Text(0, 0.5, 'Game number')

# %% [markdown]
# Hooray, it has learned!  If you are getting a ten-game average score of better than 6, then you are ready to submit your model for grading.   In order to do that, you need to save the model:

# %%
q_learner.save('trained_model.npz')

# %% [markdown]
# <a id='section9'></a>

# %% [markdown]
# ## Extra Credit

# %% [markdown]
# For extra credit, download the file <a href="mp11_extra.zip">mp11_extra.zip</a>.  The only important file in this package is:
# * `tests/test_extra.py`: this contains extra tests that will evaluate your pre-trained `deep_q` learner, which should be in a file called `trained_model.pkl`.  For full credit, your model should achieve an average score of greater than 20, averaged over 10 consecutive games.
#
# With a quantized lookup table, it's probably not possible to achieve an average score of 20.  With a deep-Q learner, however, it is eminently possible.  In order to do the extra credit, therefore, you should just fill in the part of `submitted.py` that implements the `deep_q` learner, using pytorch to define a model structure, train it, save it, load it, and act on it.  This learner only needs to have five methods: `__init__`, `act`, `learn`, `save`, and `load`:

# %%
importlib.reload(submitted)
help(submitted.deep_q.__init__)
# Out:
# Help on function __init__ in module submitted:
#
# __init__(self, alpha, epsilon, gamma, nfirst)
#     Create a new deep_q learner.
#     Your q_learner object should store the provided values of alpha,
#     epsilon, gamma, and nfirst.
#     It should also create a deep learning model that will accept
#     (state,action) as input, and estimate Q as the output.
#
#     @params:
#     alpha (scalar) - learning rate of the Q-learner
#     epsilon (scalar) - probability of taking a random action
#     gamma (scalar) - discount factor
#     nfirst (scalar) - exploring each state/action pair nfirst times before exploiting
#
#     @return:
#     None

# %%
help(submitted.deep_q.act)
# Out:
# Help on function act in module submitted:
#
# act(self, state)
#     Decide what action to take in the current state.
#     You are free to determine your own exploration/exploitation policy --
#     you don't need to use the epsilon and nfirst provided to you.
#
#     @params:
#     state: a list of 5 floats: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#
#     @return:
#     -1 if the paddle should move upward
#     0 if the paddle should be stationary
#     1 if the paddle should move downward

# %%
help(submitted.deep_q.learn)
# Out:
# Help on function learn in module submitted:
#
# learn(self, state, action, reward, newstate)
#     Perform one iteration of training on a deep-Q model.
#
#     @params:
#     state: a list of 5 floats: ball_x, ball_y, ball_vx, ball_vy, paddle_y
#     action: an integer, one of -1, 0, or +1
#     reward: a reward; positive for hitting the ball, negative for losing a game
#     newstate: a list of 5 floats, in the same format as state
#
#     @return:
#     None

# %%
help(submitted.deep_q.save)
# Out:
# Help on function save in module submitted:
#
# save(self, filename)
#     Save your trained deep-Q model to a file.
#     This can save in any format you like, as long as your "load"
#     function uses the same file format.
#
#     @params:
#     filename (str) - filename to which it should be saved
#     @return:
#     None

# %%
help(submitted.deep_q.load)
# Out:
# Help on function load in module submitted:
#
# load(self, filename)
#     Load your deep-Q model from a file.
#     This should load from whatever file format your save function
#     used.
#
#     @params:
#     filename (str) - filename from which it should be loaded
#     @return:
#     None

# %% [markdown]
# <a id='grade'></a>

# %% [markdown]
# ## Grade your homework

# %% [markdown]
# If you've reached this point, and all of the above sections work, then you're ready to try grading your homework!  Before you submit it to Gradescope, try grading it on your own machine.  This will run some visible test cases (which you can read in `tests/test_visible.py`), and compare the results to the solutions (which you can read in `solution.json`).
#
# The exclamation point (!) tells python to run the following as a shell command.  Obviously you don't need to run the code this way -- this usage is here just to remind you that you can also, if you wish, run this command in a terminal window.

# %%
# !python grade.py
# Out:
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.3125, 0.0, 0.0]
# q-values [0.3125, 0.0, 0.0]
# q-values [0.0, 0.0, 0.17046875000000003]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# Completed 0 games, 2 rewards, 464 frames, score 1, max score 1
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, -0.5, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# Completed 1 games, 3 rewards, 672 frames, score 0, max score 1
# q-values [0.0, 0.0, 0.0]
# q-values [-0.5, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# Completed 2 games, 4 rewards, 853 frames, score 0, max score 1
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, -0.5, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, -0.5, 0.0]
# q-values [0.0, -0.5, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# Completed 3 games, 5 rewards, 1107 frames, score 0, max score 1
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, -0.5]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# .....F
# ======================================================================
# FAIL: test_trained_model (test_visible.TestStep.test_trained_model)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "c:\Users\mycol\CS440\MP11-Reinforcement-Learning\tests\test_visible.py", line 88, in test_trained_model
#     self.assertGreater(np.average(scores),6,
# AssertionError: 0.4 not greater than 6 : trained_model.npz average score is 0.4 which is not above 6
#
#
# ----------------------------------------------------------------------
# Ran 6 tests in 0.066s
#
# FAILED (failures=1)
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# Completed 4 games, 8 rewards, 1828 frames, score 2, max score 2
# q-values [0.0, 0.0, 0.0]
# q-values [-0.5, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# ...
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# Completed 7 games, 12 rewards, 2696 frames, score 0, max score 2
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, -0.5]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# Completed 8 games, 13 rewards, 2950 frames, score 0, max score 2
# q-values [0.0, 0.0, 0.0]
# q-values [-0.5, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, 0.0]
# Completed 9 games, 14 rewards, 3131 frames, score 0, max score 2
# q-values [0.0, 0.0, 0.0]
# q-values [0.0, 0.0, -0.5]

# %% [markdown]
# Now you should try uploading your code to <a href="https://www.gradescope.com/courses/486387">Gradescope</a>.
#
# **Warning:** For this MP you need to update two files, not just one.
# * `trained_model.npz` should contain your trained model
# * `submitted.py` should contain your code that loads and runs your trained model.
#
# **Warning:** The autograder calculates the average score over ten random games.  If you are getting an average score above 10 almost all the time on your own computer, and if the autograder says you had a score below 10, try resubmitting to see if the next round of random games is better.
#
# **Extra Credit:** Your extra credit should also be uploaded as two files,
# * `trained_model.pkl` should contain your trained model
# * `submitted.py` should contain your code that loads and runs your trained model.
